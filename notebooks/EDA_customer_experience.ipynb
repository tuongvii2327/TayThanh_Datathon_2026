# %% [markdown]
# # EDA trải nghiệm khách hàng

# %% [markdown]
# Tài liệu này tập trung phân tích trải nghiệm của khách hàng thông qua dữ liệu trả hàng và đánh giá sản phẩm của công ty

# %% [markdown]
# ### Preparing the analytical environment

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# ## Phase 1: Data Understanding & Profiling
# Xem và đánh giá tổng quan dữ liệu, chưa thao tác chỉnh sửa trên dữ liệu

# %% [markdown]
# ### 1.1 Load data

# %%
print("Loading data...")

df_cus = pd.read_csv('../dataset1/customers.csv')
df_ord = pd.read_csv('../dataset1/orders.csv')
df_pduct = pd.read_csv('../dataset1/products.csv')
df_ret = pd.read_csv('../dataset1/returns.csv')
df_rev = pd.read_csv('../dataset1/reviews.csv')

#df_geo = pd.read_csv('../dataset1/geography.csv')
#df_item = pd.read_csv('../dataset1/order_items.csv')
#df_pay = pd.read_csv('../dataset1/payments.csv')
#df_pmot = pd.read_csv('../dataset1/promotions.csv')
#df_ship = pd.read_csv('../dataset1/shipments.csv')
#df_web = pd.read_csv('../dataset1/web_traffic.csv')

print("Load data successfully")
# Out:
# Loading data...
# Load data successfully

# %% [markdown]
# ### 1.2 Describe Data

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# 1. Đọc dữ liệu (ví dụ file CSV)
df = pd.read_csv('du_lieu_cua_ban.csv')

# 2. Tạo báo cáo
profile = ProfileReport(df, title="Báo cáo Tổng quan Dữ liệu")

# 3. Xuất kết quả
# Cách 1: Lưu thành file HTML để gửi cho sếp hoặc đồng đội xem (khuyên dùng)
profile.to_file("baocao_data.html")

# Cách 2: Hiển thị trực tiếp ngay trong Jupyter Notebook
profile.to_notebook_iframe()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#       4 # 1. Đọc dữ liệu (ví dụ file CSV)
#       5 df = pd.read_csv('du_lieu_cua_ban.csv')
#
# ModuleNotFoundError: No module named 'ydata_profiling'
