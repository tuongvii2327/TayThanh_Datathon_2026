# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df_pmot = pd.read_parquet('../dataset/cleaned/promotions.parquet')

# %% [markdown]
# # 1. Load the data

# %%
df_products= pd.read_parquet('../dataset/cleaned/products.parquet')
df_order_items= pd.read_parquet('../dataset/cleaned/order_items.parquet')

# %% [markdown]
# ### Merged file products.csv and order_items.csv through product_id column

# %%
df_merged= pd.merge(df_products, df_order_items, on='product_id', how='left')

# %%
print("Cột trong order_items:", df_order_items.columns.tolist())
print("Cột sau khi merged:", df_merged.columns.tolist())
# Out:
# Cột trong order_items: ['order_id', 'product_id', 'quantity', 'unit_price', 'discount_amount', 'promo_id', 'promo_id_2']
# Cột sau khi merged: ['product_id', 'product_name', 'category', 'segment', 'size', 'color', 'price', 'cogs', 'order_id', 'quantity', 'unit_price', 'discount_amount', 'promo_id', 'promo_id_2']

# %%
df_merged.head()
# Out:
#   product_id      product_name    category   segment size  color     price  \
# 0        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 1        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 2        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 3        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 4        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
#
#           cogs order_id  quantity  unit_price  discount_amount promo_id  \
# 0  9704.842875   245451       5.0    11183.67              0.0     None
# 1  9704.842875   245898       8.0    10918.75              0.0     None
# 2  9704.842875   246268       6.0    11184.55              0.0     None
# 3  9704.842875   246907       2.0    11104.72              0.0     None
# 4  9704.842875   247911       6.0    11143.16              0.0     None
#
#   promo_id_2
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None

# %%
df_promos = pd.read_parquet('../dataset/cleaned/promotions.parquet')
df_final = df_merged.merge(df_promos, on='promo_id', how='left')
display(df_final.head())
# Out:
#   product_id      product_name    category   segment size  color     price  \
# 0        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 1        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 2        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 3        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 4        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
#
#           cogs order_id  quantity  ...  promo_id_2  promo_name promo_type  \
# 0  9704.842875   245451       5.0  ...        None        <NA>        NaN
# 1  9704.842875   245898       8.0  ...        None        <NA>        NaN
# 2  9704.842875   246268       6.0  ...        None        <NA>        NaN
# 3  9704.842875   246907       2.0  ...        None        <NA>        NaN
# 4  9704.842875   247911       6.0  ...        None        <NA>        NaN
#
#   discount_value start_date end_date  applicable_category promo_channel  \
# 0            NaN        NaT      NaT                  NaN           NaN
# 1            NaN        NaT      NaT                  NaN           NaN
# 2            NaN        NaT      NaT                  NaN           NaN
# 3            NaN        NaT      NaT                  NaN           NaN
# 4            NaN        NaT      NaT                  NaN           NaN
#
#   stackable_flag min_order_value
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# 3            NaN             NaN
# 4            NaN             NaN
#
# [5 rows x 23 columns]

# %%
df_orders = pd.read_parquet('../dataset/cleaned/orders.parquet')
df_master = df_final.merge(df_orders[['order_id', 'order_date']], on='order_id', how='left')

df_master = df_master.rename(columns={'order_date': 'Date'})
print("Kích thước bảng Master:", df_master.shape)
display(df_master.head())
# Out:
# Kích thước bảng Master: (715483, 24)
#   product_id      product_name    category   segment size  color     price  \
# 0        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 1        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 2        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 3        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 4        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
#
#           cogs order_id  quantity  ...  promo_name  promo_type discount_value  \
# 0  9704.842875   245451       5.0  ...        <NA>         NaN            NaN
# 1  9704.842875   245898       8.0  ...        <NA>         NaN            NaN
# 2  9704.842875   246268       6.0  ...        <NA>         NaN            NaN
# 3  9704.842875   246907       2.0  ...        <NA>         NaN            NaN
# 4  9704.842875   247911       6.0  ...        <NA>         NaN            NaN
#
#   start_date end_date applicable_category  promo_channel stackable_flag  \
# 0        NaT      NaT                 NaN            NaN            NaN
# 1        NaT      NaT                 NaN            NaN            NaN
# 2        NaT      NaT                 NaN            NaN            NaN
# 3        NaT      NaT                 NaN            NaN            NaN
# 4        NaT      NaT                 NaN            NaN            NaN
#
#   min_order_value       Date
# 0             NaN 2015-01-07
# 1             NaN 2015-01-13
# 2             NaN 2015-01-13
# 3             NaN 2015-01-17
# 4             NaN 2015-01-24
#
# [5 rows x 24 columns]

# %% [markdown]
# # 2. EDA

# %%
check_promo = df_final[df_final['promo_name'].notna()]
print(f"Tổng số dòng có thông tin khuyến mãi: {len(check_promo)}")
display(check_promo.head())
# Out:
# Tổng số dòng có thông tin khuyến mãi: 276316
#    product_id      product_name    category   segment size   color  \
# 14        536  SaigonFlex UC-01  Streetwear  Everyday    S   green
# 15        536  SaigonFlex UC-01  Streetwear  Everyday    S   green
# 16        536  SaigonFlex UC-01  Streetwear  Everyday    S   green
# 26        536  SaigonFlex UC-01  Streetwear  Everyday    S   green
# 27        537  SaigonFlex UC-02  Streetwear  Everyday    M  silver
#
#            price         cogs order_id  quantity  ...  promo_id_2  \
# 14  11059.650000  9704.842875   259871       1.0  ...        None
# 15  11059.650000  9704.842875   268094       6.0  ...        None
# 16  11059.650000  9704.842875   268430       8.0  ...        None
# 26  11059.650000  9704.842875   299601       3.0  ...        None
# 27   9523.076013  5393.870254   523256       7.0  ...        None
#
#             promo_name  promo_type discount_value start_date   end_date  \
# 14    Spring Sale 2015  percentage           12.0 2015-03-18 2015-04-17
# 15    Spring Sale 2015  percentage           12.0 2015-03-18 2015-04-17
# 16    Spring Sale 2015  percentage           12.0 2015-03-18 2015-04-17
# 26  Mid-Year Sale 2015  percentage           18.0 2015-06-23 2015-07-22
# 27  Urban Blowout 2017       fixed           50.0 2017-07-30 2017-09-02
#
#     applicable_category promo_channel stackable_flag min_order_value
# 14                  All  all_channels           True        100000.0
# 15                  All  all_channels           True        100000.0
# 16                  All  all_channels           True        100000.0
# 26                  All  social_media          False             0.0
# 27           Streetwear        online          False        150000.0
#
# [5 rows x 23 columns]

# %%
df_final.info()
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715483 entries, 0 to 715482
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   product_id           715483 non-null  string
#  1   product_name         715483 non-null  string
#  2   category             715483 non-null  category
#  3   segment              715483 non-null  category
#  4   size                 715483 non-null  category
#  5   color                715483 non-null  category
#  6   price                715483 non-null  float64
#  7   cogs                 715483 non-null  float64
#  8   order_id             714669 non-null  string
#  9   quantity             714669 non-null  float64
#  10  unit_price           714669 non-null  float64
#  11  discount_amount      714669 non-null  float64
#  12  promo_id             714669 non-null  string
#  13  promo_id_2           714669 non-null  string
#  14  promo_name           276316 non-null  string
#  15  promo_type           276316 non-null  category
#  16  discount_value       276316 non-null  float64
#  17  start_date           276316 non-null  datetime64[ns]
#  18  end_date             276316 non-null  datetime64[ns]
#  19  applicable_category  276316 non-null  category
#  20  promo_channel        276316 non-null  category
#  21  stackable_flag       276316 non-null  object
#  22  min_order_value      276316 non-null  float64
# dtypes: category(7), datetime64[ns](2), float64(7), object(1), string(6)
# memory usage: 92.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715483 entries, 0 to 715482
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   product_id           715483 non-null  string
#  1   product_name         715483 non-null  string
#  2   category             715483 non-null  category
#  3   segment              715483 non-null  category
#  4   size                 715483 non-null  category
#  5   color                715483 non-null  category
#  6   price                715483 non-null  float64
#  7   cogs                 715483 non-null  float64
#  8   order_id             714669 non-null  string
#  9   quantity             714669 non-null  float64
#  10  unit_price           714669 non-null  float64
#  11  discount_amount      714669 non-null  float64
#  12  promo_id             714669 non-null  string
#  13  promo_id_2           714669 non-null  string
#  14  promo_name           276316 non-null  string
#  15  promo_type           276316 non-null  category
#  16  discount_value       276316 non-null  float64
#  17  start_date           276316 non-null  datetime64[ns]
#  18  end_date             276316 non-null  datetime64[ns]
#  19  applicable_category  276316 non-null  category
#  20  promo_channel        276316 non-null  category
#  21  stackable_flag       276316 non-null  object
#  22  min_order_value      276316 non-null  float64
#  23  Date                 714669 non-null  datetime64[ns]
# dtypes: category(7), datetime64[ns](3), float64(7), object(1), string(6)
# memory usage: 97.6+ MB

# %%
# print(df_master[df_master['order_id'].isnull()].sample(5))
df_missing_orders = df_master[df_master['order_id'].isnull()]
print(df_missing_orders['product_id'].is_unique)

missing_product_ids = df_missing_orders['product_id']
df_products['is_never_sale'] = df_products['product_id'].isin(missing_product_ids).astype(bool)

duplicate_primary_key = df_products[df_products['product_name'].duplicated(keep=False)].sort_values(by='product_name')
if len(duplicate_primary_key) > 0:
    print(f"{len(duplicate_primary_key)} duplicated product_name rows:")
    display(duplicate_primary_key.head(5))
    
df_products['is_duplicated'] = df_products['product_id'].isin(duplicate_primary_key['product_id']).astype(bool)
df_products = df_products.sort_values(by='product_id')

duplicate_primary_key.to_parquet('duplicate_products.parquet', engine='pyarrow')
df_products.to_parquet('products_add.parquet', engine='pyarrow')
# Out:
# True
# 426 duplicated product_name rows:
#     product_id     product_name    category      segment size   color  \
# 745        380  LotusWear UE-01  Streetwear  Performance    S     red
# 645        280  LotusWear UE-01  Streetwear  Performance    S     red
# 646        281  LotusWear UE-02  Streetwear  Performance    M   black
# 746        381  LotusWear UE-02  Streetwear  Performance    M   black
# 647        282  LotusWear UE-03  Streetwear  Performance    L  orange
#
#             price          cogs  is_never_sale
# 745     34.036218     21.343813           True
# 645  12596.850000  11967.007500          False
# 646  15746.850000   8750.524545          False
# 746     21.651582     12.139172           True
# 647  14486.850000  12008.149965          False

# %%
print("Tổng số sản phẩm sau khi merge:", len(df_master))
print("Số lượng đơn hàng có Date:", df_master['Date'].notnull().sum())
print(f"=> Phát hiện: {len(df_master) - df_master['Date'].notnull().sum()} sản phẩm chưa bao giờ được bán.")
# Out:
# Tổng số sản phẩm sau khi merge: 715483
# Số lượng đơn hàng có Date: 714669
# => Phát hiện: 814 sản phẩm chưa bao giờ được bán.

# %% [markdown]
# ### Insight: Có 814 "sản phẩm ma" (Deadstock). Chúng ta cần loại bỏ chúng để dữ liệu dự báo không bị nhiễu.

# %%
df_master = df_master.dropna(subset=['Date']).reset_index(drop=True)
print("Kích thước bảng thực tế:", df_master.shape)
# Out:
# Kích thước bảng thực tế: (714669, 24)

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714669 entries, 0 to 714668
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   product_id           714669 non-null  string
#  1   product_name         714669 non-null  string
#  2   category             714669 non-null  category
#  3   segment              714669 non-null  category
#  4   size                 714669 non-null  category
#  5   color                714669 non-null  category
#  6   price                714669 non-null  float64
#  7   cogs                 714669 non-null  float64
#  8   order_id             714669 non-null  string
#  9   quantity             714669 non-null  float64
#  10  unit_price           714669 non-null  float64
#  11  discount_amount      714669 non-null  float64
#  12  promo_id             714669 non-null  string
#  13  promo_id_2           714669 non-null  string
#  14  promo_name           276316 non-null  string
#  15  promo_type           276316 non-null  category
#  16  discount_value       276316 non-null  float64
#  17  start_date           276316 non-null  datetime64[ns]
#  18  end_date             276316 non-null  datetime64[ns]
#  19  applicable_category  276316 non-null  category
#  20  promo_channel        276316 non-null  category
#  21  stackable_flag       276316 non-null  object
#  22  min_order_value      276316 non-null  float64
#  23  Date                 714669 non-null  datetime64[ns]
# dtypes: category(7), datetime64[ns](3), float64(7), object(1), string(6)
# memory usage: 97.5+ MB

# %% [markdown]
# ### Check if any columns are missing data.

# %%
missing_data = df_master.isnull().sum()
print(missing_data[missing_data > 0])
# Out:
# promo_name             438353
# promo_type             438353
# discount_value         438353
# start_date             438353
# end_date               438353
# applicable_category    438353
# promo_channel          438353
# stackable_flag         438353
# min_order_value        438353
# dtype: int64

# %%
if 'stackable_flag' in df_master.columns:
    df_master['stackable_flag'] = df_master['stackable_flag'].fillna(0)

# %%
missing_data = df_master.isnull().sum()
print(missing_data[missing_data > 0])
# Out:
# promo_name             438353
# promo_type             438353
# discount_value         438353
# start_date             438353
# end_date               438353
# applicable_category    438353
# promo_channel          438353
# min_order_value        438353
# dtype: int64

# %% [markdown]
# ### Add revenue and profit

# %%
df_master['Revenue_line'] = df_master['quantity'] * df_master['unit_price'] - df_master['discount_amount']
df_master['COGS_line'] = df_master['quantity'] * df_master['cogs']
df_master['Profit_line'] = df_master['Revenue_line'] - df_master['COGS_line']

display(df_master[['product_name', 'quantity', 'unit_price', 'cogs', 'Revenue_line', 'Profit_line']].head())
# Out:
#        product_name  quantity  unit_price         cogs  Revenue_line  \
# 0  SaigonFlex UC-01       5.0    11183.67  9704.842875      55918.35
# 1  SaigonFlex UC-01       8.0    10918.75  9704.842875      87350.00
# 2  SaigonFlex UC-01       6.0    11184.55  9704.842875      67107.30
# 3  SaigonFlex UC-01       2.0    11104.72  9704.842875      22209.44
# 4  SaigonFlex UC-01       6.0    11143.16  9704.842875      66858.96
#
#    Profit_line
# 0  7394.135625
# 1  9711.257000
# 2  8878.242750
# 3  2799.754250
# 4  8629.902750

# %%
cat_data = df_master.groupby('category')[['Revenue_line', 'Profit_line']].sum().reset_index()
cat_data = cat_data.sort_values('Profit_line', ascending=False)
cat_data['Profit_Billion'] = cat_data['Profit_line'] / 1e9

plt.figure(figsize=(10, 6))
sns.barplot(data=cat_data, x='Profit_Billion', y='category', hue='category', palette='viridis', legend=False)
plt.title('Tổng lợi nhuận theo từng Ngành hàng')
plt.xlabel('Lợi nhuận (Tỷ VNĐ)')
plt.show()
# Out:
# C:\Users\thaim\AppData\Local\Temp\ipykernel_12672\1575777460.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cat_data = df_master.groupby('category')[['Revenue_line', 'Profit_line']].sum().reset_index()

# %% [markdown]
# ### As illustrated in the bar chart, the Streetwear category accounts for the lion's share of total profit, reaching approximately 1.75 billion VND. My team suggested focusing the marketing budget on this segment to optimize cash flow.

# %%
prod_analysis = df_master.groupby('product_name').agg({
    'Revenue_line': 'sum',
    'Profit_line': 'sum'
}).reset_index()
prod_analysis['Margin_pct'] = (prod_analysis['Profit_line'] / prod_analysis['Revenue_line']) * 100

plt.figure(figsize=(10, 6))
sns.scatterplot(data=prod_analysis, x='Revenue_line', y='Margin_pct', alpha=0.6)
plt.axhline(prod_analysis['Margin_pct'].mean(), color='red', linestyle='--', label='Average Margin')
plt.title('Product Portfolio Analysis: Revenue vs Margin %')
plt.show()

# %% [markdown]
# ### The scatter plot reveals a significant disparity in product performance. While the majority of items are clustered in the low-revenue zone, a few outliers stand out as high-performers with profit margins exceeding the mean of approximately 16%. Notably, there is a concerning anomaly in the bottom-left quadrant exhibiting a negative margin of nearly -80%, which warrants further investigation into potential pricing errors or aggressive discounting strategies.

# %%
outlier = prod_analysis.sort_values('Margin_pct').head(1)
display(outlier)
# Out:
#         product_name  Revenue_line  Profit_line  Margin_pct
# 1325  VietMode UR-02      15606.06   -14192.058  -90.939404

# %%
daily_trend = df_master.groupby('Date')[['Revenue_line', 'Profit_line']].sum().reset_index()

plt.figure(figsize=(12, 5))
sns.lineplot(data=daily_trend, x='Date', y='Profit_line', color='orange', label='Daily Profit')
plt.title('Profit Trend Over Time')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### The line chart illustrates the **daily profit fluctuations** over a decade. It is palpably evident that the business experiences **extreme volatility**, characterized by frequent peaks and significant "dips" where profit plummets into negative territory.
#
# * **Seasonality:** The recurring spikes suggest a strong seasonal pattern, possibly linked to annual shopping festivals or holiday seasons.
# * **Anomalies:** Several "deep dips" (negative profit) are observed periodically. These could be attributed to **aggressive loss-leader strategies** or major clearance sales aimed at inventory turnover rather than immediate margin.
# * **Overall Trend:** Despite the volatility, the business maintains a relatively stable baseline, though a slight saturation is visible in the latter years (2020-2022).

# %% [markdown]
# # 3.Feature Engineering

# %%
df_master['day_of_week'] = df_master['Date'].dt.dayofweek
df_master['month'] = df_master['Date'].dt.month
df_master['is_weekend'] = df_master['day_of_week'].apply(lambda x: 1 if x >= 5 else 0)

# %%
df_master['discount_value'].value_counts()
df_master['discount_pct'] = 0.0
mask_pct = df_master['promo_type'] == 'percentage'
mask_fixed = df_master['promo_type'] == 'fixed'
df_master.loc[mask_pct, 'discount_pct'] = df_master.loc[mask_pct, 'discount_value'] / 100
df_master.loc[mask_fixed, 'discount_pct'] = df_master.loc[mask_fixed, 'discount_value'] / df_master.loc[mask_fixed, 'price']
df_master['discount_pct'] = df_master['discount_pct'].clip(0, 1)
print("Các giá trị discount_pct sau khi tính toán:")
print(df_master['discount_pct'].value_counts().head(10))
# Out:
# Các giá trị discount_pct sau khi tính toán:
# discount_pct
# 0.000000    438353
# 0.200000     71799
# 0.120000     71591
# 0.180000     57417
# 0.100000     45654
# 0.150000      8905
# 0.008532       460
# 0.003840       459
# 0.008978       404
# 0.008150       401
# Name: count, dtype: int64

# %%
df_master['discount_pct_mean'] = df_master['discount_pct'] 
df_master['discount_pct_max'] = df_master['discount_pct']

# %%
df_master['is_promoted']= df_master['promo_id'].apply(lambda x: 0 if x == 'None' else 1)
df_master['discount_rate'] = (df_master['price'] - df_master['unit_price']) / df_master['price']
df_master['discount_rate'] = df_master['discount_rate'].fillna(0)

# %%
df_daily = df_master.groupby('Date').agg({
    'Revenue_line': 'sum',
    'is_promoted': 'max',     
    'day_of_week': 'first',
    'is_weekend': 'first',
}).reset_index()
df_daily = df_daily.sort_values('Date')
df_daily['revenue_lag_1'] = df_daily['Revenue_line'].shift(1)
df_daily['revenue_lag_7'] = df_daily['Revenue_line'].shift(7)
df_daily = df_daily.fillna(0)

# %% [markdown]
# ### Feature Engineering Strategy:
# * To surpass the established baseline, we implemented a robust feature engineering pipeline. Beyond basic temporal variables like day_of_week and is_weekend, we introduced Lag Features (Lag 1​ and Lag 7) to capture the autocorrelation inherent in sales data. Furthermore, by encoding promotion status, the model can now distinguish between natural demand and artificially inflated sales driven by marketing campaigns.

# %%
df_master.info()
df_master['stackable_flag'] = df_master['stackable_flag'].astype(bool)
df_master.to_parquet('sale_train_vi.parquet')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714669 entries, 0 to 714668
# Data columns (total 35 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   product_id           714669 non-null  string
#  1   product_name         714669 non-null  string
#  2   category             714669 non-null  category
#  3   segment              714669 non-null  category
#  4   size                 714669 non-null  category
#  5   color                714669 non-null  category
#  6   price                714669 non-null  float64
#  7   cogs                 714669 non-null  float64
#  8   order_id             714669 non-null  string
#  9   quantity             714669 non-null  float64
#  10  unit_price           714669 non-null  float64
#  11  discount_amount      714669 non-null  float64
#  12  promo_id             714669 non-null  string
#  13  promo_id_2           714669 non-null  string
#  14  promo_name           276316 non-null  string
#  15  promo_type           276316 non-null  category
#  16  discount_value       276316 non-null  float64
#  17  start_date           276316 non-null  datetime64[ns]
#  18  end_date             276316 non-null  datetime64[ns]
#  19  applicable_category  276316 non-null  category
#  20  promo_channel        276316 non-null  category
#  21  stackable_flag       714669 non-null  object
#  22  min_order_value      276316 non-null  float64
#  23  Date                 714669 non-null  datetime64[ns]
#  24  Revenue_line         714669 non-null  float64
#  25  COGS_line            714669 non-null  float64
#  26  Profit_line          714669 non-null  float64
#  27  day_of_week          714669 non-null  int32
#  28  month                714669 non-null  int32
#  29  is_weekend           714669 non-null  int64
#  30  discount_pct         714669 non-null  float64
#  31  discount_pct_mean    714669 non-null  float64
#  32  discount_pct_max     714669 non-null  float64
#  33  is_promoted          714669 non-null  int64
#  34  discount_rate        714669 non-null  float64
# dtypes: category(7), datetime64[ns](3), float64(14), int32(2), int64(2), object(1), string(6)
# memory usage: 152.0+ MB

# %% [markdown]
# # 4. Machine Learning

# %%
# One-Hot Encoding cho Category & Segment
df_encoded = pd.get_dummies(df_master, columns=['category', 'segment'], prefix=['cat', 'seg'])

# Lấy danh sách các cột vừa mới tạo ra từ One-Hot
encoded_cols = [col for col in df_encoded.columns if col.startswith(('cat_', 'seg_'))]

special_days = [
    '01-01', '02-14',
    '04-30', '05-01',
    '12-31', '12-24', '12-25'
]
def get_special_event(date):
    return 1 if date.strftime('%m-%d') in special_days else 0
# Daily Aggregation: Nén dữ liệu về dạng Ngày
df_encoded['is_special'] = df_encoded['Date'].apply(get_special_event)
df_encoded['is_payday'] = ((df_encoded['Date'].dt.day == 15) | (df_encoded['Date'].dt.is_month_end)).astype(int)
# Với các cột One-Hot, chúng ta dùng 'sum' để biết ngày đó bán được bao nhiêu món thuộc loại đó
agg_logic = {
    'Revenue_line': 'sum',
    'Profit_line': 'sum',
    'is_promoted': 'max',  
    'day_of_week': 'first',
    'month': 'first',
    'is_weekend': 'first',
    'is_special': 'max',
    'is_payday': 'max',
    'discount_pct_mean' : 'mean',
    'discount_pct_max' : 'max'
}
# Thêm các cột encoded vào logic tính tổng
for col in encoded_cols:
    agg_logic[col] = 'sum'
df_daily = df_encoded.groupby('Date').agg(agg_logic).reset_index()
df_daily.columns = ['_'.join(col) if isinstance(col, tuple) else col for col in df_daily.columns]
# Lag Features
# Model sẽ nhìn vào kết quả của 1 ngày và 7 ngày trước đó để dự báo
df_daily = df_daily.sort_values('Date')
df_daily['rev_lag_1'] = df_daily['Revenue_line'].shift(1)
df_daily['rev_lag_7'] = df_daily['Revenue_line'].shift(7)
df_daily['rev_lag_365'] = df_daily['Revenue_line'].shift(365)

df_daily['margin_rate']= df_daily['Profit_line'] / df_daily['Revenue_line']
df_daily['margin_rate_lag_7'] = df_daily['margin_rate'].shift(7)
df_daily['margin_rate_lag_1'] = df_daily['margin_rate'].shift(1)
df_daily['margin_rate_lag_365'] = df_daily['margin_rate'].shift(365)

df_daily['profit_lag_1'] = df_daily['Profit_line'].shift(1)
df_daily['profit_lag_7'] = df_daily['Profit_line'].shift(7)
df_daily['profit_lag_365'] = df_daily['Profit_line'].shift(365)
# Cuối cùng là lấp đầy các giá trị NaN do hàm shift tạo ra
df_daily = df_daily.fillna(0)

# Đổi tên cho đúng format
df_daily = df_daily.rename(columns={'Revenue_line': 'Revenue', 'Profit_line': 'Profit'})
df_daily = df_daily.rename(columns={'discount_pct_mean': 'avg_discount_pct', 'discount_pct_max': 'max_discount_pct'})
print("Kích thước bảng Daily:", df_daily.shape)
display(df_daily.head())
# Out:
# Kích thước bảng Daily: (3833, 33)
#         Date     Revenue        Profit  is_promoted  day_of_week  month  \
# 0 2012-07-04  5123547.94  1.140557e+06            0            2      7
# 1 2012-07-05  2751773.45  6.011932e+05            0            3      7
# 2 2012-07-06  3054029.42  5.363966e+05            0            4      7
# 3 2012-07-07  2667930.94  5.596843e+05            0            5      7
# 4 2012-07-08  2360851.90  5.522291e+05            0            6      7
#
#    is_weekend  is_special  is_payday  avg_discount_pct  ...   rev_lag_1  \
# 0           0           0          0               0.0  ...        0.00
# 1           0           0          0               0.0  ...  5123547.94
# 2           0           0          0               0.0  ...  2751773.45
# 3           1           0          0               0.0  ...  3054029.42
# 4           1           0          0               0.0  ...  2667930.94
#
#    rev_lag_7  rev_lag_365  margin_rate  margin_rate_lag_7  margin_rate_lag_1  \
# 0        0.0          0.0     0.222611                0.0           0.000000
# 1        0.0          0.0     0.218475                0.0           0.222611
# 2        0.0          0.0     0.175636                0.0           0.218475
# 3        0.0          0.0     0.209782                0.0           0.175636
# 4        0.0          0.0     0.233911                0.0           0.209782
#
#    margin_rate_lag_365  profit_lag_1  profit_lag_7  profit_lag_365
# 0                  0.0  0.000000e+00           0.0             0.0
# 1                  0.0  1.140557e+06           0.0             0.0
# 2                  0.0  6.011932e+05           0.0             0.0
# 3                  0.0  5.363966e+05           0.0             0.0
# 4                  0.0  5.596843e+05           0.0             0.0
#
# [5 rows x 33 columns]

# %%
df_daily['year'] = df_daily['Date'].dt.year
df_daily['month_day'] = df_daily['Date'].dt.strftime('%m-%d')

df_daily['is_Spring_promotion'] = df_daily['month_day'].between('03-18', '04-17').astype(int)
df_daily['is_MidYear_promotion'] = df_daily['month_day'].between('06-23', '07-22').astype(int)
df_daily['is_FallLauch_promotion'] = (df_daily['month_day'].between('08-30', '10-01') | ((df_daily['year'] % 4 == 1) & (df_daily['month_day'] == '10-02'))).astype(int)
df_daily['is_YearEnd_promotion'] = (df_daily['month_day'].between('11-18', '12-31') |  df_daily['month_day'].between('01-01', '01-02')).astype(int) # có nhiều ngày kết thúc khác nhưng fix vào 02/01 hàng năm
df_daily['is_Rural_promotion'] = ((df_daily['year'] % 2 == 1)  & df_daily['month_day'].between('01-30', '03-01')).astype(int) # từ năm 2015 mới cố định ngày kết thúc
df_daily['is_Urban_promotion'] = ((df_daily['year'] % 2 == 1)  & df_daily['month_day'].between('07-30', '09-02')).astype(int)
df_daily['category_promotion'] = -1 # default: if it isn't in any promotion
df_daily['chanel_promotion'] = -1 # default: if it isn't in any promotion
# df_daily['pct_discount_promotion'] = 0.0 # default: if it isn't in any promotion
# df_daily['fix_discount_promotion'] = 0 # default: if it isn't in any promotion

#decode category_promotion: 0 -> All ; 1 -> Outdoor ; 2 -> Steetwear
df_daily.loc[(df_daily['is_Spring_promotion'] | df_daily['is_MidYear_promotion'] | df_daily['is_YearEnd_promotion']), 'category_promotion'] = 0
df_daily.loc[df_daily['is_Rural_promotion'], 'category_promotion'] = 1
df_daily.loc[df_daily['is_Urban_promotion'], 'category_promotion'] = 2

#decode chanel_promotion: 0 -> all_chanel ; 1 -> in_store ; 2 -> online ; 3 -> onl or social ; 4 onl or email or social
df_daily.loc[(df_daily['is_Spring_promotion'] | df_daily['is_FallLauch_promotion']), 'chanel_promotion'] = 4
df_daily.loc[df_daily['is_Rural_promotion'], 'chanel_promotion'] = 1
df_daily.loc[df_daily['is_Urban_promotion'], 'chanel_promotion'] = 2
df_daily.loc[df_daily['is_MidYear_promotion'], 'chanel_promotion'] = 3
df_daily.loc[df_daily['is_YearEnd_promotion'], 'chanel_promotion'] = 0

# #setup pct_discount_promotion
# df_daily.loc[(df_daily['is_Spring_promotion'] | df_daily['is_FallLauch_promotion']), 'chanel_promotion'] = 4


df_daily.to_parquet('sale_train_vi.parquet')

# %%
final_features=['seg_Balanced', 'seg_Activewear', 'seg_Premium', 'seg_All-weather', 'seg_Everyday', 'seg_Performance', 
                'cat_Casual', 'cat_Outdoor', 'cat_Streetwear', 
                
                'rev_lag_1', 'rev_lag_7', 'rev_lag_365', 
                'profit_lag_1', 'profit_lag_7', 'profit_lag_365', 
                'margin_rate', 'margin_rate_lag_1', 'margin_rate_lag_7', 'margin_rate_lag_365',  
                
                'month', 'is_promoted', 
                'avg_discount_pct', 'max_discount_pct',

                'is_Spring_promotion', 'is_MidYear_promotion', 'is_FallLauch_promotion',
                'is_YearEnd_promotion', 'is_Rural_promotion', 'is_Urban_promotion',
                'category_promotion', 'chanel_promotion']

# %%
df_daily['COGS'] = df_daily['Revenue'] - df_daily['Profit']
# Xác định danh sách Feature
features = final_features
print("Danh sách Feature cho Model:", features)
# Out:
# Danh sách Feature cho Model: ['seg_Balanced', 'seg_Activewear', 'seg_Premium', 'seg_All-weather', 'seg_Everyday', 'seg_Performance', 'cat_Casual', 'cat_Outdoor', 'cat_Streetwear', 'rev_lag_1', 'rev_lag_7', 'rev_lag_365', 'profit_lag_1', 'profit_lag_7', 'profit_lag_365', 'margin_rate', 'margin_rate_lag_1', 'margin_rate_lag_7', 'margin_rate_lag_365', 'month', 'is_promoted', 'avg_discount_pct', 'max_discount_pct', 'is_Spring_promotion', 'is_MidYear_promotion', 'is_FallLauch_promotion', 'is_YearEnd_promotion', 'is_Rural_promotion', 'is_Urban_promotion', 'category_promotion', 'chanel_promotion']

# %%
# 1. Xác định Target và Features
target = 'Revenue'
# 2. Tách dữ liệu theo thời gian (Ví dụ: lấy 2 tháng cuối 2022 để kiểm tra)
train_data = df_daily[(df_daily['Date'] <= '2021-12-31') & (df_daily['Date'] >= '2013-01-01')]
val_data = df_daily[df_daily['Date'] > '2021-12-31']

# 3. Tạo bộ X (câu hỏi) và y (đáp án)
X_train = train_data[features]
y_train = train_data[target]

X_val = val_data[features]
y_val = val_data[target]

print(f"Đã sẵn sàng! Train: {X_train.shape}, Val: {X_val.shape}")
# Out:
# Đã sẵn sàng! Train: (3287, 31), Val: (365, 31)

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

def objective(trial):
    # 1. Khai báo các "nút vặn" cần tìm
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 500, 2000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
    }


    # 2. Chạy thử mô hình với bộ tham số này
    model = XGBRegressor(**param, tree_method='hist')

    # --- ĐOẠN CODE SỬA LỖI ---
    # Loại bỏ các cột bị trùng tên trong X_train và X_val (nếu có)
    X_train_clean = X_train.loc[:, ~X_train.columns.duplicated()].copy()
    X_val_clean = X_val.loc[:, ~X_val.columns.duplicated()].copy()

    # Ép y_train về dạng 1 chiều (Series) bằng .squeeze()
    y_train_1d = y_train.squeeze()
    y_val_1d = y_val.squeeze()
    # -------------------------

    # Fit mô hình với dữ liệu đã dọn dẹp
    model.fit(X_train_clean, y_train_1d)

    # 3. Tính sai số trên tập Validation
    preds = model.predict(X_val_clean)
    mse = mean_squared_error(y_val_1d, preds)
    rmse = np.sqrt(mse)

    return rmse


    # # 2. Chạy thử mô hình với bộ tham số này
    # model = XGBRegressor(**param, tree_method='hist') # Dùng hist để chạy cho nhanh
    # model.fit(X_train, y_train)
    
    # # 3. Tính sai số trên tập Validation (Nhớ dùng Time Series Split để test cho chuẩn)
    # preds = model.predict(X_val)
    # mse = mean_squared_error(y_val, preds)
    # rmse = np.sqrt(mse)
    
    # return rmse

# 4. Bắt đầu cuộc đi tìm "kho báu"
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=200) 

print("Bộ tham số xịn nhất đây rồi:", study.best_params)
# Out:
# [I 2026-04-27 21:10:52,383] A new study created in memory with name: no-name-2b3a3067-8d48-4036-b4d3-98de7c5a9107
# [I 2026-04-27 21:10:53,075] Trial 0 finished with value: 308957.7638150155 and parameters: {'n_estimators': 976, 'max_depth': 3, 'learning_rate': 0.04428075027529903, 'subsample': 0.8246504374543351, 'colsample_bytree': 0.6252142576820865, 'reg_alpha': 0.4417935175313012, 'reg_lambda': 0.10343077516771326}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:10:56,410] Trial 1 finished with value: 355680.83757334645 and parameters: {'n_estimators': 884, 'max_depth': 8, 'learning_rate': 0.02705862234387645, 'subsample': 0.9405791586827984, 'colsample_bytree': 0.8117665683599478, 'reg_alpha': 1.2726668803653443, 'reg_lambda': 0.4208059808165401}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:11:00,196] Trial 2 finished with value: 357624.13051137753 and parameters: {'n_estimators': 997, 'max_depth': 8, 'learning_rate': 0.025138770892615684, 'subsample': 0.7805592083854481, 'colsample_bytree': 0.6381689239767943, 'reg_alpha': 0.0031586312190201617, 'reg_lambda': 0.01087243993382045}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:11:07,019] Trial 3 finished with value: 365733.8949938581 and parameters: {'n_estimators': 1526, 'max_depth': 8, 'learning_rate': 0.04612206468170178, 'subsample': 0.9544482667606551, 'colsample_bytree': 0.8475210531589981, 'reg_alpha': 0.001097591348928075, 'reg_lambda': 0.05089549172152032}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:11:07,558] Trial 4 finished with value: 333317.0413434793 and parameters: {'n_estimators': 713, 'max_depth': 3, 'learning_rate': 0.018254477500326095, 'subsample': 0.705740421950011, 'colsample_bytree': 0.661711859125104, 'reg_alpha': 0.08854699826281465, 'reg_lambda': 0.00291416124087049}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:11:13,092] Trial 5 finished with value: 397113.55483162246 and parameters: {'n_estimators': 1067, 'max_depth': 9, 'learning_rate': 0.09248092334281631, 'subsample': 0.7590182625013623, 'colsample_bytree': 0.6521173254176291, 'reg_alpha': 8.387416901519954, 'reg_lambda': 0.06109515878756348}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:11:14,100] Trial 6 finished with value: 309971.8442620901 and parameters: {'n_estimators': 1011, 'max_depth': 4, 'learning_rate': 0.026976881813090103, 'subsample': 0.577941560810816, 'colsample_bytree': 0.7542364560382893, 'reg_alpha': 0.008083790148535165, 'reg_lambda': 0.012330509004570235}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:11:25,116] Trial 7 finished with value: 359632.51381412795 and parameters: {'n_estimators': 1767, 'max_depth': 10, 'learning_rate': 0.03376167440109891, 'subsample': 0.5989805237773889, 'colsample_bytree': 0.7951547033537492, 'reg_alpha': 0.0013321392458169198, 'reg_lambda': 0.4055759274278249}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:11:26,410] Trial 8 finished with value: 309831.21322505095 and parameters: {'n_estimators': 944, 'max_depth': 4, 'learning_rate': 0.06774237803610987, 'subsample': 0.5196821988882315, 'colsample_bytree': 0.9463189214755569, 'reg_alpha': 0.11511178985513909, 'reg_lambda': 0.17040993679156927}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:11:29,359] Trial 9 finished with value: 329317.19230657123 and parameters: {'n_estimators': 1331, 'max_depth': 6, 'learning_rate': 0.01033666172476978, 'subsample': 0.8666877867000713, 'colsample_bytree': 0.5712218756068723, 'reg_alpha': 0.14837980359313055, 'reg_lambda': 0.024223871964218522}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:11:30,153] Trial 10 finished with value: 343706.0682255097 and parameters: {'n_estimators': 578, 'max_depth': 6, 'learning_rate': 0.04938209632534226, 'subsample': 0.852224300602154, 'colsample_bytree': 0.5214622592191013, 'reg_alpha': 0.9816279906099691, 'reg_lambda': 4.853685034269405}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:11:31,292] Trial 11 finished with value: 330227.13619820395 and parameters: {'n_estimators': 1315, 'max_depth': 4, 'learning_rate': 0.08038632530239519, 'subsample': 0.5285909628431712, 'colsample_bytree': 0.9747491905880856, 'reg_alpha': 0.06296308757965059, 'reg_lambda': 0.3879188870590936}. Best is trial 0 with value: 308957.7638150155.
# [I 2026-04-27 21:11:31,768] Trial 12 finished with value: 302293.44653477473 and parameters: {'n_estimators': 763, 'max_depth': 3, 'learning_rate': 0.061080556114322296, 'subsample': 0.6467045372980378, 'colsample_bytree': 0.966679312068714, 'reg_alpha': 0.4773886153984328, 'reg_lambda': 2.6099966764036324}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:32,098] Trial 13 finished with value: 315258.39512209943 and parameters: {'n_estimators': 550, 'max_depth': 3, 'learning_rate': 0.052206708201815534, 'subsample': 0.6773640891400906, 'colsample_bytree': 0.890034914192715, 'reg_alpha': 0.8136444082564878, 'reg_lambda': 9.114882513756601}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:33,071] Trial 14 finished with value: 318119.2289026098 and parameters: {'n_estimators': 735, 'max_depth': 5, 'learning_rate': 0.039950562605755045, 'subsample': 0.6427525747526631, 'colsample_bytree': 0.6916349527475608, 'reg_alpha': 5.418140502396309, 'reg_lambda': 1.9063073613741581}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:33,828] Trial 15 finished with value: 307428.96618375607 and parameters: {'n_estimators': 1150, 'max_depth': 3, 'learning_rate': 0.0617542681447023, 'subsample': 0.8410356201449607, 'colsample_bytree': 0.5906463283158285, 'reg_alpha': 0.338918813099581, 'reg_lambda': 0.001039026994395425}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:36,001] Trial 16 finished with value: 316798.4938030692 and parameters: {'n_estimators': 1949, 'max_depth': 5, 'learning_rate': 0.06457043337608194, 'subsample': 0.7155378609027183, 'colsample_bytree': 0.7210061502249283, 'reg_alpha': 0.019513389723054497, 'reg_lambda': 0.0011422863662418035}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:37,467] Trial 17 finished with value: 321511.22864223685 and parameters: {'n_estimators': 1202, 'max_depth': 5, 'learning_rate': 0.06603165623931788, 'subsample': 0.9092766603512071, 'colsample_bytree': 0.9059453759556704, 'reg_alpha': 0.3184428520368769, 'reg_lambda': 1.5250957113640309}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:40,530] Trial 18 finished with value: 355830.83518424217 and parameters: {'n_estimators': 1466, 'max_depth': 7, 'learning_rate': 0.09695124650956465, 'subsample': 0.796379901909042, 'colsample_bytree': 0.5126054156706576, 'reg_alpha': 2.778689693970946, 'reg_lambda': 0.002650391449216038}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:41,002] Trial 19 finished with value: 336932.02658387815 and parameters: {'n_estimators': 766, 'max_depth': 3, 'learning_rate': 0.018078407473728075, 'subsample': 0.9908208685736061, 'colsample_bytree': 0.5812557483667659, 'reg_alpha': 0.037902747863620724, 'reg_lambda': 1.4115560500971143}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:42,040] Trial 20 finished with value: 319522.7179377371 and parameters: {'n_estimators': 1182, 'max_depth': 4, 'learning_rate': 0.059060197231715544, 'subsample': 0.644245488443315, 'colsample_bytree': 0.7416911719073138, 'reg_alpha': 0.3046969683763064, 'reg_lambda': 0.006058522702699361}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:42,681] Trial 21 finished with value: 315032.0542214708 and parameters: {'n_estimators': 877, 'max_depth': 3, 'learning_rate': 0.04260720304861123, 'subsample': 0.8350973583535924, 'colsample_bytree': 0.5732703714492413, 'reg_alpha': 0.3944457383686798, 'reg_lambda': 0.154037856666257}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:43,670] Trial 22 finished with value: 310187.3294403199 and parameters: {'n_estimators': 1120, 'max_depth': 3, 'learning_rate': 0.03546956470425702, 'subsample': 0.817301100442402, 'colsample_bytree': 0.6108771296388741, 'reg_alpha': 2.588105432073702, 'reg_lambda': 0.024504474380100165}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:44,968] Trial 23 finished with value: 328521.12447809434 and parameters: {'n_estimators': 843, 'max_depth': 4, 'learning_rate': 0.07585493864068346, 'subsample': 0.8761622723162124, 'colsample_bytree': 0.9944104519255141, 'reg_alpha': 0.45720894464988393, 'reg_lambda': 0.8482301875767763}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:46,291] Trial 24 finished with value: 324195.1538129306 and parameters: {'n_estimators': 652, 'max_depth': 5, 'learning_rate': 0.054067059631513745, 'subsample': 0.7252731663550153, 'colsample_bytree': 0.6914918139094514, 'reg_alpha': 0.18274238301882506, 'reg_lambda': 0.08349986619403488}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:47,409] Trial 25 finished with value: 311424.03101781185 and parameters: {'n_estimators': 1526, 'max_depth': 3, 'learning_rate': 0.07902878403859025, 'subsample': 0.7684663791250792, 'colsample_bytree': 0.5434826531198411, 'reg_alpha': 1.9944536060376485, 'reg_lambda': 6.697167661459998}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:48,055] Trial 26 finished with value: 326961.0046170223 and parameters: {'n_estimators': 801, 'max_depth': 4, 'learning_rate': 0.039566848744136046, 'subsample': 0.8110962419047827, 'colsample_bytree': 0.5949632979600782, 'reg_alpha': 0.6367241207045448, 'reg_lambda': 3.282399923721207}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:50,762] Trial 27 finished with value: 346956.8115683468 and parameters: {'n_estimators': 1292, 'max_depth': 6, 'learning_rate': 0.057256960570599154, 'subsample': 0.9002398025848957, 'colsample_bytree': 0.6252927421893714, 'reg_alpha': 0.0332953726831821, 'reg_lambda': 0.03375357544206561}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:51,319] Trial 28 finished with value: 308348.5328505373 and parameters: {'n_estimators': 502, 'max_depth': 3, 'learning_rate': 0.046927530246703514, 'subsample': 0.6715153469047032, 'colsample_bytree': 0.7925076969217842, 'reg_alpha': 0.2419001277086077, 'reg_lambda': 0.0012171973552795718}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:51,868] Trial 29 finished with value: 307322.0032011541 and parameters: {'n_estimators': 548, 'max_depth': 3, 'learning_rate': 0.044564268057560405, 'subsample': 0.6005949196211724, 'colsample_bytree': 0.8730334049419692, 'reg_alpha': 0.2395290988899289, 'reg_lambda': 0.001282429268414669}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:53,031] Trial 30 finished with value: 313642.6532106072 and parameters: {'n_estimators': 624, 'max_depth': 5, 'learning_rate': 0.020899377301129812, 'subsample': 0.5767186109945259, 'colsample_bytree': 0.914092433601641, 'reg_alpha': 0.05959548709635333, 'reg_lambda': 0.002426176292636336}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:53,593] Trial 31 finished with value: 314235.13296587556 and parameters: {'n_estimators': 535, 'max_depth': 3, 'learning_rate': 0.04375318747346537, 'subsample': 0.6397244390918058, 'colsample_bytree': 0.8510816562975698, 'reg_alpha': 0.19140519149527896, 'reg_lambda': 0.0011591001739424834}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:54,358] Trial 32 finished with value: 310461.0795842303 and parameters: {'n_estimators': 506, 'max_depth': 4, 'learning_rate': 0.030933493816995002, 'subsample': 0.6082132242574377, 'colsample_bytree': 0.8047812830749237, 'reg_alpha': 1.3551311733781461, 'reg_lambda': 0.005309603479658379}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:55,145] Trial 33 finished with value: 306013.20872242603 and parameters: {'n_estimators': 662, 'max_depth': 3, 'learning_rate': 0.049813022712726446, 'subsample': 0.6803931830301407, 'colsample_bytree': 0.8597673922842239, 'reg_alpha': 0.2598256716003276, 'reg_lambda': 0.001605513780992842}. Best is trial 12 with value: 302293.44653477473.
# [I 2026-04-27 21:11:55,634] Trial 34 finished with value: 297174.9058208744 and parameters: {'n_estimators': 686, 'max_depth': 3, 'learning_rate': 0.06078396827309274, 'subsample': 0.5588316905030621, 'colsample_bytree': 0.857727631111468, 'reg_alpha': 0.578580318509212, 'reg_lambda': 0.005388345443197518}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:11:56,227] Trial 35 finished with value: 302124.4403053552 and parameters: {'n_estimators': 668, 'max_depth': 4, 'learning_rate': 0.03674056627423533, 'subsample': 0.5310753709578977, 'colsample_bytree': 0.8464740677486138, 'reg_alpha': 0.5566847937143491, 'reg_lambda': 0.005008164655708313}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:11:56,908] Trial 36 finished with value: 303200.6310416259 and parameters: {'n_estimators': 677, 'max_depth': 4, 'learning_rate': 0.036387237759794064, 'subsample': 0.5398183381793561, 'colsample_bytree': 0.8373249036907957, 'reg_alpha': 1.8027896130462746, 'reg_lambda': 0.009703316558194766}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:11:59,490] Trial 37 finished with value: 323118.4633235102 and parameters: {'n_estimators': 943, 'max_depth': 7, 'learning_rate': 0.024175905290070854, 'subsample': 0.5457721290408488, 'colsample_bytree': 0.9357815525914795, 'reg_alpha': 4.558827104412237, 'reg_lambda': 0.010090337092809754}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:00,215] Trial 38 finished with value: 309237.89956879226 and parameters: {'n_estimators': 705, 'max_depth': 4, 'learning_rate': 0.02909641173477333, 'subsample': 0.5014777394663262, 'colsample_bytree': 0.8231335621581152, 'reg_alpha': 1.315094551508643, 'reg_lambda': 0.006711809812880852}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:05,754] Trial 39 finished with value: 344948.65506923856 and parameters: {'n_estimators': 794, 'max_depth': 9, 'learning_rate': 0.011661522042778084, 'subsample': 0.5596990373852725, 'colsample_bytree': 0.8287505064412442, 'reg_alpha': 0.6632195208716094, 'reg_lambda': 0.010857884205198582}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:07,040] Trial 40 finished with value: 309383.34673741076 and parameters: {'n_estimators': 1000, 'max_depth': 4, 'learning_rate': 0.03387742768138068, 'subsample': 0.5335531228999814, 'colsample_bytree': 0.7771985730114206, 'reg_alpha': 8.355762799585007, 'reg_lambda': 0.016985144446079986}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:07,767] Trial 41 finished with value: 306626.6601775744 and parameters: {'n_estimators': 677, 'max_depth': 3, 'learning_rate': 0.03840828134536944, 'subsample': 0.5673362641731802, 'colsample_bytree': 0.8518691510519019, 'reg_alpha': 0.5369887815178536, 'reg_lambda': 0.0029765639721251133}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:08,866] Trial 42 finished with value: 312154.83805585373 and parameters: {'n_estimators': 629, 'max_depth': 4, 'learning_rate': 0.07195614643212676, 'subsample': 0.6204282308655779, 'colsample_bytree': 0.9523546705850463, 'reg_alpha': 1.5476497650993473, 'reg_lambda': 0.0035907145328723388}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:10,158] Trial 43 finished with value: 315310.707455655 and parameters: {'n_estimators': 896, 'max_depth': 4, 'learning_rate': 0.05038528912670756, 'subsample': 0.5020610263703275, 'colsample_bytree': 0.8686266162455336, 'reg_alpha': 0.10187100213411475, 'reg_lambda': 0.0018692791511295726}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:11,003] Trial 44 finished with value: 306217.98194091255 and parameters: {'n_estimators': 717, 'max_depth': 3, 'learning_rate': 0.03679198737489805, 'subsample': 0.6862663425046883, 'colsample_bytree': 0.9100313268370265, 'reg_alpha': 0.7737162723135812, 'reg_lambda': 0.004459798466626597}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:12,156] Trial 45 finished with value: 320586.0691400366 and parameters: {'n_estimators': 618, 'max_depth': 5, 'learning_rate': 0.054159132747428486, 'subsample': 0.5828093811934564, 'colsample_bytree': 0.8738331880791429, 'reg_alpha': 0.9375725116366566, 'reg_lambda': 0.007799837842233459}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:12,965] Trial 46 finished with value: 306170.15408781753 and parameters: {'n_estimators': 812, 'max_depth': 3, 'learning_rate': 0.08899141484721693, 'subsample': 0.7383247321144842, 'colsample_bytree': 0.7751540078931979, 'reg_alpha': 3.496362232151207, 'reg_lambda': 0.04159549272630353}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:14,552] Trial 47 finished with value: 306099.80862702616 and parameters: {'n_estimators': 1048, 'max_depth': 4, 'learning_rate': 0.02574275757639371, 'subsample': 0.5476672975958341, 'colsample_bytree': 0.8341833369276591, 'reg_alpha': 0.1320846352500937, 'reg_lambda': 0.01658964822451841}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:20,255] Trial 48 finished with value: 358775.0709608497 and parameters: {'n_estimators': 921, 'max_depth': 10, 'learning_rate': 0.05009121741787939, 'subsample': 0.6178489896780921, 'colsample_bytree': 0.9548103229890292, 'reg_alpha': 1.9117775602407097, 'reg_lambda': 0.31887145147735035}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:21,005] Trial 49 finished with value: 303419.3851860456 and parameters: {'n_estimators': 592, 'max_depth': 5, 'learning_rate': 0.02957764557178541, 'subsample': 0.5212580685454022, 'colsample_bytree': 0.927913791942616, 'reg_alpha': 0.46717964047311755, 'reg_lambda': 0.0016373029261183755}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:22,395] Trial 50 finished with value: 319579.5040668077 and parameters: {'n_estimators': 747, 'max_depth': 6, 'learning_rate': 0.021350965393663685, 'subsample': 0.5195003902313249, 'colsample_bytree': 0.9273387426371573, 'reg_alpha': 1.1501575232475554, 'reg_lambda': 0.004122362912611774}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:23,112] Trial 51 finished with value: 305030.8601615583 and parameters: {'n_estimators': 591, 'max_depth': 5, 'learning_rate': 0.028394118715270835, 'subsample': 0.5869565798184049, 'colsample_bytree': 0.9719679261081472, 'reg_alpha': 0.4284927259594752, 'reg_lambda': 0.0019153617093712533}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:23,800] Trial 52 finished with value: 305012.9347531692 and parameters: {'n_estimators': 585, 'max_depth': 5, 'learning_rate': 0.0294134255945937, 'subsample': 0.5884868043191535, 'colsample_bytree': 0.9987191057737482, 'reg_alpha': 0.9246703982516529, 'reg_lambda': 0.0021649086038723155}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:25,040] Trial 53 finished with value: 314156.4754269205 and parameters: {'n_estimators': 580, 'max_depth': 5, 'learning_rate': 0.031182912373015147, 'subsample': 0.5547627474870725, 'colsample_bytree': 0.9960480236813881, 'reg_alpha': 0.8924457823417236, 'reg_lambda': 0.002323914787480466}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:25,716] Trial 54 finished with value: 308618.9951093664 and parameters: {'n_estimators': 697, 'max_depth': 4, 'learning_rate': 0.017084064561430773, 'subsample': 0.5230097795766078, 'colsample_bytree': 0.8905305607563714, 'reg_alpha': 0.550564870638461, 'reg_lambda': 0.009021272526626585}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:26,723] Trial 55 finished with value: 308822.8336876506 and parameters: {'n_estimators': 837, 'max_depth': 5, 'learning_rate': 0.02265272435679336, 'subsample': 0.5363812796049877, 'colsample_bytree': 0.9737790344712136, 'reg_alpha': 2.100532405594821, 'reg_lambda': 0.004046759013134245}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:28,002] Trial 56 finished with value: 330452.22007816983 and parameters: {'n_estimators': 754, 'max_depth': 6, 'learning_rate': 0.03236247248666777, 'subsample': 0.5666315965740487, 'colsample_bytree': 0.8877444163100502, 'reg_alpha': 3.834889105281464, 'reg_lambda': 0.0058829312341791284}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:29,301] Trial 57 finished with value: 327152.2930879942 and parameters: {'n_estimators': 601, 'max_depth': 7, 'learning_rate': 0.027424355414078387, 'subsample': 0.514770137485852, 'colsample_bytree': 0.9291033558748002, 'reg_alpha': 0.0059432145298163215, 'reg_lambda': 0.013931798817045668}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:30,066] Trial 58 finished with value: 318380.0333186581 and parameters: {'n_estimators': 671, 'max_depth': 5, 'learning_rate': 0.015525561974479251, 'subsample': 0.6353699113788782, 'colsample_bytree': 0.9541179021090672, 'reg_alpha': 0.35063130406769344, 'reg_lambda': 0.5879279624879487}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:31,595] Trial 59 finished with value: 316106.5164617051 and parameters: {'n_estimators': 1650, 'max_depth': 4, 'learning_rate': 0.0417973598761489, 'subsample': 0.5904736359989408, 'colsample_bytree': 0.97666425675523, 'reg_alpha': 1.5774772870503735, 'reg_lambda': 0.021423347274813282}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:32,970] Trial 60 finished with value: 319110.2041144578 and parameters: {'n_estimators': 852, 'max_depth': 6, 'learning_rate': 0.0696029091444687, 'subsample': 0.5407780069365091, 'colsample_bytree': 0.8988370076493967, 'reg_alpha': 2.902747286462082, 'reg_lambda': 0.2019790595212555}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:33,578] Trial 61 finished with value: 306106.14568724803 and parameters: {'n_estimators': 567, 'max_depth': 5, 'learning_rate': 0.02941163306900527, 'subsample': 0.588767035434433, 'colsample_bytree': 0.9823115212785153, 'reg_alpha': 0.4278058828819277, 'reg_lambda': 0.0017830479761991867}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:34,268] Trial 62 finished with value: 311694.3982797578 and parameters: {'n_estimators': 587, 'max_depth': 5, 'learning_rate': 0.035851244921953185, 'subsample': 0.6634515563405817, 'colsample_bytree': 0.9675038152316483, 'reg_alpha': 0.7320053714705425, 'reg_lambda': 0.0031175264269322337}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:34,897] Trial 63 finished with value: 313705.83831468 and parameters: {'n_estimators': 500, 'max_depth': 5, 'learning_rate': 0.028340139646546147, 'subsample': 0.5718685684488445, 'colsample_bytree': 0.9998874389725205, 'reg_alpha': 0.46465367128980745, 'reg_lambda': 0.0020299641766664146}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:35,513] Trial 64 finished with value: 305031.2817840289 and parameters: {'n_estimators': 765, 'max_depth': 4, 'learning_rate': 0.02467965785130987, 'subsample': 0.6216273552951933, 'colsample_bytree': 0.9345470898994315, 'reg_alpha': 0.180421287188927, 'reg_lambda': 0.0016862769442180649}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:36,561] Trial 65 finished with value: 320019.41577676655 and parameters: {'n_estimators': 642, 'max_depth': 6, 'learning_rate': 0.08636281150127975, 'subsample': 0.5567385350576423, 'colsample_bytree': 0.9186420569122524, 'reg_alpha': 0.07167427538125397, 'reg_lambda': 0.005220337571442479}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:37,013] Trial 66 finished with value: 299994.2896464763 and parameters: {'n_estimators': 722, 'max_depth': 3, 'learning_rate': 0.05902821366788806, 'subsample': 0.598251775368529, 'colsample_bytree': 0.9634445649139814, 'reg_alpha': 1.0548662042406471, 'reg_lambda': 0.0027971745955939482}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:37,922] Trial 67 finished with value: 298952.82213041506 and parameters: {'n_estimators': 1384, 'max_depth': 3, 'learning_rate': 0.06232091510817812, 'subsample': 0.604894869374021, 'colsample_bytree': 0.9427530441674932, 'reg_alpha': 1.0778081899052006, 'reg_lambda': 0.0026728400299938213}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:39,289] Trial 68 finished with value: 302499.7763780712 and parameters: {'n_estimators': 1428, 'max_depth': 3, 'learning_rate': 0.06264708909981562, 'subsample': 0.658414261036248, 'colsample_bytree': 0.9488992059913096, 'reg_alpha': 0.0020874478011856734, 'reg_lambda': 0.07270592316018847}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:40,170] Trial 69 finished with value: 298387.741013104 and parameters: {'n_estimators': 1392, 'max_depth': 3, 'learning_rate': 0.06236993868779315, 'subsample': 0.6120135169298415, 'colsample_bytree': 0.8156831938689244, 'reg_alpha': 0.002070199847829737, 'reg_lambda': 2.6351531835750275}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:41,422] Trial 70 finished with value: 304229.29965915467 and parameters: {'n_estimators': 1395, 'max_depth': 3, 'learning_rate': 0.06241669816049138, 'subsample': 0.6651632627464469, 'colsample_bytree': 0.733512546443123, 'reg_alpha': 0.0018980009825880475, 'reg_lambda': 2.4644011400506445}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:42,215] Trial 71 finished with value: 300709.62707377516 and parameters: {'n_estimators': 1391, 'max_depth': 3, 'learning_rate': 0.05705811691853909, 'subsample': 0.628141316003755, 'colsample_bytree': 0.8018279369957438, 'reg_alpha': 0.0030977038458069716, 'reg_lambda': 1.0423675299140374}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:43,349] Trial 72 finished with value: 307203.93557147647 and parameters: {'n_estimators': 1383, 'max_depth': 3, 'learning_rate': 0.06087074173507006, 'subsample': 0.7042852153903767, 'colsample_bytree': 0.8096375004496424, 'reg_alpha': 0.001809836250200039, 'reg_lambda': 0.918539477675121}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:44,351] Trial 73 finished with value: 301358.87273942126 and parameters: {'n_estimators': 1528, 'max_depth': 3, 'learning_rate': 0.05690323652914015, 'subsample': 0.6534315997713513, 'colsample_bytree': 0.790921073980823, 'reg_alpha': 0.005121991900421892, 'reg_lambda': 4.088356246815667}. Best is trial 34 with value: 297174.9058208744.
# [I 2026-04-27 21:12:45,330] Trial 74 finished with value: 292644.69709184737 and parameters: {'n_estimators': 1511, 'max_depth': 3, 'learning_rate': 0.05738215859368015, 'subsample': 0.6098349570974388, 'colsample_bytree': 0.769850452751978, 'reg_alpha': 0.005195434424610817, 'reg_lambda': 4.329743824286871}. Best is trial 74 with value: 292644.69709184737.
# [I 2026-04-27 21:12:46,768] Trial 75 finished with value: 302540.2111800895 and parameters: {'n_estimators': 1639, 'max_depth': 3, 'learning_rate': 0.05621022810011293, 'subsample': 0.6041295676393126, 'colsample_bytree': 0.7741774922436782, 'reg_alpha': 0.005731471961235533, 'reg_lambda': 4.132785375461551}. Best is trial 74 with value: 292644.69709184737.
# [I 2026-04-27 21:12:47,722] Trial 76 finished with value: 306639.25036784064 and parameters: {'n_estimators': 1564, 'max_depth': 3, 'learning_rate': 0.07392469189484592, 'subsample': 0.6249891428078416, 'colsample_bytree': 0.7897227172213315, 'reg_alpha': 0.0034652508734549447, 'reg_lambda': 6.959016429921496}. Best is trial 74 with value: 292644.69709184737.
# [I 2026-04-27 21:12:48,455] Trial 77 finished with value: 308549.79778462683 and parameters: {'n_estimators': 1237, 'max_depth': 3, 'learning_rate': 0.046238670965775115, 'subsample': 0.6535166856164539, 'colsample_bytree': 0.7581787882811306, 'reg_alpha': 0.015187963553072127, 'reg_lambda': 5.652822269108511}. Best is trial 74 with value: 292644.69709184737.
# [I 2026-04-27 21:12:49,361] Trial 78 finished with value: 314514.91153252363 and parameters: {'n_estimators': 1486, 'max_depth': 3, 'learning_rate': 0.066580478258122, 'subsample': 0.6969079124783187, 'colsample_bytree': 0.7067978462057121, 'reg_alpha': 0.0012076716819946585, 'reg_lambda': 2.085982781094407}. Best is trial 74 with value: 292644.69709184737.
# [I 2026-04-27 21:12:50,209] Trial 79 finished with value: 307688.0340188523 and parameters: {'n_estimators': 1348, 'max_depth': 3, 'learning_rate': 0.07863128615744881, 'subsample': 0.6351210811050044, 'colsample_bytree': 0.8170838588272051, 'reg_alpha': 0.00995924423359716, 'reg_lambda': 9.202643644375927}. Best is trial 74 with value: 292644.69709184737.
# [I 2026-04-27 21:12:51,256] Trial 80 finished with value: 292293.49670542264 and parameters: {'n_estimators': 1592, 'max_depth': 3, 'learning_rate': 0.05776544005163415, 'subsample': 0.6073404316526829, 'colsample_bytree': 0.8027547587658374, 'reg_alpha': 0.0034289934216635864, 'reg_lambda': 2.861487892727415}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:12:52,239] Trial 81 finished with value: 304930.8922919469 and parameters: {'n_estimators': 1551, 'max_depth': 3, 'learning_rate': 0.05806851995247442, 'subsample': 0.6074458874325155, 'colsample_bytree': 0.7990405939374833, 'reg_alpha': 0.0034876418586601444, 'reg_lambda': 3.596175295104098}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:12:53,645] Trial 82 finished with value: 301357.73970719235 and parameters: {'n_estimators': 1615, 'max_depth': 3, 'learning_rate': 0.053232394198132284, 'subsample': 0.6140171428322262, 'colsample_bytree': 0.75890998457243, 'reg_alpha': 0.0024893419732527782, 'reg_lambda': 1.2228228162402106}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:12:54,824] Trial 83 finished with value: 299358.8369463054 and parameters: {'n_estimators': 1634, 'max_depth': 3, 'learning_rate': 0.05350156213454173, 'subsample': 0.6027378867558987, 'colsample_bytree': 0.7646049313940045, 'reg_alpha': 0.00250873272556413, 'reg_lambda': 1.37079975410702}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:12:56,259] Trial 84 finished with value: 304690.9071753588 and parameters: {'n_estimators': 1626, 'max_depth': 3, 'learning_rate': 0.05392107539197314, 'subsample': 0.599145041978832, 'colsample_bytree': 0.7596434219380357, 'reg_alpha': 0.0026187561446044333, 'reg_lambda': 1.157857988572235}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:12:57,492] Trial 85 finished with value: 305502.7457352863 and parameters: {'n_estimators': 1737, 'max_depth': 3, 'learning_rate': 0.0695711369194313, 'subsample': 0.610617830553698, 'colsample_bytree': 0.7395219758935854, 'reg_alpha': 0.001500813740302861, 'reg_lambda': 1.522215091800278}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:12:58,657] Trial 86 finished with value: 300295.8180694682 and parameters: {'n_estimators': 1714, 'max_depth': 3, 'learning_rate': 0.047073256910762355, 'subsample': 0.6345230241809556, 'colsample_bytree': 0.7508180983596362, 'reg_alpha': 0.004566624581993781, 'reg_lambda': 0.6139972818763917}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:00,517] Trial 87 finished with value: 299574.12569948944 and parameters: {'n_estimators': 1747, 'max_depth': 3, 'learning_rate': 0.047965888706716905, 'subsample': 0.6316698272743896, 'colsample_bytree': 0.7185575548709093, 'reg_alpha': 0.0010158150555622696, 'reg_lambda': 0.6135924314074054}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:02,046] Trial 88 finished with value: 295363.97888219275 and parameters: {'n_estimators': 1861, 'max_depth': 3, 'learning_rate': 0.04649638117157394, 'subsample': 0.642300553578337, 'colsample_bytree': 0.7226525886565154, 'reg_alpha': 0.004572114334347376, 'reg_lambda': 2.4507252457421913}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:03,175] Trial 89 finished with value: 300191.41990323894 and parameters: {'n_estimators': 1870, 'max_depth': 3, 'learning_rate': 0.06468427431937328, 'subsample': 0.5768381107143898, 'colsample_bytree': 0.692212897139738, 'reg_alpha': 0.008708384334662055, 'reg_lambda': 2.883031292664509}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:04,887] Trial 90 finished with value: 300213.46171835135 and parameters: {'n_estimators': 1814, 'max_depth': 4, 'learning_rate': 0.04814408642715595, 'subsample': 0.5966173093813638, 'colsample_bytree': 0.7075823053107739, 'reg_alpha': 0.0010271265904048452, 'reg_lambda': 2.0738445538943635}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:06,074] Trial 91 finished with value: 308388.34562499553 and parameters: {'n_estimators': 1869, 'max_depth': 3, 'learning_rate': 0.06710775969303619, 'subsample': 0.5783439050428791, 'colsample_bytree': 0.6725011266550386, 'reg_alpha': 0.008234737004073251, 'reg_lambda': 2.7123893193351067}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:07,209] Trial 92 finished with value: 314547.78122977965 and parameters: {'n_estimators': 2000, 'max_depth': 3, 'learning_rate': 0.06474985753646946, 'subsample': 0.6479066459232476, 'colsample_bytree': 0.6703081894430061, 'reg_alpha': 0.001505161402401985, 'reg_lambda': 3.187332594544385}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:08,384] Trial 93 finished with value: 301327.9000239136 and parameters: {'n_estimators': 1829, 'max_depth': 3, 'learning_rate': 0.05275919948026256, 'subsample': 0.5662668867389936, 'colsample_bytree': 0.724129024624875, 'reg_alpha': 0.003876325698874397, 'reg_lambda': 1.7032069459451549}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:10,186] Trial 94 finished with value: 298481.31995720475 and parameters: {'n_estimators': 1921, 'max_depth': 3, 'learning_rate': 0.06124938654668837, 'subsample': 0.6149245929128432, 'colsample_bytree': 0.6452266568842877, 'reg_alpha': 0.012181059712552235, 'reg_lambda': 4.921957904701015}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:11,903] Trial 95 finished with value: 300211.6838849393 and parameters: {'n_estimators': 1689, 'max_depth': 3, 'learning_rate': 0.04174980112042539, 'subsample': 0.5980180925664356, 'colsample_bytree': 0.5541457855179803, 'reg_alpha': 0.006417706578442683, 'reg_lambda': 5.132859493792731}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:20,162] Trial 96 finished with value: 373334.2358920612 and parameters: {'n_estimators': 1461, 'max_depth': 9, 'learning_rate': 0.0509369966297404, 'subsample': 0.6147532149484695, 'colsample_bytree': 0.7690939768697849, 'reg_alpha': 0.012656873746860503, 'reg_lambda': 0.7016682150155246}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:22,070] Trial 97 finished with value: 325822.7807507692 and parameters: {'n_estimators': 1918, 'max_depth': 4, 'learning_rate': 0.05951385061271486, 'subsample': 0.6779100950674021, 'colsample_bytree': 0.6440693722800689, 'reg_alpha': 0.027193742634718594, 'reg_lambda': 7.847089317932378}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:23,019] Trial 98 finished with value: 303719.91649202246 and parameters: {'n_estimators': 1280, 'max_depth': 3, 'learning_rate': 0.043974756511976104, 'subsample': 0.6456517584992826, 'colsample_bytree': 0.8188375232850342, 'reg_alpha': 0.0027176878514434655, 'reg_lambda': 4.258330901963751}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:24,622] Trial 99 finished with value: 318474.246006797 and parameters: {'n_estimators': 1766, 'max_depth': 4, 'learning_rate': 0.0735005303782686, 'subsample': 0.6220559976628421, 'colsample_bytree': 0.7201293977069387, 'reg_alpha': 0.003981956479381953, 'reg_lambda': 2.349353113071216}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:25,662] Trial 100 finished with value: 308952.7584781573 and parameters: {'n_estimators': 1590, 'max_depth': 3, 'learning_rate': 0.06001932414201696, 'subsample': 0.5519766095508546, 'colsample_bytree': 0.623165858613749, 'reg_alpha': 0.0014238190369201989, 'reg_lambda': 5.498305124020718}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:27,031] Trial 101 finished with value: 305082.9269238118 and parameters: {'n_estimators': 1880, 'max_depth': 3, 'learning_rate': 0.0634763839905204, 'subsample': 0.5745584139566376, 'colsample_bytree': 0.6830713342067258, 'reg_alpha': 0.009327887168318356, 'reg_lambda': 2.9274022704116147}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:28,319] Trial 102 finished with value: 308801.46459654364 and parameters: {'n_estimators': 1962, 'max_depth': 3, 'learning_rate': 0.08242350127332504, 'subsample': 0.5859932549568004, 'colsample_bytree': 0.7007979882089552, 'reg_alpha': 0.00446812975507225, 'reg_lambda': 3.4633209896188}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:29,528] Trial 103 finished with value: 298346.81862967176 and parameters: {'n_estimators': 1805, 'max_depth': 3, 'learning_rate': 0.055121060457709856, 'subsample': 0.6055015108369882, 'colsample_bytree': 0.785473634918124, 'reg_alpha': 0.007089865886653398, 'reg_lambda': 1.7949632935032525}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:30,771] Trial 104 finished with value: 304729.9938392392 and parameters: {'n_estimators': 1798, 'max_depth': 3, 'learning_rate': 0.054769856638271185, 'subsample': 0.6316072885181775, 'colsample_bytree': 0.7835446461431667, 'reg_alpha': 0.007032115240948116, 'reg_lambda': 1.8628999361971983}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:31,997] Trial 105 finished with value: 297904.76028861507 and parameters: {'n_estimators': 1769, 'max_depth': 3, 'learning_rate': 0.0512352560940878, 'subsample': 0.607255445348574, 'colsample_bytree': 0.8426754968586095, 'reg_alpha': 0.002020047525853052, 'reg_lambda': 1.5438286028218642}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:33,176] Trial 106 finished with value: 295214.114458372 and parameters: {'n_estimators': 1669, 'max_depth': 3, 'learning_rate': 0.04948488595958615, 'subsample': 0.6092634521064869, 'colsample_bytree': 0.8305742773900006, 'reg_alpha': 0.002286002663349711, 'reg_lambda': 1.2471301385010676}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:39,487] Trial 107 finished with value: 357258.3009516226 and parameters: {'n_estimators': 1683, 'max_depth': 8, 'learning_rate': 0.06995019427539934, 'subsample': 0.6077403926643566, 'colsample_bytree': 0.8431715548450668, 'reg_alpha': 0.002082970359205771, 'reg_lambda': 1.3740514188140913}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:41,318] Trial 108 finished with value: 325474.55794477934 and parameters: {'n_estimators': 1840, 'max_depth': 4, 'learning_rate': 0.0516582892551706, 'subsample': 0.5614389176970533, 'colsample_bytree': 0.8294838651473039, 'reg_alpha': 0.0029014103751465697, 'reg_lambda': 0.46244291198623505}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:42,425] Trial 109 finished with value: 299835.5236774023 and parameters: {'n_estimators': 1488, 'max_depth': 3, 'learning_rate': 0.05626858997855888, 'subsample': 0.6418250262417303, 'colsample_bytree': 0.866869717299142, 'reg_alpha': 0.002382523045440429, 'reg_lambda': 0.8602491161701883}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:44,171] Trial 110 finished with value: 315325.7250332407 and parameters: {'n_estimators': 1699, 'max_depth': 4, 'learning_rate': 0.045345394632950634, 'subsample': 0.6145656411360914, 'colsample_bytree': 0.8395382826997038, 'reg_alpha': 0.0016876979316614534, 'reg_lambda': 1.7684844414767564}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:45,533] Trial 111 finished with value: 299287.6780187393 and parameters: {'n_estimators': 1771, 'max_depth': 3, 'learning_rate': 0.050585604355946494, 'subsample': 0.6272908069404739, 'colsample_bytree': 0.8115518756498977, 'reg_alpha': 0.0011294647730687693, 'reg_lambda': 2.1268777679868287}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:46,847] Trial 112 finished with value: 293793.1073089964 and parameters: {'n_estimators': 1789, 'max_depth': 3, 'learning_rate': 0.049572693362049905, 'subsample': 0.5913562033444427, 'colsample_bytree': 0.8589408986335301, 'reg_alpha': 0.0012718388615382287, 'reg_lambda': 2.3521451244981177}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:48,210] Trial 113 finished with value: 295198.61267324275 and parameters: {'n_estimators': 1909, 'max_depth': 3, 'learning_rate': 0.04879920205387758, 'subsample': 0.5905503441496134, 'colsample_bytree': 0.856721771189377, 'reg_alpha': 0.001195611459185778, 'reg_lambda': 2.3668285418610666}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:49,895] Trial 114 finished with value: 300352.9652918879 and parameters: {'n_estimators': 1919, 'max_depth': 3, 'learning_rate': 0.04945326906662057, 'subsample': 0.5853734581116756, 'colsample_bytree': 0.8600989013287732, 'reg_alpha': 0.0012328239902989636, 'reg_lambda': 6.590119479997267}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:51,624] Trial 115 finished with value: 297454.6406440124 and parameters: {'n_estimators': 1905, 'max_depth': 3, 'learning_rate': 0.038385472207831235, 'subsample': 0.5926815437805041, 'colsample_bytree': 0.8796580878547903, 'reg_alpha': 0.004809067839722004, 'reg_lambda': 4.513426789204961}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:53,224] Trial 116 finished with value: 300542.3419393668 and parameters: {'n_estimators': 1979, 'max_depth': 3, 'learning_rate': 0.040621244444323086, 'subsample': 0.5916732408766902, 'colsample_bytree': 0.8849316846383306, 'reg_alpha': 0.005105861279488292, 'reg_lambda': 4.548717019771855}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:54,646] Trial 117 finished with value: 292463.8282645033 and parameters: {'n_estimators': 1930, 'max_depth': 3, 'learning_rate': 0.042996766499131575, 'subsample': 0.5816500390959842, 'colsample_bytree': 0.8489689405263973, 'reg_alpha': 0.010889068768851214, 'reg_lambda': 3.490475613833471}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:55,950] Trial 118 finished with value: 304934.10301100014 and parameters: {'n_estimators': 1865, 'max_depth': 3, 'learning_rate': 0.04309766598977805, 'subsample': 0.9487969771523556, 'colsample_bytree': 0.8565456725383073, 'reg_alpha': 0.002183196872565631, 'reg_lambda': 3.6236250378560406}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:58,101] Trial 119 finished with value: 316607.01250721724 and parameters: {'n_estimators': 1896, 'max_depth': 4, 'learning_rate': 0.039242117297693835, 'subsample': 0.5744586641825254, 'colsample_bytree': 0.8763140233539654, 'reg_alpha': 0.007058720125582456, 'reg_lambda': 2.6119267185875525}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:13:59,425] Trial 120 finished with value: 304760.8090006076 and parameters: {'n_estimators': 1796, 'max_depth': 3, 'learning_rate': 0.038140968559730086, 'subsample': 0.5469063715812332, 'colsample_bytree': 0.8229234572082874, 'reg_alpha': 0.0036735987431076225, 'reg_lambda': 0.12954918891133196}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:14:01,016] Trial 121 finished with value: 294851.89370647166 and parameters: {'n_estimators': 1930, 'max_depth': 3, 'learning_rate': 0.045443641658998, 'subsample': 0.5918898456166585, 'colsample_bytree': 0.8461442413726721, 'reg_alpha': 0.019130023820400587, 'reg_lambda': 6.550205122697641}. Best is trial 80 with value: 292293.49670542264.
# [I 2026-04-27 21:14:02,917] Trial 122 finished with value: 291360.2606624697 and parameters: {'n_estimators': 1945, 'max_depth': 3, 'learning_rate': 0.04516417699351403, 'subsample': 0.5632250186857866, 'colsample_bytree': 0.8476962443460175, 'reg_alpha': 0.01117666260837648, 'reg_lambda': 6.534074597725049}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:14:05,102] Trial 123 finished with value: 296284.8859354313 and parameters: {'n_estimators': 1941, 'max_depth': 3, 'learning_rate': 0.04448243845051279, 'subsample': 0.5673900410503717, 'colsample_bytree': 0.8483795004976541, 'reg_alpha': 0.02068637879775497, 'reg_lambda': 6.178882276380866}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:14:07,250] Trial 124 finished with value: 301084.2834333264 and parameters: {'n_estimators': 1926, 'max_depth': 3, 'learning_rate': 0.04491477831162203, 'subsample': 0.5581611115580877, 'colsample_bytree': 0.8466158153557202, 'reg_alpha': 0.024783634796840655, 'reg_lambda': 7.426871182287427}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:14:09,238] Trial 125 finished with value: 298616.48315800435 and parameters: {'n_estimators': 1945, 'max_depth': 3, 'learning_rate': 0.04069897544886197, 'subsample': 0.5674090042316903, 'colsample_bytree': 0.899640718876119, 'reg_alpha': 0.013801121106443855, 'reg_lambda': 6.647748383933074}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:14:10,835] Trial 126 finished with value: 301047.70007315907 and parameters: {'n_estimators': 1975, 'max_depth': 3, 'learning_rate': 0.04327686934229772, 'subsample': 0.7811535713593398, 'colsample_bytree': 0.8645115295533115, 'reg_alpha': 0.018300146238376447, 'reg_lambda': 8.838503175888896}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:14:12,466] Trial 127 finished with value: 297631.7587137449 and parameters: {'n_estimators': 1843, 'max_depth': 3, 'learning_rate': 0.047819667715349144, 'subsample': 0.585243917918971, 'colsample_bytree': 0.879342390096637, 'reg_alpha': 0.010795449140774445, 'reg_lambda': 5.728636345636981}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:14:13,963] Trial 128 finished with value: 292590.91560521565 and parameters: {'n_estimators': 1844, 'max_depth': 3, 'learning_rate': 0.046753257370872305, 'subsample': 0.5804219092618714, 'colsample_bytree': 0.8793112788267657, 'reg_alpha': 0.018101932764526044, 'reg_lambda': 5.602768664765523}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:14:16,310] Trial 129 finished with value: 308423.39789654553 and parameters: {'n_estimators': 1897, 'max_depth': 4, 'learning_rate': 0.033879198382776525, 'subsample': 0.5385758992006321, 'colsample_bytree': 0.8550962165100272, 'reg_alpha': 0.04430062098474953, 'reg_lambda': 9.508144627355678}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:14:18,028] Trial 130 finished with value: 297778.37336784194 and parameters: {'n_estimators': 1946, 'max_depth': 3, 'learning_rate': 0.04608229354965846, 'subsample': 0.5515891727487799, 'colsample_bytree': 0.8292058963484494, 'reg_alpha': 0.022627997859162797, 'reg_lambda': 4.13151440573407}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:14:19,478] Trial 131 finished with value: 300450.3838186789 and parameters: {'n_estimators': 1865, 'max_depth': 3, 'learning_rate': 0.04732077450682042, 'subsample': 0.5763609731175765, 'colsample_bytree': 0.8812911393993363, 'reg_alpha': 0.010666809769822087, 'reg_lambda': 6.202536779063796}. Best is trial 122 with value: 291360.2606624697.
# ...
# [I 2026-04-27 21:15:08,417] Trial 157 finished with value: 295206.3532246315 and parameters: {'n_estimators': 1881, 'max_depth': 3, 'learning_rate': 0.03774253037525817, 'subsample': 0.6216624194559635, 'colsample_bytree': 0.8193191912538641, 'reg_alpha': 0.013490731956039902, 'reg_lambda': 4.048498114294079}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:09,952] Trial 158 finished with value: 294778.9390203137 and parameters: {'n_estimators': 1880, 'max_depth': 3, 'learning_rate': 0.037540699107217884, 'subsample': 0.6213649974233663, 'colsample_bytree': 0.804277416798182, 'reg_alpha': 0.013846571890938205, 'reg_lambda': 4.123129772678604}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:11,669] Trial 159 finished with value: 297822.17129563674 and parameters: {'n_estimators': 1879, 'max_depth': 3, 'learning_rate': 0.03695919895596826, 'subsample': 0.5994383022253092, 'colsample_bytree': 0.7946175658749598, 'reg_alpha': 0.014861032464941826, 'reg_lambda': 3.911728070090446}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:13,095] Trial 160 finished with value: 299653.37782110774 and parameters: {'n_estimators': 1834, 'max_depth': 3, 'learning_rate': 0.034733879990169386, 'subsample': 0.6248531866909394, 'colsample_bytree': 0.8223937302747055, 'reg_alpha': 0.013013767387213637, 'reg_lambda': 2.9348877601846177}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:14,541] Trial 161 finished with value: 297252.66003811365 and parameters: {'n_estimators': 1882, 'max_depth': 3, 'learning_rate': 0.0367298593215228, 'subsample': 0.6370003674794215, 'colsample_bytree': 0.7828747583967776, 'reg_alpha': 0.009271452438558907, 'reg_lambda': 4.492184438950527}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:16,130] Trial 162 finished with value: 301341.59037378285 and parameters: {'n_estimators': 1970, 'max_depth': 3, 'learning_rate': 0.04039717164750506, 'subsample': 0.618205350486824, 'colsample_bytree': 0.8120963916627739, 'reg_alpha': 0.010466968125614814, 'reg_lambda': 3.410491997055602}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:17,706] Trial 163 finished with value: 302018.7634533623 and parameters: {'n_estimators': 1924, 'max_depth': 3, 'learning_rate': 0.03793839366310565, 'subsample': 0.6448860748390349, 'colsample_bytree': 0.8035221476456579, 'reg_alpha': 0.001645375925535061, 'reg_lambda': 2.1945927530578815}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:19,335] Trial 164 finished with value: 296491.56926793756 and parameters: {'n_estimators': 1861, 'max_depth': 3, 'learning_rate': 0.042283982521352535, 'subsample': 0.6180836081830361, 'colsample_bytree': 0.8137989353401777, 'reg_alpha': 0.018879960836281417, 'reg_lambda': 4.018271068223712}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:21,024] Trial 165 finished with value: 298415.2275670558 and parameters: {'n_estimators': 1998, 'max_depth': 3, 'learning_rate': 0.03048612702445129, 'subsample': 0.605111830079497, 'colsample_bytree': 0.8343094990901773, 'reg_alpha': 0.0035421201029926593, 'reg_lambda': 4.968461454284227}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:22,867] Trial 166 finished with value: 294662.35216764075 and parameters: {'n_estimators': 1898, 'max_depth': 3, 'learning_rate': 0.03941885751046639, 'subsample': 0.6298466318752136, 'colsample_bytree': 0.8018294353689963, 'reg_alpha': 0.013265718235505652, 'reg_lambda': 2.6638589713765977}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:24,636] Trial 167 finished with value: 304147.6609983766 and parameters: {'n_estimators': 1903, 'max_depth': 3, 'learning_rate': 0.03815581664728304, 'subsample': 0.6630259497469158, 'colsample_bytree': 0.7436743766890905, 'reg_alpha': 0.024881694258525176, 'reg_lambda': 2.718743338720004}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:27,354] Trial 168 finished with value: 299751.999565785 and parameters: {'n_estimators': 1831, 'max_depth': 3, 'learning_rate': 0.034069845108852935, 'subsample': 0.631119732859047, 'colsample_bytree': 0.7950188474347711, 'reg_alpha': 0.014407910145688598, 'reg_lambda': 2.461119460679634}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:29,180] Trial 169 finished with value: 305334.71845619526 and parameters: {'n_estimators': 1881, 'max_depth': 3, 'learning_rate': 0.04627481528812021, 'subsample': 0.7424596449151253, 'colsample_bytree': 0.8220463086796733, 'reg_alpha': 0.001293372485817029, 'reg_lambda': 2.024923698285983}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:30,960] Trial 170 finished with value: 298234.9716742938 and parameters: {'n_estimators': 1812, 'max_depth': 3, 'learning_rate': 0.04387796494145994, 'subsample': 0.5957023519104012, 'colsample_bytree': 0.7726307218577323, 'reg_alpha': 0.01681710007688917, 'reg_lambda': 3.5838866304341765}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:33,997] Trial 171 finished with value: 295908.65500738355 and parameters: {'n_estimators': 1932, 'max_depth': 3, 'learning_rate': 0.04093031444915107, 'subsample': 0.6208353896279377, 'colsample_bytree': 0.8061278945351573, 'reg_alpha': 0.012006918178198248, 'reg_lambda': 7.252829943139268}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:35,821] Trial 172 finished with value: 296714.10015745874 and parameters: {'n_estimators': 1974, 'max_depth': 3, 'learning_rate': 0.042270811339707295, 'subsample': 0.6235990589205298, 'colsample_bytree': 0.8424621950955222, 'reg_alpha': 0.007831396975165253, 'reg_lambda': 5.943478166220183}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:37,673] Trial 173 finished with value: 308519.17573142756 and parameters: {'n_estimators': 1909, 'max_depth': 3, 'learning_rate': 0.03650279763280626, 'subsample': 0.6503155635904991, 'colsample_bytree': 0.7815263381582693, 'reg_alpha': 0.01245628255033829, 'reg_lambda': 7.752996822261629}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:46,834] Trial 174 finished with value: 361623.80146686285 and parameters: {'n_estimators': 1857, 'max_depth': 9, 'learning_rate': 0.039163341164216485, 'subsample': 0.6381682431579783, 'colsample_bytree': 0.8306839716596628, 'reg_alpha': 0.009909768860443006, 'reg_lambda': 7.103330659799019}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:48,519] Trial 175 finished with value: 295275.1424153582 and parameters: {'n_estimators': 1941, 'max_depth': 3, 'learning_rate': 0.04948818501482028, 'subsample': 0.6111692300922962, 'colsample_bytree': 0.8592588550979351, 'reg_alpha': 0.006645911340995843, 'reg_lambda': 2.91196385577544}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:50,181] Trial 176 finished with value: 296087.76994109177 and parameters: {'n_estimators': 1962, 'max_depth': 3, 'learning_rate': 0.05146319165726329, 'subsample': 0.6016886497469814, 'colsample_bytree': 0.8634251225023881, 'reg_alpha': 0.006311761073386403, 'reg_lambda': 2.9690190508064123}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:51,698] Trial 177 finished with value: 292241.5278506778 and parameters: {'n_estimators': 1759, 'max_depth': 3, 'learning_rate': 0.04924496362039076, 'subsample': 0.5832224315760098, 'colsample_bytree': 0.8561486320216318, 'reg_alpha': 0.004404164189792022, 'reg_lambda': 4.171972835960231}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:53,737] Trial 178 finished with value: 308925.5295241804 and parameters: {'n_estimators': 1595, 'max_depth': 4, 'learning_rate': 0.04938698554500087, 'subsample': 0.5866361838006662, 'colsample_bytree': 0.8519163075690626, 'reg_alpha': 0.005615877359788337, 'reg_lambda': 4.130465713993665}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:55,020] Trial 179 finished with value: 297579.05074829864 and parameters: {'n_estimators': 1749, 'max_depth': 3, 'learning_rate': 0.054959298295457724, 'subsample': 0.580284163116256, 'colsample_bytree': 0.841706552748418, 'reg_alpha': 0.007316417806087087, 'reg_lambda': 3.4281308088754607}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:56,685] Trial 180 finished with value: 291913.483656274 and parameters: {'n_estimators': 1895, 'max_depth': 3, 'learning_rate': 0.044633403842638336, 'subsample': 0.6051415334804083, 'colsample_bytree': 0.8594154672705023, 'reg_alpha': 0.003060488400569886, 'reg_lambda': 4.316696640955813}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:58,320] Trial 181 finished with value: 297149.75591374375 and parameters: {'n_estimators': 1916, 'max_depth': 3, 'learning_rate': 0.04428785440471704, 'subsample': 0.6100025758326332, 'colsample_bytree': 0.8578795260556686, 'reg_alpha': 0.0030851137421916146, 'reg_lambda': 5.304575229146107}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:15:59,770] Trial 182 finished with value: 293941.8315395244 and parameters: {'n_estimators': 1879, 'max_depth': 3, 'learning_rate': 0.048881369868209054, 'subsample': 0.59329980148669, 'colsample_bytree': 0.8611340644434602, 'reg_alpha': 0.003930824564004999, 'reg_lambda': 4.410363868086156}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:06,364] Trial 183 finished with value: 337285.603537883 and parameters: {'n_estimators': 1886, 'max_depth': 7, 'learning_rate': 0.052830939581704664, 'subsample': 0.5906340930031728, 'colsample_bytree': 0.8596217632033463, 'reg_alpha': 0.003847795688233565, 'reg_lambda': 4.133188866186035}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:08,055] Trial 184 finished with value: 295464.02788192226 and parameters: {'n_estimators': 1948, 'max_depth': 3, 'learning_rate': 0.04845434436590382, 'subsample': 0.6069140937087226, 'colsample_bytree': 0.841294292328604, 'reg_alpha': 0.003001034339244619, 'reg_lambda': 3.08298086860671}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:09,674] Trial 185 finished with value: 300463.1508744049 and parameters: {'n_estimators': 1973, 'max_depth': 3, 'learning_rate': 0.04594960202536529, 'subsample': 0.9169063392162617, 'colsample_bytree': 0.8193802874683884, 'reg_alpha': 0.0024674945467038573, 'reg_lambda': 5.824144332231336}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:11,034] Trial 186 finished with value: 299867.0265458193 and parameters: {'n_estimators': 1707, 'max_depth': 3, 'learning_rate': 0.04959635992153873, 'subsample': 0.5819313750848852, 'colsample_bytree': 0.8513023091991015, 'reg_alpha': 0.004460042529303943, 'reg_lambda': 3.67034195644327}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:12,513] Trial 187 finished with value: 302536.29634751176 and parameters: {'n_estimators': 1898, 'max_depth': 3, 'learning_rate': 0.057374989228561074, 'subsample': 0.6049916052181727, 'colsample_bytree': 0.8307404995477479, 'reg_alpha': 0.005224480704708136, 'reg_lambda': 1.8933661934068857}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:13,837] Trial 188 finished with value: 309482.75726300443 and parameters: {'n_estimators': 1769, 'max_depth': 3, 'learning_rate': 0.013902192353859312, 'subsample': 0.5947496984748614, 'colsample_bytree': 0.8688374134598025, 'reg_alpha': 0.003575941704769541, 'reg_lambda': 2.8403539167562166}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:15,240] Trial 189 finished with value: 303293.91998209944 and parameters: {'n_estimators': 1839, 'max_depth': 3, 'learning_rate': 0.05232653738556067, 'subsample': 0.6133607654663664, 'colsample_bytree': 0.8454888459383368, 'reg_alpha': 0.0017172690170260774, 'reg_lambda': 4.324748245428669}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:16,828] Trial 190 finished with value: 298744.8992775703 and parameters: {'n_estimators': 1931, 'max_depth': 3, 'learning_rate': 0.04684587793150546, 'subsample': 0.5738899163150974, 'colsample_bytree': 0.8615566500618863, 'reg_alpha': 0.004283196081191858, 'reg_lambda': 5.643105721362073}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:18,570] Trial 191 finished with value: 292044.59513677773 and parameters: {'n_estimators': 1817, 'max_depth': 3, 'learning_rate': 0.04389819443993737, 'subsample': 0.5931328664760896, 'colsample_bytree': 0.8870473534555947, 'reg_alpha': 0.01599791797766038, 'reg_lambda': 4.548315903513113}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:20,405] Trial 192 finished with value: 295948.6964279522 and parameters: {'n_estimators': 1856, 'max_depth': 3, 'learning_rate': 0.044882687292237454, 'subsample': 0.5891860651692926, 'colsample_bytree': 0.8839090866792282, 'reg_alpha': 0.021111151339874165, 'reg_lambda': 3.5990294299176244}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:22,299] Trial 193 finished with value: 293622.59774804814 and parameters: {'n_estimators': 2000, 'max_depth': 3, 'learning_rate': 0.050340610818379095, 'subsample': 0.6295803062068425, 'colsample_bytree': 0.873878562515421, 'reg_alpha': 0.017931557358657996, 'reg_lambda': 4.786038581353682}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:24,083] Trial 194 finished with value: 300877.409218257 and parameters: {'n_estimators': 1994, 'max_depth': 3, 'learning_rate': 0.04723046306575118, 'subsample': 0.6316573464554135, 'colsample_bytree': 0.8929486474691603, 'reg_alpha': 0.017313315654196276, 'reg_lambda': 4.667699775078962}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:26,013] Trial 195 finished with value: 302581.5921045699 and parameters: {'n_estimators': 1886, 'max_depth': 3, 'learning_rate': 0.041708819002028524, 'subsample': 0.8578962611416545, 'colsample_bytree': 0.9233247787524649, 'reg_alpha': 0.014647738380703544, 'reg_lambda': 6.210481490469642}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:27,640] Trial 196 finished with value: 297469.051468879 and parameters: {'n_estimators': 1817, 'max_depth': 3, 'learning_rate': 0.05480432264773694, 'subsample': 0.579627407108037, 'colsample_bytree': 0.8743658890956012, 'reg_alpha': 0.030448936555473028, 'reg_lambda': 4.367744567323787}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:29,205] Trial 197 finished with value: 299903.1643133827 and parameters: {'n_estimators': 1907, 'max_depth': 3, 'learning_rate': 0.051023456026228396, 'subsample': 0.6002712067457195, 'colsample_bytree': 0.8350610854941188, 'reg_alpha': 0.023220237496592733, 'reg_lambda': 5.272932081709695}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:30,766] Trial 198 finished with value: 305972.8470358562 and parameters: {'n_estimators': 1789, 'max_depth': 3, 'learning_rate': 0.03922525356454165, 'subsample': 0.6273245143866449, 'colsample_bytree': 0.8859898421813969, 'reg_alpha': 0.0028085823054433408, 'reg_lambda': 3.7010692176229356}. Best is trial 122 with value: 291360.2606624697.
# [I 2026-04-27 21:16:32,268] Trial 199 finished with value: 294370.57408334356 and parameters: {'n_estimators': 1650, 'max_depth': 3, 'learning_rate': 0.04487591118342871, 'subsample': 0.5892248659768066, 'colsample_bytree': 0.7928697511066364, 'reg_alpha': 0.01731483446545553, 'reg_lambda': 6.9767172383221885}. Best is trial 122 with value: 291360.2606624697.
# Bộ tham số xịn nhất đây rồi: {'n_estimators': 1945, 'max_depth': 3, 'learning_rate': 0.04516417699351403, 'subsample': 0.5632250186857866, 'colsample_bytree': 0.8476962443460175, 'reg_alpha': 0.01117666260837648, 'reg_lambda': 6.534074597725049}

# %% [markdown]
# #### By consolidating our hyperparameter tuning into a single, parameter-driven cell, we have implemented a modular pipeline that prioritizes code maintainability. This approach allows for seamless iteration; once the high-gain features are identified through exploratory analysis, they are statically updated in the configuration layer. This decoupling ensures that the Bayesian search engine (Optuna) consistently operates on a refined input matrix, effectively reducing computational overhead and mitigating the risk of stochastic variance. The result is a highly robust and reproducible model, optimized for the structural dynamics of the 2023 retail landscape.

# %%
# from xgboost import plot_importance

# # 1. Train lại một model với bộ tham số xịn nhất Optuna vừa tìm được
# best_model = XGBRegressor(**study.best_params)
# best_model.fit(X_train, y_train)

# # 2. Vẽ biểu đồ quan trọng theo GÁNH (Gain) - Cái này chuẩn hơn Weight
# fig, ax = plt.subplots(figsize=(10, 12))
# plot_importance(best_model, importance_type='gain', ax=ax)
# plt.show()

from xgboost import plot_importance
import matplotlib.pyplot as plt # Đảm bảo bạn đã import thư viện này để vẽ hình

# 1. Train lại một model với bộ tham số xịn nhất Optuna vừa tìm được
best_model = XGBRegressor(**study.best_params)

# --- DỌN DẸP LẠI DỮ LIỆU (Giống hệt bước trước) ---
X_train_clean = X_train.loc[:, ~X_train.columns.duplicated()].copy()
y_train_1d = y_train.squeeze()
# ---------------------------------------------------

# Fit model bằng dữ liệu ĐÃ CLEAN
best_model.fit(X_train_clean, y_train_1d)

# 2. Vẽ biểu đồ quan trọng theo GÁNH (Gain) - Cái này chuẩn hơn Weight
fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(best_model, importance_type='gain', ax=ax)
plt.show()

# %%
import xgboost as xgb

best_param={
    'n_estimators': 1945,
    'max_depth': 3, 
    'learning_rate': 0.04516417699351403, 
    'subsample': 0.5632250186857866, 
    'colsample_bytree': 0.8476962443460175, 
    'reg_alpha': 0.01117666260837648, 
    'reg_lambda': 6.534074597725049
}
model_rev = XGBRegressor(**best_param)
model_rev.fit(df_daily[features], df_daily['Revenue'])

model_cogs= XGBRegressor(**best_param)
model_cogs.fit(df_daily[features], df_daily['COGS'])

print("✅ Đã huấn luyện xong bộ đôi 'não bộ' cho Model!")

from sklearn.model_selection import KFold, cross_validate
from sklearn.metrics import r2_score
kf = KFold(n_splits=5, shuffle=True, random_state=42)
scoring = {'mse': 'neg_mean_squared_error', 'r2': 'r2'}

# Chấm điểm thử cho Model Revenue
cv_results = cross_validate(model_rev, df_daily[features], df_daily['Revenue'], 
                            cv=kf, scoring=scoring)

# Tính toán các chỉ số trung bình từ kết quả CV
avg_mse = -cv_results['test_mse'].mean()
avg_rmse = np.sqrt(avg_mse)
avg_r2 = cv_results['test_r2'].mean()

print(f"📊 Kết quả Đánh giá 5-Fold:")
print(f"   - MSE:  {avg_mse:,.2f}")
print(f"   - RMSE: {avg_rmse:,.2f}")
print(f"   - R²:   {avg_r2:.4f}")

train_pred = model_rev.predict(df_daily[features])
train_r2 = r2_score(df_daily['Revenue'], train_pred)
print(f"Điểm trên tập Train: {train_r2:.4f}")
# Out:
# ✅ Đã huấn luyện xong bộ đôi 'não bộ' cho Model!
# 📊 Kết quả Đánh giá 5-Fold:
#    - MSE:  89,749,200,192.59
#    - RMSE: 299,581.71
#    - R²:   0.9864
# Điểm trên tập Train: 0.9962

# %%
# ĐÁNH GIÁ MÔ HÌNH REVENUE
cv_rev = cross_validate(model_rev, df_daily[features], df_daily['Revenue'], 
                         cv=kf, scoring=scoring)

# ĐÁNH GIÁ MÔ HÌNH COGS
cv_cogs = cross_validate(model_cogs, df_daily[features], df_daily['COGS'], 
                          cv=kf, scoring=scoring)

# TỔNG KẾT KẾT QUẢ
print(f"[REVENUE] Local RMSE: {np.sqrt(-cv_rev['test_mse'].mean()):,.2f} | R²: {cv_rev['test_r2'].mean():.4f}")
print(f"[COGS]    Local RMSE: {np.sqrt(-cv_cogs['test_mse'].mean()):,.2f} | R²: {cv_cogs['test_r2'].mean():.4f}")
# Out:
# [REVENUE] Local RMSE: 299,581.71 | R²: 0.9864
# [COGS]    Local RMSE: 256,799.29 | R²: 0.9866

# %%
from xgboost import plot_importance

# 1. Thiết lập kích thước biểu đồ
fig, ax = plt.subplots(figsize=(10, 8))

# 2. Vẽ biểu đồ quan trọng (Dùng 'weight' để xem tần suất biến đó được dùng để phân loại)
plot_importance(model_rev, ax=ax, max_num_features=15, importance_type='weight', color='royalblue')

plt.title("Top 15 Đặc trưng ảnh hưởng nhất đến Doanh thu")
plt.show()

# %%
ALL_DATES = sorted(df_daily['Date'].unique())

def get_lag_safe(date_obj, lag_days, key, hist_dict):
    target_date = date_obj - pd.Timedelta(days=lag_days)
    
    if target_date in hist_dict:
        return hist_dict[target_date].get(key, 0)
    
    valid_dates = [d for d in ALL_DATES if d <= target_date]
    if valid_dates:
        closest_date = valid_dates[-1]
        if abs((closest_date - target_date).days) <= 3:
            return hist_dict.get(closest_date, {}).get(key, 0)
    return 0

# %%
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

def get_promo_features_for_single_date(current_date):
    year = current_date.year
    month_day = current_date.strftime('%m-%d')
    
    is_spring = 1 if '03-18' <= month_day <= '04-17' else 0
    is_midyear = 1 if '06-23' <= month_day <= '07-22' else 0
    is_fall = 1 if ('08-30' <= month_day <= '10-01') or ((year % 4 == 1) and month_day == '10-02') else 0
    is_yearend = 1 if ('11-18' <= month_day <= '12-31') or ('01-01' <= month_day <= '01-02') else 0
    is_rural = 1 if (year % 2 == 1) and ('01-30' <= month_day <= '03-01') else 0
    is_urban = 1 if (year % 2 == 1) and ('07-30' <= month_day <= '09-02') else 0
    
    # --- Decode ---
    cat_promo = -1
    if is_spring or is_midyear or is_yearend:
        cat_promo = 0
    if is_rural:
        cat_promo = 1
    if is_urban:
        cat_promo = 2
        
    chanel_promo = -1
    if is_spring or is_fall:
        chanel_promo = 4
    if is_rural:
        chanel_promo = 1
    if is_urban:
        chanel_promo = 2
    if is_midyear:
        chanel_promo = 3
    if is_yearend:
        chanel_promo = 0
        
    return {
        'is_Spring_promotion': is_spring,
        'is_MidYear_promotion': is_midyear,
        'is_FallLauch_promotion': is_fall,
        'is_YearEnd_promotion': is_yearend,
        'is_Rural_promotion': is_rural,
        'is_Urban_promotion': is_urban,
        'category_promotion': cat_promo,
        'chanel_promotion': chanel_promo
    }

# Hàm helper lấy giá trị từ dictionary lịch sử
def get_lag_val(date_obj, lag_days, key, hist_dict):
    target_ds = date_obj - pd.Timedelta(days=lag_days)
    if target_ds in hist_dict:
        return hist_dict[target_ds].get(key, 0)
    return 0

# 1. Tạo tập validation 
val_start = '2022-11-01'
val_end = '2022-12-31'

# Lấy 400 ngày cuối cùng của tập train để làm lịch sử cho validation
historical_val = df_daily[['Date', 'Revenue', 'Profit']].iloc[-400:-30].copy()
historical_val = historical_val.rename(columns={'Date': 'ds', 'Revenue': 'y', 'Profit': 'profit'})
historical_val_dict = historical_val.set_index('ds').to_dict('index')

# 2. Tạo đặc trưng tĩnh theo tháng
train_monthly_avg = df_daily.groupby('month')[
    ['seg_Balanced', 'seg_Activewear', 'seg_Premium', 'seg_All-weather', 'seg_Everyday', 'seg_Performance', 
    'cat_Casual', 'cat_Outdoor', 'cat_Streetwear', 
    
    'rev_lag_1', 'rev_lag_7', 'rev_lag_365', 
    'profit_lag_1', 'profit_lag_7', 'profit_lag_365', 
    'margin_rate', 'margin_rate_lag_1', 'margin_rate_lag_7', 'margin_rate_lag_365',  
    
    'month', 'is_promoted', 
    'avg_discount_pct', 'max_discount_pct',

    'is_Spring_promotion', 'is_MidYear_promotion', 'is_FallLauch_promotion',
    'is_YearEnd_promotion', 'is_Rural_promotion', 'is_Urban_promotion',
    'category_promotion', 'chanel_promotion']
].mean().to_dict('index')

# 3. Tìm tỷ lệ blending tối ưu
best_score = float('inf')
best_ratio = 0.8
best_growth = 1.03

print("Đang tìm tỷ lệ blending tối ưu...")
for growth in [0.99, 1.0, 1.01]:
    for ratio in [0.45, 0.5, 0.55, 0.60]:
        val_results = []
        temp_dict = historical_val_dict.copy()
        
        for current_date in pd.date_range(start=val_start, end=val_end):
            month = current_date.month
            promo_features = get_promo_features_for_single_date(current_date)
            # Tạo feature cho ngày hiện tại
            current_features = {
                'month': month,
                
                'rev_lag_1': get_lag_safe(current_date, 1, 'y', temp_dict),
                'rev_lag_7': get_lag_safe(current_date, 7, 'y', temp_dict),
                'rev_lag_365': get_lag_safe(current_date, 365, 'y', temp_dict),

                'profit_lag_1': get_lag_safe(current_date, 1, 'profit', temp_dict),
                'profit_lag_7': get_lag_safe(current_date, 7, 'profit', temp_dict),
                'profit_lag_365': get_lag_safe(current_date, 365, 'profit', temp_dict),

                'margin_rate_lag_7': get_lag_safe(current_date, 7, 'profit', temp_dict) / (get_lag_safe(current_date, 7, 'y', temp_dict) + 1),
                'margin_rate_lag_1': get_lag_safe(current_date, 1, 'profit', temp_dict) / (get_lag_safe(current_date, 1, 'y', temp_dict) + 1),
                'margin_rate_lag_365': get_lag_safe(current_date, 365, 'profit', temp_dict) / (get_lag_safe(current_date, 365, 'y', temp_dict) + 1),
            }
            current_features.update(promo_features)
        
            # Tính margin_rate_lag_7
            rev_lag_7 = get_lag_safe(current_date, 7, 'y', temp_dict)
            profit_lag_7_val = current_features['profit_lag_7']
            current_features['margin_rate_lag_7'] = profit_lag_7_val / (rev_lag_7 + 1)
            
            # Thêm đặc trưng tĩnh
            for k, v in train_monthly_avg.get(month, {}).items():
                current_features[k] = v
            
            X_pred = pd.DataFrame([current_features])[features]
            revenue_pred = model_rev.predict(X_pred)[0]
            cogs_pred = model_cogs.predict(X_pred)[0]
            
            hist_rev = get_lag_safe(current_date, 365, 'y', temp_dict)
            hist_cogs = hist_rev - get_lag_safe(current_date, 365, 'profit', temp_dict) if hist_rev > 0 else 0
            
            final_rev = (hist_rev * growth * ratio) + (revenue_pred * (1 - ratio))
            final_cogs = (hist_cogs * growth * ratio) + (cogs_pred * (1 - ratio))
            
            temp_dict[current_date] = {'y': final_rev, 'profit': final_rev - final_cogs}
            val_results.append({'Date': current_date, 'Revenue': final_rev, 'COGS': final_cogs})
        
        # Đánh giá
        val_df = pd.DataFrame(val_results)
        actual_train = df_daily[df_daily['Date'].between(val_start, val_end)]
        val_merged = val_df.merge(actual_train[['Date', 'Revenue', 'COGS']], on='Date', suffixes=('_pred', '_actual'))
        
        mse_rev = mean_squared_error(val_merged['Revenue_actual'], val_merged['Revenue_pred'])
        mse_cogs = mean_squared_error(val_merged['COGS_actual'], val_merged['COGS_pred'])
        total_mse = mse_rev + mse_cogs
        
        if total_mse < best_score:
            best_score = total_mse
            best_ratio = ratio
            best_growth = growth

print(f"\nTỶ LỆ BLENDING TỐI ƯU:")
print(f"   - History weight: {best_ratio:.0%}")
print(f"   - AI weight:      {1-best_ratio:.0%}")
print(f"   - Growth factor:  {best_growth}")
print(f"   - Best MSE:       {best_score:,.2f}")
# Out:
# Đang tìm tỷ lệ blending tối ưu...
#
# TỶ LỆ BLENDING TỐI ƯU:
#    - History weight: 45%
#    - AI weight:      55%
#    - Growth factor:  0.99
#    - Best MSE:       690,505,577,574.66

# %%
from tqdm import tqdm

print("Bắt đầu quá trình dự đoán tuần tự...")

historical_df = df_daily[['Date', 'Revenue', 'Profit']].iloc[-370:].copy()
historical_df = historical_df.rename(columns={'Date': 'ds', 'Revenue': 'y', 'Profit': 'profit'})
historical_dict = historical_df.set_index('ds').to_dict('index')

future_dates = pd.date_range(start='2023-01-01', end='2024-07-01')
results = []

# Các đặc trưng tĩnh (không thay đổi theo thời gian hoặc lấy trung bình tháng)
train_monthly_avg = df_daily.groupby('month')[
    ['seg_Balanced', 'seg_Activewear', 'seg_Premium', 'seg_All-weather', 'seg_Everyday', 'seg_Performance', 
    'cat_Casual', 'cat_Outdoor', 'cat_Streetwear', 
    
    'rev_lag_1', 'rev_lag_7', 'rev_lag_365', 
    'profit_lag_1', 'profit_lag_7', 'profit_lag_365', 
    'margin_rate', 'margin_rate_lag_1', 'margin_rate_lag_7', 'margin_rate_lag_365',  
    
    'month', 'is_promoted', 
    'avg_discount_pct', 'max_discount_pct',

    'is_Spring_promotion', 'is_MidYear_promotion', 'is_FallLauch_promotion',
    'is_YearEnd_promotion', 'is_Rural_promotion', 'is_Urban_promotion',
    'category_promotion', 'chanel_promotion']
].mean().to_dict('index')
# Dự đoán tuần tự
for current_date in tqdm(future_dates, desc="Đang dự đoán"):
    month = current_date.month
    promo_features = get_promo_features_for_single_date(current_date)
    # Tạo feature cho ngày hiện tại
    current_features = {
        'month': month,
        
        'rev_lag_1': get_lag_safe(current_date, 1, 'y', historical_dict),
        'rev_lag_7': get_lag_safe(current_date, 7, 'y', historical_dict),
        'rev_lag_365': get_lag_safe(current_date, 365, 'y', historical_dict),

        'profit_lag_1': get_lag_safe(current_date, 1, 'profit', historical_dict),
        'profit_lag_7': get_lag_safe(current_date, 7, 'profit', historical_dict),
        'profit_lag_365': get_lag_safe(current_date, 365, 'profit', historical_dict),

        'margin_rate_lag_7': get_lag_safe(current_date, 7, 'profit', historical_dict) / (get_lag_safe(current_date, 7, 'y', historical_dict) + 1),
        'margin_rate_lag_1': get_lag_safe(current_date, 1, 'profit', historical_dict) / (get_lag_safe(current_date, 1, 'y', historical_dict) + 1),
        'margin_rate_lag_365': get_lag_safe(current_date, 365, 'profit', historical_dict) / (get_lag_safe(current_date, 365, 'y', historical_dict) + 1),
    }
    current_features.update(promo_features)
    
    # Thêm các đặc trưng tĩnh từ dữ liệu trung bình tháng
    for k, v in train_monthly_avg.get(month, {}).items():
        current_features[k] = v

    # Dự đoán Doanh thu và Giá vốn
    X_pred = pd.DataFrame([current_features])[features]
    revenue_pred = model_rev.predict(X_pred)[0]
    cogs_pred = model_cogs.predict(X_pred)[0]

    # Blending
    hist_rev = get_lag_safe(current_date, 365, 'y', historical_dict)
    hist_cogs = hist_rev - get_lag_safe(current_date, 365, 'profit', historical_dict) if hist_rev > 0 else 0

    growth_factor = 1.00
    final_rev = (hist_rev * growth_factor * 0.5) + (revenue_pred * 0.5)
    final_cogs = (hist_cogs * growth_factor * 0.5) + (cogs_pred * 0.5)

    # Cập nhật kết quả vào historical_dict cho các lần dự đoán tiếp theo
    historical_dict[current_date] = {'y': final_rev, 'profit': final_rev - final_cogs}
    
    # Lưu kết quả
    results.append({
        'Date': current_date.strftime('%Y-%m-%d'),
        'Revenue': final_rev,
        'COGS': final_cogs
    })

# Tạo và lưu file submission
submission_final = pd.DataFrame(results)
path_submit = 'submission_vi_v2.csv'
submission_final.to_csv(path_submit, index=False)
print(f"✅ File {path_submit} đã sẵn sàng nộp.")
# Out:
# Bắt đầu quá trình dự đoán tuần tự...
# Đang dự đoán:   0%|          | 0/548 [00:00<?, ?it/s]
# Đang dự đoán: 100%|██████████| 548/548 [00:14<00:00, 37.58it/s]
# ✅ File submission_vi_v2.csv đã sẵn sàng nộp.
