# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df_pmot = pd.read_parquet('../dataset/cleaned/promotions.parquet')

# %% [markdown]
# # 1. Load the data

# %%
df_products= pd.read_parquet('../dataset/cleaned/products.parquet')
df_order_items= pd.read_parquet('../dataset/cleaned/order_items.parquet')

# %% [markdown]
# ### Merged file products.csv and order_items.csv through product_id column

# %%
df_merged= pd.merge(df_products, df_order_items, on='product_id', how='left')

# %%
print("Cột trong order_items:", df_order_items.columns.tolist())
print("Cột sau khi merged:", df_merged.columns.tolist())
# Out:
# Cột trong order_items: ['order_id', 'product_id', 'quantity', 'unit_price', 'discount_amount', 'promo_id', 'promo_id_2']
# Cột sau khi merged: ['product_id', 'product_name', 'category', 'segment', 'size', 'color', 'price', 'cogs', 'order_id', 'quantity', 'unit_price', 'discount_amount', 'promo_id', 'promo_id_2']

# %%
df_merged.head()
# Out:
#   product_id      product_name    category   segment size  color     price  \
# 0        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 1        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 2        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 3        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 4        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
#
#           cogs order_id  quantity  unit_price  discount_amount promo_id  \
# 0  9704.842875   245451       5.0    11183.67              0.0     None
# 1  9704.842875   245898       8.0    10918.75              0.0     None
# 2  9704.842875   246268       6.0    11184.55              0.0     None
# 3  9704.842875   246907       2.0    11104.72              0.0     None
# 4  9704.842875   247911       6.0    11143.16              0.0     None
#
#   promo_id_2
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None

# %%
df_promos = pd.read_parquet('../dataset/cleaned/promotions.parquet')
df_final = df_merged.merge(df_promos, on='promo_id', how='left')
display(df_final.head())
# Out:
#   product_id      product_name    category   segment size  color     price  \
# 0        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 1        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 2        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 3        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 4        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
#
#           cogs order_id  quantity  ...  promo_id_2  promo_name promo_type  \
# 0  9704.842875   245451       5.0  ...        None        <NA>        NaN
# 1  9704.842875   245898       8.0  ...        None        <NA>        NaN
# 2  9704.842875   246268       6.0  ...        None        <NA>        NaN
# 3  9704.842875   246907       2.0  ...        None        <NA>        NaN
# 4  9704.842875   247911       6.0  ...        None        <NA>        NaN
#
#   discount_value start_date end_date  applicable_category promo_channel  \
# 0            NaN        NaT      NaT                  NaN           NaN
# 1            NaN        NaT      NaT                  NaN           NaN
# 2            NaN        NaT      NaT                  NaN           NaN
# 3            NaN        NaT      NaT                  NaN           NaN
# 4            NaN        NaT      NaT                  NaN           NaN
#
#   stackable_flag min_order_value
# 0            NaN             NaN
# 1            NaN             NaN
# 2            NaN             NaN
# 3            NaN             NaN
# 4            NaN             NaN
#
# [5 rows x 23 columns]

# %%
df_orders = pd.read_parquet('../dataset/cleaned/orders.parquet')
df_master = df_final.merge(df_orders[['order_id', 'order_date']], on='order_id', how='left')

df_master = df_master.rename(columns={'order_date': 'Date'})
print("Kích thước bảng Master:", df_master.shape)
display(df_master.head())
# Out:
# Kích thước bảng Master: (715483, 24)
#   product_id      product_name    category   segment size  color     price  \
# 0        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 1        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 2        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 3        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
# 4        536  SaigonFlex UC-01  Streetwear  Everyday    S  green  11059.65
#
#           cogs order_id  quantity  ...  promo_name  promo_type discount_value  \
# 0  9704.842875   245451       5.0  ...        <NA>         NaN            NaN
# 1  9704.842875   245898       8.0  ...        <NA>         NaN            NaN
# 2  9704.842875   246268       6.0  ...        <NA>         NaN            NaN
# 3  9704.842875   246907       2.0  ...        <NA>         NaN            NaN
# 4  9704.842875   247911       6.0  ...        <NA>         NaN            NaN
#
#   start_date end_date applicable_category  promo_channel stackable_flag  \
# 0        NaT      NaT                 NaN            NaN            NaN
# 1        NaT      NaT                 NaN            NaN            NaN
# 2        NaT      NaT                 NaN            NaN            NaN
# 3        NaT      NaT                 NaN            NaN            NaN
# 4        NaT      NaT                 NaN            NaN            NaN
#
#   min_order_value       Date
# 0             NaN 2015-01-07
# 1             NaN 2015-01-13
# 2             NaN 2015-01-13
# 3             NaN 2015-01-17
# 4             NaN 2015-01-24
#
# [5 rows x 24 columns]

# %% [markdown]
# # 2. EDA

# %%
check_promo = df_final[df_final['promo_name'].notna()]
print(f"Tổng số dòng có thông tin khuyến mãi: {len(check_promo)}")
display(check_promo.head())
# Out:
# Tổng số dòng có thông tin khuyến mãi: 276316
#    product_id      product_name    category   segment size   color  \
# 14        536  SaigonFlex UC-01  Streetwear  Everyday    S   green
# 15        536  SaigonFlex UC-01  Streetwear  Everyday    S   green
# 16        536  SaigonFlex UC-01  Streetwear  Everyday    S   green
# 26        536  SaigonFlex UC-01  Streetwear  Everyday    S   green
# 27        537  SaigonFlex UC-02  Streetwear  Everyday    M  silver
#
#            price         cogs order_id  quantity  ...  promo_id_2  \
# 14  11059.650000  9704.842875   259871       1.0  ...        None
# 15  11059.650000  9704.842875   268094       6.0  ...        None
# 16  11059.650000  9704.842875   268430       8.0  ...        None
# 26  11059.650000  9704.842875   299601       3.0  ...        None
# 27   9523.076013  5393.870254   523256       7.0  ...        None
#
#             promo_name  promo_type discount_value start_date   end_date  \
# 14    Spring Sale 2015  percentage           12.0 2015-03-18 2015-04-17
# 15    Spring Sale 2015  percentage           12.0 2015-03-18 2015-04-17
# 16    Spring Sale 2015  percentage           12.0 2015-03-18 2015-04-17
# 26  Mid-Year Sale 2015  percentage           18.0 2015-06-23 2015-07-22
# 27  Urban Blowout 2017       fixed           50.0 2017-07-30 2017-09-02
#
#     applicable_category promo_channel stackable_flag min_order_value
# 14                  All  all_channels           True        100000.0
# 15                  All  all_channels           True        100000.0
# 16                  All  all_channels           True        100000.0
# 26                  All  social_media          False             0.0
# 27           Streetwear        online          False        150000.0
#
# [5 rows x 23 columns]

# %%
df_final.info()
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715483 entries, 0 to 715482
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   product_id           715483 non-null  string
#  1   product_name         715483 non-null  string
#  2   category             715483 non-null  category
#  3   segment              715483 non-null  category
#  4   size                 715483 non-null  category
#  5   color                715483 non-null  category
#  6   price                715483 non-null  float64
#  7   cogs                 715483 non-null  float64
#  8   order_id             714669 non-null  string
#  9   quantity             714669 non-null  float64
#  10  unit_price           714669 non-null  float64
#  11  discount_amount      714669 non-null  float64
#  12  promo_id             714669 non-null  string
#  13  promo_id_2           714669 non-null  string
#  14  promo_name           276316 non-null  string
#  15  promo_type           276316 non-null  category
#  16  discount_value       276316 non-null  float64
#  17  start_date           276316 non-null  datetime64[ns]
#  18  end_date             276316 non-null  datetime64[ns]
#  19  applicable_category  276316 non-null  category
#  20  promo_channel        276316 non-null  category
#  21  stackable_flag       276316 non-null  object
#  22  min_order_value      276316 non-null  float64
# dtypes: category(7), datetime64[ns](2), float64(7), object(1), string(6)
# memory usage: 92.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715483 entries, 0 to 715482
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   product_id           715483 non-null  string
#  1   product_name         715483 non-null  string
#  2   category             715483 non-null  category
#  3   segment              715483 non-null  category
#  4   size                 715483 non-null  category
#  5   color                715483 non-null  category
#  6   price                715483 non-null  float64
#  7   cogs                 715483 non-null  float64
#  8   order_id             714669 non-null  string
#  9   quantity             714669 non-null  float64
#  10  unit_price           714669 non-null  float64
#  11  discount_amount      714669 non-null  float64
#  12  promo_id             714669 non-null  string
#  13  promo_id_2           714669 non-null  string
#  14  promo_name           276316 non-null  string
#  15  promo_type           276316 non-null  category
#  16  discount_value       276316 non-null  float64
#  17  start_date           276316 non-null  datetime64[ns]
#  18  end_date             276316 non-null  datetime64[ns]
#  19  applicable_category  276316 non-null  category
#  20  promo_channel        276316 non-null  category
#  21  stackable_flag       276316 non-null  object
#  22  min_order_value      276316 non-null  float64
#  23  Date                 714669 non-null  datetime64[ns]
# dtypes: category(7), datetime64[ns](3), float64(7), object(1), string(6)
# memory usage: 97.6+ MB

# %%
# print(df_master[df_master['order_id'].isnull()].sample(5))
df_missing_orders = df_master[df_master['order_id'].isnull()]
print(df_missing_orders['product_id'].is_unique)

missing_product_ids = df_missing_orders['product_id']
df_products['is_never_sale'] = df_products['product_id'].isin(missing_product_ids).astype(bool)

duplicate_primary_key = df_products[df_products['product_name'].duplicated(keep=False)].sort_values(by='product_name')
if len(duplicate_primary_key) > 0:
    print(f"{len(duplicate_primary_key)} duplicated product_name rows:")
    display(duplicate_primary_key.head(5))
    
df_products['is_duplicated'] = df_products['product_id'].isin(duplicate_primary_key['product_id']).astype(bool)
df_products = df_products.sort_values(by='product_id')

duplicate_primary_key.to_parquet('duplicate_products.parquet', engine='pyarrow')
df_products.to_parquet('products_add.parquet', engine='pyarrow')
# Out:
# True
# 426 duplicated product_name rows:
#     product_id     product_name    category      segment size   color  \
# 745        380  LotusWear UE-01  Streetwear  Performance    S     red
# 645        280  LotusWear UE-01  Streetwear  Performance    S     red
# 646        281  LotusWear UE-02  Streetwear  Performance    M   black
# 746        381  LotusWear UE-02  Streetwear  Performance    M   black
# 647        282  LotusWear UE-03  Streetwear  Performance    L  orange
#
#             price          cogs  is_never_sale
# 745     34.036218     21.343813           True
# 645  12596.850000  11967.007500          False
# 646  15746.850000   8750.524545          False
# 746     21.651582     12.139172           True
# 647  14486.850000  12008.149965          False

# %%
print("Tổng số sản phẩm sau khi merge:", len(df_master))
print("Số lượng đơn hàng có Date:", df_master['Date'].notnull().sum())
print(f"=> Phát hiện: {len(df_master) - df_master['Date'].notnull().sum()} sản phẩm chưa bao giờ được bán.")
# Out:
# Tổng số sản phẩm sau khi merge: 715483
# Số lượng đơn hàng có Date: 714669
# => Phát hiện: 814 sản phẩm chưa bao giờ được bán.

# %% [markdown]
# ### Insight: Có 814 "sản phẩm ma" (Deadstock). Chúng ta cần loại bỏ chúng để dữ liệu dự báo không bị nhiễu.

# %%
df_master = df_master.dropna(subset=['Date']).reset_index(drop=True)
print("Kích thước bảng thực tế:", df_master.shape)
# Out:
# Kích thước bảng thực tế: (714669, 24)

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714669 entries, 0 to 714668
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   product_id           714669 non-null  string
#  1   product_name         714669 non-null  string
#  2   category             714669 non-null  category
#  3   segment              714669 non-null  category
#  4   size                 714669 non-null  category
#  5   color                714669 non-null  category
#  6   price                714669 non-null  float64
#  7   cogs                 714669 non-null  float64
#  8   order_id             714669 non-null  string
#  9   quantity             714669 non-null  float64
#  10  unit_price           714669 non-null  float64
#  11  discount_amount      714669 non-null  float64
#  12  promo_id             714669 non-null  string
#  13  promo_id_2           714669 non-null  string
#  14  promo_name           276316 non-null  string
#  15  promo_type           276316 non-null  category
#  16  discount_value       276316 non-null  float64
#  17  start_date           276316 non-null  datetime64[ns]
#  18  end_date             276316 non-null  datetime64[ns]
#  19  applicable_category  276316 non-null  category
#  20  promo_channel        276316 non-null  category
#  21  stackable_flag       276316 non-null  object
#  22  min_order_value      276316 non-null  float64
#  23  Date                 714669 non-null  datetime64[ns]
# dtypes: category(7), datetime64[ns](3), float64(7), object(1), string(6)
# memory usage: 97.5+ MB

# %% [markdown]
# ### Check if any columns are missing data.

# %%
missing_data = df_master.isnull().sum()
print(missing_data[missing_data > 0])
# Out:
# promo_name             438353
# promo_type             438353
# discount_value         438353
# start_date             438353
# end_date               438353
# applicable_category    438353
# promo_channel          438353
# stackable_flag         438353
# min_order_value        438353
# dtype: int64

# %%
if 'stackable_flag' in df_master.columns:
    df_master['stackable_flag'] = df_master['stackable_flag'].fillna(0)

# %%
missing_data = df_master.isnull().sum()
print(missing_data[missing_data > 0])
# Out:
# promo_name             438353
# promo_type             438353
# discount_value         438353
# start_date             438353
# end_date               438353
# applicable_category    438353
# promo_channel          438353
# min_order_value        438353
# dtype: int64

# %% [markdown]
# ### Add revenue and profit

# %%
df_master['Revenue_line'] = df_master['quantity'] * df_master['unit_price'] - df_master['discount_amount']
df_master['COGS_line'] = df_master['quantity'] * df_master['cogs']
df_master['Profit_line'] = df_master['Revenue_line'] - df_master['COGS_line']

display(df_master[['product_name', 'quantity', 'unit_price', 'cogs', 'Revenue_line', 'Profit_line']].head())
# Out:
#        product_name  quantity  unit_price         cogs  Revenue_line  \
# 0  SaigonFlex UC-01       5.0    11183.67  9704.842875      55918.35
# 1  SaigonFlex UC-01       8.0    10918.75  9704.842875      87350.00
# 2  SaigonFlex UC-01       6.0    11184.55  9704.842875      67107.30
# 3  SaigonFlex UC-01       2.0    11104.72  9704.842875      22209.44
# 4  SaigonFlex UC-01       6.0    11143.16  9704.842875      66858.96
#
#    Profit_line
# 0  7394.135625
# 1  9711.257000
# 2  8878.242750
# 3  2799.754250
# 4  8629.902750

# %%
cat_data = df_master.groupby('category')[['Revenue_line', 'Profit_line']].sum().reset_index()
cat_data = cat_data.sort_values('Profit_line', ascending=False)
cat_data['Profit_Billion'] = cat_data['Profit_line'] / 1e9

plt.figure(figsize=(10, 6))
sns.barplot(data=cat_data, x='Profit_Billion', y='category', hue='category', palette='viridis', legend=False)
plt.title('Tổng lợi nhuận theo từng Ngành hàng')
plt.xlabel('Lợi nhuận (Tỷ VNĐ)')
plt.show()
# Out:
# C:\Users\thaim\AppData\Local\Temp\ipykernel_5856\1575777460.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   cat_data = df_master.groupby('category')[['Revenue_line', 'Profit_line']].sum().reset_index()

# %% [markdown]
# ### As illustrated in the bar chart, the Streetwear category accounts for the lion's share of total profit, reaching approximately 1.75 billion VND. My team suggested focusing the marketing budget on this segment to optimize cash flow.

# %%
prod_analysis = df_master.groupby('product_name').agg({
    'Revenue_line': 'sum',
    'Profit_line': 'sum'
}).reset_index()
prod_analysis['Margin_pct'] = (prod_analysis['Profit_line'] / prod_analysis['Revenue_line']) * 100

plt.figure(figsize=(10, 6))
sns.scatterplot(data=prod_analysis, x='Revenue_line', y='Margin_pct', alpha=0.6)
plt.axhline(prod_analysis['Margin_pct'].mean(), color='red', linestyle='--', label='Average Margin')
plt.title('Product Portfolio Analysis: Revenue vs Margin %')
plt.show()

# %% [markdown]
# ### The scatter plot reveals a significant disparity in product performance. While the majority of items are clustered in the low-revenue zone, a few outliers stand out as high-performers with profit margins exceeding the mean of approximately 16%. Notably, there is a concerning anomaly in the bottom-left quadrant exhibiting a negative margin of nearly -80%, which warrants further investigation into potential pricing errors or aggressive discounting strategies.

# %%
outlier = prod_analysis.sort_values('Margin_pct').head(1)
display(outlier)
# Out:
#         product_name  Revenue_line  Profit_line  Margin_pct
# 1325  VietMode UR-02      15606.06   -14192.058  -90.939404

# %%
daily_trend = df_master.groupby('Date')[['Revenue_line', 'Profit_line']].sum().reset_index()

plt.figure(figsize=(12, 5))
sns.lineplot(data=daily_trend, x='Date', y='Profit_line', color='orange', label='Daily Profit')
plt.title('Profit Trend Over Time')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### The line chart illustrates the **daily profit fluctuations** over a decade. It is palpably evident that the business experiences **extreme volatility**, characterized by frequent peaks and significant "dips" where profit plummets into negative territory.
#
# * **Seasonality:** The recurring spikes suggest a strong seasonal pattern, possibly linked to annual shopping festivals or holiday seasons.
# * **Anomalies:** Several "deep dips" (negative profit) are observed periodically. These could be attributed to **aggressive loss-leader strategies** or major clearance sales aimed at inventory turnover rather than immediate margin.
# * **Overall Trend:** Despite the volatility, the business maintains a relatively stable baseline, though a slight saturation is visible in the latter years (2020-2022).

# %% [markdown]
# # 3.Feature Engineering

# %%
df_master['day_of_week'] = df_master['Date'].dt.dayofweek
df_master['month'] = df_master['Date'].dt.month
df_master['is_weekend'] = df_master['day_of_week'].apply(lambda x: 1 if x >= 5 else 0)

# %%
df_master['discount_value'].value_counts()
df_master['discount_pct'] = 0.0
mask_pct = df_master['promo_type'] == 'percentage'
mask_fixed = df_master['promo_type'] == 'fixed'
df_master.loc[mask_pct, 'discount_pct'] = df_master.loc[mask_pct, 'discount_value'] / 100
df_master.loc[mask_fixed, 'discount_pct'] = df_master.loc[mask_fixed, 'discount_value'] / df_master.loc[mask_fixed, 'price']
df_master['discount_pct'] = df_master['discount_pct'].clip(0, 1)
print("Các giá trị discount_pct sau khi tính toán:")
print(df_master['discount_pct'].value_counts().head(10))
# Out:
# Các giá trị discount_pct sau khi tính toán:
# discount_pct
# 0.000000    438353
# 0.200000     71799
# 0.120000     71591
# 0.180000     57417
# 0.100000     45654
# 0.150000      8905
# 0.008532       460
# 0.003840       459
# 0.008978       404
# 0.008150       401
# Name: count, dtype: int64

# %%
df_master['discount_pct_mean'] = df_master['discount_pct'] 
df_master['discount_pct_max'] = df_master['discount_pct']

# %%
df_master['is_promoted']= df_master['promo_id'].apply(lambda x: 0 if x == 'None' else 1)
df_master['discount_rate'] = (df_master['price'] - df_master['unit_price']) / df_master['price']
df_master['discount_rate'] = df_master['discount_rate'].fillna(0)

# %%
df_daily = df_master.groupby('Date').agg({
    'Revenue_line': 'sum',
    'is_promoted': 'max',     
    'day_of_week': 'first',
    'is_weekend': 'first',
}).reset_index()
df_daily = df_daily.sort_values('Date')
df_daily['revenue_lag_1'] = df_daily['Revenue_line'].shift(1)
df_daily['revenue_lag_7'] = df_daily['Revenue_line'].shift(7)
df_daily = df_daily.fillna(0)

# %% [markdown]
# ### Feature Engineering Strategy:
# * To surpass the established baseline, we implemented a robust feature engineering pipeline. Beyond basic temporal variables like day_of_week and is_weekend, we introduced Lag Features (Lag 1​ and Lag 7) to capture the autocorrelation inherent in sales data. Furthermore, by encoding promotion status, the model can now distinguish between natural demand and artificially inflated sales driven by marketing campaigns.

# %%
df_master.info()
df_master['stackable_flag'] = df_master['stackable_flag'].astype(bool)
df_master.to_parquet('sale_train_vi.parquet')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714669 entries, 0 to 714668
# Data columns (total 35 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   product_id           714669 non-null  string
#  1   product_name         714669 non-null  string
#  2   category             714669 non-null  category
#  3   segment              714669 non-null  category
#  4   size                 714669 non-null  category
#  5   color                714669 non-null  category
#  6   price                714669 non-null  float64
#  7   cogs                 714669 non-null  float64
#  8   order_id             714669 non-null  string
#  9   quantity             714669 non-null  float64
#  10  unit_price           714669 non-null  float64
#  11  discount_amount      714669 non-null  float64
#  12  promo_id             714669 non-null  string
#  13  promo_id_2           714669 non-null  string
#  14  promo_name           276316 non-null  string
#  15  promo_type           276316 non-null  category
#  16  discount_value       276316 non-null  float64
#  17  start_date           276316 non-null  datetime64[ns]
#  18  end_date             276316 non-null  datetime64[ns]
#  19  applicable_category  276316 non-null  category
#  20  promo_channel        276316 non-null  category
#  21  stackable_flag       714669 non-null  object
#  22  min_order_value      276316 non-null  float64
#  23  Date                 714669 non-null  datetime64[ns]
#  24  Revenue_line         714669 non-null  float64
#  25  COGS_line            714669 non-null  float64
#  26  Profit_line          714669 non-null  float64
#  27  day_of_week          714669 non-null  int32
#  28  month                714669 non-null  int32
#  29  is_weekend           714669 non-null  int64
#  30  discount_pct         714669 non-null  float64
#  31  discount_pct_mean    714669 non-null  float64
#  32  discount_pct_max     714669 non-null  float64
#  33  is_promoted          714669 non-null  int64
#  34  discount_rate        714669 non-null  float64
# dtypes: category(7), datetime64[ns](3), float64(14), int32(2), int64(2), object(1), string(6)
# memory usage: 152.0+ MB

# %% [markdown]
# # 4. Machine Learning

# %%
# One-Hot Encoding cho Category & Segment
df_encoded = pd.get_dummies(df_master, columns=['category', 'segment'], prefix=['cat', 'seg'])

# Lấy danh sách các cột vừa mới tạo ra từ One-Hot
encoded_cols = [col for col in df_encoded.columns if col.startswith(('cat_', 'seg_'))]

special_days = [
    '01-01', '02-14',
    '04-30', '05-01',
    '12-31', '12-24', '12-25'
]
def get_special_event(date):
    return 1 if date.strftime('%m-%d') in special_days else 0
# Daily Aggregation: Nén dữ liệu về dạng Ngày
df_encoded['is_special'] = df_encoded['Date'].apply(get_special_event)
df_encoded['is_payday'] = ((df_encoded['Date'].dt.day == 15) | (df_encoded['Date'].dt.is_month_end)).astype(int)
# Với các cột One-Hot, chúng ta dùng 'sum' để biết ngày đó bán được bao nhiêu món thuộc loại đó
agg_logic = {
    'Revenue_line': 'sum',
    'Profit_line': 'sum',
    'is_promoted': 'max',  
    'day_of_week': 'first',
    'month': 'first',
    'is_weekend': 'first',
    'is_special': 'max',
    'is_payday': 'max',
    'discount_pct_mean' : 'mean',
    'discount_pct_max' : 'max'
}
# Thêm các cột encoded vào logic tính tổng
for col in encoded_cols:
    agg_logic[col] = 'sum'
df_daily = df_encoded.groupby('Date').agg(agg_logic).reset_index()
df_daily.columns = ['_'.join(col) if isinstance(col, tuple) else col for col in df_daily.columns]
# Lag Features
# Model sẽ nhìn vào kết quả của 1 ngày và 7 ngày trước đó để dự báo
df_daily = df_daily.sort_values('Date')
df_daily['rev_lag_1'] = df_daily['Revenue_line'].shift(1)
df_daily['rev_lag_7'] = df_daily['Revenue_line'].shift(7)
df_daily['rev_lag_365'] = df_daily['Revenue_line'].shift(365)

df_daily['margin_rate']= df_daily['Profit_line'] / df_daily['Revenue_line']
df_daily['margin_rate_lag_7'] = df_daily['margin_rate'].shift(7)
df_daily['margin_rate_lag_1'] = df_daily['margin_rate'].shift(1)
df_daily['margin_rate_lag_365'] = df_daily['margin_rate'].shift(365)

df_daily['profit_lag_1'] = df_daily['Profit_line'].shift(1)
df_daily['profit_lag_7'] = df_daily['Profit_line'].shift(7)
df_daily['profit_lag_365'] = df_daily['Profit_line'].shift(365)
# Cuối cùng là lấp đầy các giá trị NaN do hàm shift tạo ra
df_daily = df_daily.fillna(0)

# Đổi tên cho đúng format
df_daily = df_daily.rename(columns={'Revenue_line': 'Revenue', 'Profit_line': 'Profit'})
df_daily = df_daily.rename(columns={'discount_pct_mean': 'avg_discount_pct', 'discount_pct_max': 'max_discount_pct'})
print("Kích thước bảng Daily:", df_daily.shape)
display(df_daily.head())
# Out:
# Kích thước bảng Daily: (3833, 33)
#         Date     Revenue        Profit  is_promoted  day_of_week  month  \
# 0 2012-07-04  5123547.94  1.140557e+06            0            2      7
# 1 2012-07-05  2751773.45  6.011932e+05            0            3      7
# 2 2012-07-06  3054029.42  5.363966e+05            0            4      7
# 3 2012-07-07  2667930.94  5.596843e+05            0            5      7
# 4 2012-07-08  2360851.90  5.522291e+05            0            6      7
#
#    is_weekend  is_special  is_payday  avg_discount_pct  ...   rev_lag_1  \
# 0           0           0          0               0.0  ...        0.00
# 1           0           0          0               0.0  ...  5123547.94
# 2           0           0          0               0.0  ...  2751773.45
# 3           1           0          0               0.0  ...  3054029.42
# 4           1           0          0               0.0  ...  2667930.94
#
#    rev_lag_7  rev_lag_365  margin_rate  margin_rate_lag_7  margin_rate_lag_1  \
# 0        0.0          0.0     0.222611                0.0           0.000000
# 1        0.0          0.0     0.218475                0.0           0.222611
# 2        0.0          0.0     0.175636                0.0           0.218475
# 3        0.0          0.0     0.209782                0.0           0.175636
# 4        0.0          0.0     0.233911                0.0           0.209782
#
#    margin_rate_lag_365  profit_lag_1  profit_lag_7  profit_lag_365
# 0                  0.0  0.000000e+00           0.0             0.0
# 1                  0.0  1.140557e+06           0.0             0.0
# 2                  0.0  6.011932e+05           0.0             0.0
# 3                  0.0  5.363966e+05           0.0             0.0
# 4                  0.0  5.596843e+05           0.0             0.0
#
# [5 rows x 33 columns]

# %%
df_daily['year'] = df_daily['Date'].dt.year
df_daily['month_day'] = df_daily['Date'].dt.strftime('%m-%d')

df_daily['is_Spring_promotion'] = df_daily['month_day'].between('03-18', '04-17').astype(int)
df_daily['is_MidYear_promotion'] = df_daily['month_day'].between('06-23', '07-22').astype(int)
df_daily['is_FallLauch_promotion'] = (df_daily['month_day'].between('08-30', '10-01') | ((df_daily['year'] % 4 == 1) & (df_daily['month_day'] == '10-02'))).astype(int)
df_daily['is_YearEnd_promotion'] = (df_daily['month_day'].between('11-18', '12-31') |  df_daily['month_day'].between('01-01', '01-02')).astype(int) # có nhiều ngày kết thúc khác nhưng fix vào 02/01 hàng năm
df_daily['is_Rural_promotion'] = ((df_daily['year'] % 2 == 1)  & df_daily['month_day'].between('01-30', '03-01')).astype(int) # từ năm 2015 mới cố định ngày kết thúc
df_daily['is_Urban_promotion'] = ((df_daily['year'] % 2 == 1)  & df_daily['month_day'].between('07-30', '09-02')).astype(int)
df_daily['category_promotion'] = -1 # default: if it isn't in any promotion
df_daily['chanel_promotion'] = -1 # default: if it isn't in any promotion
df_daily['pct_discount_promotion'] = 0.0 # default: if it isn't in any promotion
df_daily['fix_discount_promotion'] = 0 # default: if it isn't in any promotion

#decode category_promotion: 0 -> All ; 1 -> Outdoor ; 2 -> Steetwear
df_daily.loc[(df_daily['is_Spring_promotion'] | df_daily['is_MidYear_promotion'] | df_daily['is_YearEnd_promotion']), 'category_promotion'] = 0
df_daily.loc[df_daily['is_Rural_promotion'], 'category_promotion'] = 1
df_daily.loc[df_daily['is_Urban_promotion'], 'category_promotion'] = 2

#decode chanel_promotion: 0 -> all_chanel ; 1 -> in_store ; 2 -> online ; 3 -> onl or social ; 4 onl or email or social
df_daily.loc[(df_daily['is_Spring_promotion'] | df_daily['is_FallLauch_promotion']), 'chanel_promotion'] = 4
df_daily.loc[df_daily['is_Rural_promotion'], 'chanel_promotion'] = 1
df_daily.loc[df_daily['is_Urban_promotion'], 'chanel_promotion'] = 2
df_daily.loc[df_daily['is_MidYear_promotion'], 'chanel_promotion'] = 3
df_daily.loc[df_daily['is_YearEnd_promotion'], 'chanel_promotion'] = 0

#setup pct_discount_promotion and fix_discount_promotion
df_daily.loc[df_daily['is_Rural_promotion'], 'pct_discount_promotion'] = 0.15
df_daily.loc[df_daily['is_Spring_promotion'], 'pct_discount_promotion'] = 0.12
df_daily.loc[df_daily['is_MidYear_promotion'], 'pct_discount_promotion'] = 0.18
df_daily.loc[df_daily['is_FallLauch_promotion'], 'pct_discount_promotion'] = 0.1
df_daily.loc[df_daily['is_YearEnd_promotion'], 'pct_discount_promotion'] = 0.2

df_daily.loc[df_daily['is_Urban_promotion'], 'fix_discount_promotion'] = 50

df_daily.to_parquet('sale_train_vi.parquet')

# %%
final_features=['seg_Balanced', 'seg_Activewear', 'seg_Premium', 'seg_All-weather', 'seg_Everyday', 'seg_Performance', 
                'cat_Casual', 'cat_Outdoor', 'cat_Streetwear', 
                
                'rev_lag_1', 'rev_lag_7', 'rev_lag_365', 
                'profit_lag_1', 'profit_lag_7', 'profit_lag_365', 
                'margin_rate', 'margin_rate_lag_1', 'margin_rate_lag_7', 'margin_rate_lag_365',  
                
                'month', 'is_promoted', 
                'avg_discount_pct', 'max_discount_pct',

                'is_Spring_promotion', 'is_MidYear_promotion', 'is_FallLauch_promotion',
                'is_YearEnd_promotion', 'is_Rural_promotion', 'is_Urban_promotion',
                'category_promotion', 'chanel_promotion', 
                'pct_discount_promotion', 'fix_discount_promotion']

# %%
df_daily['COGS'] = df_daily['Revenue'] - df_daily['Profit']
# Xác định danh sách Feature
features = final_features
print("Danh sách Feature cho Model:", features)
# Out:
# Danh sách Feature cho Model: ['seg_Balanced', 'seg_Activewear', 'seg_Premium', 'seg_All-weather', 'seg_Everyday', 'seg_Performance', 'cat_Casual', 'cat_Outdoor', 'cat_Streetwear', 'rev_lag_1', 'rev_lag_7', 'rev_lag_365', 'profit_lag_1', 'profit_lag_7', 'profit_lag_365', 'margin_rate', 'margin_rate_lag_1', 'margin_rate_lag_7', 'margin_rate_lag_365', 'month', 'is_promoted', 'avg_discount_pct', 'max_discount_pct', 'is_Spring_promotion', 'is_MidYear_promotion', 'is_FallLauch_promotion', 'is_YearEnd_promotion', 'is_Rural_promotion', 'is_Urban_promotion', 'category_promotion', 'chanel_promotion', 'pct_discount_promotion', 'fix_discount_promotion']

# %%
# 1. Xác định Target và Features
target = 'Revenue'
# 2. Tách dữ liệu theo thời gian (Ví dụ: lấy 2 tháng cuối 2022 để kiểm tra)
train_data = df_daily[(df_daily['Date'] <= '2021-12-31') & (df_daily['Date'] >= '2013-01-01')]
val_data = df_daily[df_daily['Date'] > '2021-12-31']

# 3. Tạo bộ X (câu hỏi) và y (đáp án)
X_train = train_data[features]
y_train = train_data[target]

X_val = val_data[features]
y_val = val_data[target]

print(f"Đã sẵn sàng! Train: {X_train.shape}, Val: {X_val.shape}")
# Out:
# Đã sẵn sàng! Train: (3287, 33), Val: (365, 33)

# %%
import optuna
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

def objective(trial):
    # 1. Khai báo các "nút vặn" cần tìm
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 500, 2000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True),
    }


    # 2. Chạy thử mô hình với bộ tham số này
    model = XGBRegressor(**param, tree_method='hist')

    # --- ĐOẠN CODE SỬA LỖI ---
    # Loại bỏ các cột bị trùng tên trong X_train và X_val (nếu có)
    X_train_clean = X_train.loc[:, ~X_train.columns.duplicated()].copy()
    X_val_clean = X_val.loc[:, ~X_val.columns.duplicated()].copy()

    # Ép y_train về dạng 1 chiều (Series) bằng .squeeze()
    y_train_1d = y_train.squeeze()
    y_val_1d = y_val.squeeze()
    # -------------------------

    # Fit mô hình với dữ liệu đã dọn dẹp
    model.fit(X_train_clean, y_train_1d)

    # 3. Tính sai số trên tập Validation
    preds = model.predict(X_val_clean)
    mse = mean_squared_error(y_val_1d, preds)
    rmse = np.sqrt(mse)

    return rmse


    # # 2. Chạy thử mô hình với bộ tham số này
    # model = XGBRegressor(**param, tree_method='hist') # Dùng hist để chạy cho nhanh
    # model.fit(X_train, y_train)
    
    # # 3. Tính sai số trên tập Validation (Nhớ dùng Time Series Split để test cho chuẩn)
    # preds = model.predict(X_val)
    # mse = mean_squared_error(y_val, preds)
    # rmse = np.sqrt(mse)
    
    # return rmse

# 4. Bắt đầu cuộc đi tìm "kho báu"
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=200) 

print("Bộ tham số xịn nhất đây rồi:", study.best_params)
# Out:
# [I 2026-04-27 21:21:49,363] A new study created in memory with name: no-name-59291e31-a8e0-4f77-8067-7fe484a61f1a
# [I 2026-04-27 21:21:56,958] Trial 0 finished with value: 364400.95652887877 and parameters: {'n_estimators': 1182, 'max_depth': 9, 'learning_rate': 0.010357604902219613, 'subsample': 0.8063954005841212, 'colsample_bytree': 0.7820955994112585, 'reg_alpha': 0.03041376435347435, 'reg_lambda': 0.42619641579524375}. Best is trial 0 with value: 364400.95652887877.
# [I 2026-04-27 21:21:59,048] Trial 1 finished with value: 328591.24371729104 and parameters: {'n_estimators': 1082, 'max_depth': 4, 'learning_rate': 0.010516211221442409, 'subsample': 0.8031395670637835, 'colsample_bytree': 0.6662232053388202, 'reg_alpha': 4.918492486961664, 'reg_lambda': 0.008134592311720196}. Best is trial 1 with value: 328591.24371729104.
# [I 2026-04-27 21:21:59,593] Trial 2 finished with value: 361278.3864515029 and parameters: {'n_estimators': 530, 'max_depth': 3, 'learning_rate': 0.010495436216883385, 'subsample': 0.6942239908009509, 'colsample_bytree': 0.9032584087776894, 'reg_alpha': 0.11652562606865449, 'reg_lambda': 0.009096231503025805}. Best is trial 1 with value: 328591.24371729104.
# [I 2026-04-27 21:22:06,267] Trial 3 finished with value: 341987.77600450173 and parameters: {'n_estimators': 1558, 'max_depth': 7, 'learning_rate': 0.06794350426043473, 'subsample': 0.7335408667314998, 'colsample_bytree': 0.5906035729908118, 'reg_alpha': 0.02907895366896015, 'reg_lambda': 0.2112543119991285}. Best is trial 1 with value: 328591.24371729104.
# [I 2026-04-27 21:22:10,050] Trial 4 finished with value: 322601.68403319526 and parameters: {'n_estimators': 1647, 'max_depth': 5, 'learning_rate': 0.07575840367317158, 'subsample': 0.8286652585887886, 'colsample_bytree': 0.8134425495234319, 'reg_alpha': 1.0469536061524336, 'reg_lambda': 0.0032608633982252814}. Best is trial 4 with value: 322601.68403319526.
# [I 2026-04-27 21:22:21,804] Trial 5 finished with value: 354036.4801655692 and parameters: {'n_estimators': 1554, 'max_depth': 10, 'learning_rate': 0.010639559735727205, 'subsample': 0.5272607008327828, 'colsample_bytree': 0.5453296049182289, 'reg_alpha': 0.8035831243500077, 'reg_lambda': 0.12607067019263252}. Best is trial 4 with value: 322601.68403319526.
# [I 2026-04-27 21:22:25,360] Trial 6 finished with value: 314210.01828843914 and parameters: {'n_estimators': 1904, 'max_depth': 5, 'learning_rate': 0.029006524359270706, 'subsample': 0.859725075656087, 'colsample_bytree': 0.6067697102828506, 'reg_alpha': 0.1491052705146861, 'reg_lambda': 0.004127418226496042}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:22:39,442] Trial 7 finished with value: 348115.321409957 and parameters: {'n_estimators': 1917, 'max_depth': 10, 'learning_rate': 0.01976399827254452, 'subsample': 0.530862396862096, 'colsample_bytree': 0.8200656288373117, 'reg_alpha': 5.857868271338138, 'reg_lambda': 0.45612926968629874}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:22:43,129] Trial 8 finished with value: 317507.76055535465 and parameters: {'n_estimators': 1377, 'max_depth': 6, 'learning_rate': 0.015374296786720639, 'subsample': 0.5256025957395056, 'colsample_bytree': 0.9620838683199353, 'reg_alpha': 0.26386319994363716, 'reg_lambda': 2.1275901093482403}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:22:48,545] Trial 9 finished with value: 333941.81245611777 and parameters: {'n_estimators': 1730, 'max_depth': 7, 'learning_rate': 0.09217260750600045, 'subsample': 0.5712535051068925, 'colsample_bytree': 0.7971839926726149, 'reg_alpha': 0.38947324404849326, 'reg_lambda': 1.0997381246770663}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:22:50,000] Trial 10 finished with value: 316964.0143803938 and parameters: {'n_estimators': 848, 'max_depth': 5, 'learning_rate': 0.03873866741906883, 'subsample': 0.9833425646028122, 'colsample_bytree': 0.6689256382908378, 'reg_alpha': 0.0014161449085619755, 'reg_lambda': 0.0010320809835733806}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:22:51,517] Trial 11 finished with value: 319477.21858591295 and parameters: {'n_estimators': 853, 'max_depth': 5, 'learning_rate': 0.039549475931493855, 'subsample': 0.9945638280717576, 'colsample_bytree': 0.6619459936051653, 'reg_alpha': 0.0010518721748645676, 'reg_lambda': 0.0010897873174963572}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:22:52,846] Trial 12 finished with value: 317025.4754440073 and parameters: {'n_estimators': 777, 'max_depth': 3, 'learning_rate': 0.03875920630516816, 'subsample': 0.9933047312172353, 'colsample_bytree': 0.6570292049714744, 'reg_alpha': 0.0012846760526943704, 'reg_lambda': 0.024994961554238}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:22:55,374] Trial 13 finished with value: 315562.4452962199 and parameters: {'n_estimators': 938, 'max_depth': 5, 'learning_rate': 0.026271915720182094, 'subsample': 0.9034799782867755, 'colsample_bytree': 0.5288948042411961, 'reg_alpha': 0.006894993677992729, 'reg_lambda': 0.0015524005188243479}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:04,299] Trial 14 finished with value: 356691.8570464825 and parameters: {'n_estimators': 1340, 'max_depth': 8, 'learning_rate': 0.024713773338599018, 'subsample': 0.8959974082855957, 'colsample_bytree': 0.5007161567152616, 'reg_alpha': 0.007966427888304468, 'reg_lambda': 0.03714713701424357}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:10,641] Trial 15 finished with value: 327635.6326615841 and parameters: {'n_estimators': 1939, 'max_depth': 6, 'learning_rate': 0.02747289315375687, 'subsample': 0.8979103057538063, 'colsample_bytree': 0.5924598480986994, 'reg_alpha': 0.013824272787988173, 'reg_lambda': 0.0038068028063512963}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:12,611] Trial 16 finished with value: 318036.0436358953 and parameters: {'n_estimators': 1036, 'max_depth': 4, 'learning_rate': 0.05559158696254743, 'subsample': 0.91346511465133, 'colsample_bytree': 0.5896262902878633, 'reg_alpha': 0.007305961063400112, 'reg_lambda': 0.04443900617972105}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:13,262] Trial 17 finished with value: 319582.5659881452 and parameters: {'n_estimators': 530, 'max_depth': 4, 'learning_rate': 0.018814834229886356, 'subsample': 0.6552090886951221, 'colsample_bytree': 0.5111282255344239, 'reg_alpha': 0.0626624920288985, 'reg_lambda': 0.0030183898233800874}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:15,991] Trial 18 finished with value: 325510.18974462413 and parameters: {'n_estimators': 719, 'max_depth': 6, 'learning_rate': 0.04927171000438414, 'subsample': 0.8622869477129783, 'colsample_bytree': 0.7206574162078604, 'reg_alpha': 0.0038164214803441845, 'reg_lambda': 0.014914034751959515}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:18,512] Trial 19 finished with value: 314304.9169377467 and parameters: {'n_estimators': 987, 'max_depth': 5, 'learning_rate': 0.030324421494558218, 'subsample': 0.7587355547987417, 'colsample_bytree': 0.5612458331489966, 'reg_alpha': 0.11557046989048023, 'reg_lambda': 0.0015976021830400007}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:25,668] Trial 20 finished with value: 345134.90837149235 and parameters: {'n_estimators': 1317, 'max_depth': 8, 'learning_rate': 0.03213713552144962, 'subsample': 0.7541591336062697, 'colsample_bytree': 0.7360539913524807, 'reg_alpha': 1.8172118342316166, 'reg_lambda': 8.689223691105067}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:28,150] Trial 21 finished with value: 319215.00521672354 and parameters: {'n_estimators': 969, 'max_depth': 5, 'learning_rate': 0.022263008745332102, 'subsample': 0.929792133443292, 'colsample_bytree': 0.5651634362239802, 'reg_alpha': 0.12471506521691476, 'reg_lambda': 0.0020138807613088146}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:30,573] Trial 22 finished with value: 315998.40853346844 and parameters: {'n_estimators': 1191, 'max_depth': 4, 'learning_rate': 0.0317490440830143, 'subsample': 0.7501203895057241, 'colsample_bytree': 0.6177401751958609, 'reg_alpha': 0.045980009744793576, 'reg_lambda': 0.0059428866220684}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:32,798] Trial 23 finished with value: 315931.6881567143 and parameters: {'n_estimators': 927, 'max_depth': 5, 'learning_rate': 0.01459996475329721, 'subsample': 0.8536069546808518, 'colsample_bytree': 0.5433047981455112, 'reg_alpha': 0.29554258100482006, 'reg_lambda': 0.0017737604661598532}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:36,504] Trial 24 finished with value: 327815.9557120506 and parameters: {'n_estimators': 1106, 'max_depth': 6, 'learning_rate': 0.02782135264373956, 'subsample': 0.6444480781078985, 'colsample_bytree': 0.6267563581678423, 'reg_alpha': 0.16023278624241963, 'reg_lambda': 0.016613465860708512}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:39,295] Trial 25 finished with value: 344028.52564354916 and parameters: {'n_estimators': 667, 'max_depth': 7, 'learning_rate': 0.04805773630822759, 'subsample': 0.7769388837420994, 'colsample_bytree': 0.5319368183525167, 'reg_alpha': 0.05144789953919836, 'reg_lambda': 0.004881952418698052}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:41,238] Trial 26 finished with value: 315578.9025521742 and parameters: {'n_estimators': 1458, 'max_depth': 3, 'learning_rate': 0.016396157160617802, 'subsample': 0.9484934919071915, 'colsample_bytree': 0.7006319414666997, 'reg_alpha': 0.018263250630346457, 'reg_lambda': 0.002073578389888938}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:43,176] Trial 27 finished with value: 315258.9325754056 and parameters: {'n_estimators': 1779, 'max_depth': 4, 'learning_rate': 0.034966695879768056, 'subsample': 0.8635941952782976, 'colsample_bytree': 0.5663033512658261, 'reg_alpha': 0.003000175094695607, 'reg_lambda': 0.0010282040941347295}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:44,930] Trial 28 finished with value: 315278.51708703407 and parameters: {'n_estimators': 1772, 'max_depth': 4, 'learning_rate': 0.03440207591873362, 'subsample': 0.8494317647020919, 'colsample_bytree': 0.6319940006702942, 'reg_alpha': 0.00319917676242253, 'reg_lambda': 0.009533741221139478}. Best is trial 6 with value: 314210.01828843914.
# [I 2026-04-27 21:23:46,275] Trial 29 finished with value: 304601.752407179 and parameters: {'n_estimators': 1849, 'max_depth': 3, 'learning_rate': 0.04385742403815707, 'subsample': 0.8068112099491599, 'colsample_bytree': 0.5668878788508402, 'reg_alpha': 0.5434019197226632, 'reg_lambda': 0.06190657357227257}. Best is trial 29 with value: 304601.752407179.
# [I 2026-04-27 21:23:47,694] Trial 30 finished with value: 307667.97937956423 and parameters: {'n_estimators': 1865, 'max_depth': 3, 'learning_rate': 0.044764543006649976, 'subsample': 0.7052053624749248, 'colsample_bytree': 0.8789778071276537, 'reg_alpha': 0.6755850546775239, 'reg_lambda': 0.07099789610191541}. Best is trial 29 with value: 304601.752407179.
# [I 2026-04-27 21:23:49,122] Trial 31 finished with value: 304193.45641183795 and parameters: {'n_estimators': 1867, 'max_depth': 3, 'learning_rate': 0.04538686802357858, 'subsample': 0.8000003838770646, 'colsample_bytree': 0.9098253425069842, 'reg_alpha': 0.7584454016965604, 'reg_lambda': 0.061201268129685134}. Best is trial 31 with value: 304193.45641183795.
# [I 2026-04-27 21:23:50,619] Trial 32 finished with value: 308162.5184962481 and parameters: {'n_estimators': 1997, 'max_depth': 3, 'learning_rate': 0.04757617977232011, 'subsample': 0.7127252428169616, 'colsample_bytree': 0.8650475526569872, 'reg_alpha': 2.7945528521823237, 'reg_lambda': 0.07891582572172218}. Best is trial 31 with value: 304193.45641183795.
# [I 2026-04-27 21:23:52,142] Trial 33 finished with value: 299105.5980230447 and parameters: {'n_estimators': 1991, 'max_depth': 3, 'learning_rate': 0.06046442561762844, 'subsample': 0.7089570991900969, 'colsample_bytree': 0.8582852021354018, 'reg_alpha': 2.7955089606027705, 'reg_lambda': 0.0717235232347767}. Best is trial 33 with value: 299105.5980230447.
# [I 2026-04-27 21:23:53,610] Trial 34 finished with value: 312139.66705219593 and parameters: {'n_estimators': 1840, 'max_depth': 3, 'learning_rate': 0.0626243038395189, 'subsample': 0.807480333763752, 'colsample_bytree': 0.9299944923811133, 'reg_alpha': 8.80609568611333, 'reg_lambda': 0.20804673636357338}. Best is trial 33 with value: 299105.5980230447.
# [I 2026-04-27 21:23:54,847] Trial 35 finished with value: 295508.01024843304 and parameters: {'n_estimators': 1647, 'max_depth': 3, 'learning_rate': 0.0794661122377118, 'subsample': 0.6715407490229719, 'colsample_bytree': 0.8661031420614395, 'reg_alpha': 0.6780383982984685, 'reg_lambda': 0.1506355839884549}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:23:56,120] Trial 36 finished with value: 301770.00788525783 and parameters: {'n_estimators': 1618, 'max_depth': 3, 'learning_rate': 0.08499325797163179, 'subsample': 0.6694226355745476, 'colsample_bytree': 0.9985091145355343, 'reg_alpha': 1.645869653771381, 'reg_lambda': 0.16475236690187178}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:23:57,415] Trial 37 finished with value: 296383.61235753045 and parameters: {'n_estimators': 1632, 'max_depth': 3, 'learning_rate': 0.09676929638211214, 'subsample': 0.6536556447200882, 'colsample_bytree': 0.9885149990678052, 'reg_alpha': 1.7256904582392016, 'reg_lambda': 0.14276012484782352}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:23:59,136] Trial 38 finished with value: 315929.03418979776 and parameters: {'n_estimators': 1608, 'max_depth': 4, 'learning_rate': 0.09954380743110193, 'subsample': 0.6574245840747093, 'colsample_bytree': 0.9994787907378602, 'reg_alpha': 1.7842815045092744, 'reg_lambda': 0.17132124104690633}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:00,665] Trial 39 finished with value: 314061.90637372807 and parameters: {'n_estimators': 1458, 'max_depth': 4, 'learning_rate': 0.08139442327518738, 'subsample': 0.6125181803535306, 'colsample_bytree': 0.9752881043966493, 'reg_alpha': 3.365790357990479, 'reg_lambda': 0.39073419571213286}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:02,115] Trial 40 finished with value: 305239.33301802044 and parameters: {'n_estimators': 1702, 'max_depth': 3, 'learning_rate': 0.07282646790275808, 'subsample': 0.6088702524924161, 'colsample_bytree': 0.854189885064204, 'reg_alpha': 1.337057694247399, 'reg_lambda': 0.3828456135625929}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:03,577] Trial 41 finished with value: 309568.3661425511 and parameters: {'n_estimators': 1524, 'max_depth': 3, 'learning_rate': 0.08405854247065696, 'subsample': 0.6708954457003063, 'colsample_bytree': 0.9180742522071936, 'reg_alpha': 3.598929768144445, 'reg_lambda': 0.12405630394030333}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:05,118] Trial 42 finished with value: 297851.3982230449 and parameters: {'n_estimators': 1639, 'max_depth': 3, 'learning_rate': 0.06255432755508177, 'subsample': 0.6850548520252832, 'colsample_bytree': 0.9434230712764121, 'reg_alpha': 1.0069990914101776, 'reg_lambda': 0.6798829642871994}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:07,206] Trial 43 finished with value: 315905.76971446915 and parameters: {'n_estimators': 1658, 'max_depth': 4, 'learning_rate': 0.06448065415117853, 'subsample': 0.6868710191164614, 'colsample_bytree': 0.9451657021629741, 'reg_alpha': 5.717828885926973, 'reg_lambda': 0.8523341745315406}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:08,558] Trial 44 finished with value: 304794.93174047145 and parameters: {'n_estimators': 1591, 'max_depth': 3, 'learning_rate': 0.08797362183357461, 'subsample': 0.6243697660669703, 'colsample_bytree': 0.9995272576704969, 'reg_alpha': 1.16908762342608, 'reg_lambda': 0.6868542468770829}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:09,689] Trial 45 finished with value: 308046.0838843389 and parameters: {'n_estimators': 1422, 'max_depth': 3, 'learning_rate': 0.0734132429431536, 'subsample': 0.5731269542350189, 'colsample_bytree': 0.8300277603320609, 'reg_alpha': 1.9699550985407281, 'reg_lambda': 0.25330666079209757}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:11,451] Trial 46 finished with value: 317323.2036869964 and parameters: {'n_estimators': 1523, 'max_depth': 4, 'learning_rate': 0.05906731212965808, 'subsample': 0.7119053739841644, 'colsample_bytree': 0.7673029880081851, 'reg_alpha': 9.878674326597002, 'reg_lambda': 1.4602782594983292}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:13,050] Trial 47 finished with value: 308608.5643062447 and parameters: {'n_estimators': 1676, 'max_depth': 3, 'learning_rate': 0.09915871396352455, 'subsample': 0.7295142256257545, 'colsample_bytree': 0.9636800313101574, 'reg_alpha': 0.4240609882461824, 'reg_lambda': 0.11351692071129603}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:25,272] Trial 48 finished with value: 344377.407070572 and parameters: {'n_estimators': 1784, 'max_depth': 9, 'learning_rate': 0.05395171743884176, 'subsample': 0.5889156743561487, 'colsample_bytree': 0.8867744958943523, 'reg_alpha': 0.20564795514145542, 'reg_lambda': 0.2675849928615548}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:27,695] Trial 49 finished with value: 313052.132694968 and parameters: {'n_estimators': 1286, 'max_depth': 4, 'learning_rate': 0.06891254595929329, 'subsample': 0.6835766924148966, 'colsample_bytree': 0.9399349828404598, 'reg_alpha': 0.9597792214840798, 'reg_lambda': 4.644408364860896}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:30,257] Trial 50 finished with value: 314529.6767816414 and parameters: {'n_estimators': 1954, 'max_depth': 3, 'learning_rate': 0.07944732965028109, 'subsample': 0.6286615362664298, 'colsample_bytree': 0.9753493639449354, 'reg_alpha': 4.4146427757870095, 'reg_lambda': 0.034818121012698634}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:32,400] Trial 51 finished with value: 302299.25970202335 and parameters: {'n_estimators': 1620, 'max_depth': 3, 'learning_rate': 0.06716541268708431, 'subsample': 0.7267758135623708, 'colsample_bytree': 0.9163434423776653, 'reg_alpha': 2.419988061562535, 'reg_lambda': 0.15521967294125963}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:34,402] Trial 52 finished with value: 311101.65351087303 and parameters: {'n_estimators': 1615, 'max_depth': 3, 'learning_rate': 0.09153085687656343, 'subsample': 0.7289567560062518, 'colsample_bytree': 0.8982128295179658, 'reg_alpha': 2.509978974007097, 'reg_lambda': 0.1551348033963055}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:35,880] Trial 53 finished with value: 299982.4388357187 and parameters: {'n_estimators': 1742, 'max_depth': 3, 'learning_rate': 0.06798083672856468, 'subsample': 0.6804721344317206, 'colsample_bytree': 0.8408755854486918, 'reg_alpha': 1.1622770968738074, 'reg_lambda': 0.6084430754941259}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:38,035] Trial 54 finished with value: 321776.0333529722 and parameters: {'n_estimators': 1736, 'max_depth': 4, 'learning_rate': 0.07512778758353228, 'subsample': 0.6768386056143486, 'colsample_bytree': 0.8421700462995421, 'reg_alpha': 1.3953258951643328, 'reg_lambda': 0.6089595790441769}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:39,355] Trial 55 finished with value: 297016.51315264613 and parameters: {'n_estimators': 1547, 'max_depth': 3, 'learning_rate': 0.055307074923225064, 'subsample': 0.65561029297414, 'colsample_bytree': 0.961195017932161, 'reg_alpha': 0.593458984083669, 'reg_lambda': 1.4909767068187099}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:41,556] Trial 56 finished with value: 312002.324597491 and parameters: {'n_estimators': 1533, 'max_depth': 4, 'learning_rate': 0.059186320685690075, 'subsample': 0.6417522837645147, 'colsample_bytree': 0.8013379366781518, 'reg_alpha': 0.5171187682505697, 'reg_lambda': 1.8601302697451336}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:43,395] Trial 57 finished with value: 307443.60057688586 and parameters: {'n_estimators': 1730, 'max_depth': 3, 'learning_rate': 0.05257900055131053, 'subsample': 0.5427405512774439, 'colsample_bytree': 0.7854510082181326, 'reg_alpha': 0.3183347641309715, 'reg_lambda': 1.2674583717018002}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:45,488] Trial 58 finished with value: 319323.9929156143 and parameters: {'n_estimators': 1381, 'max_depth': 4, 'learning_rate': 0.06952167677863995, 'subsample': 0.6943644225644339, 'colsample_bytree': 0.9476990521049083, 'reg_alpha': 0.9696226182901814, 'reg_lambda': 3.344630917833408}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:48,230] Trial 59 finished with value: 295943.25059800287 and parameters: {'n_estimators': 1968, 'max_depth': 3, 'learning_rate': 0.060685943788176155, 'subsample': 0.5923072186860862, 'colsample_bytree': 0.8734514941998428, 'reg_alpha': 0.6520342354341441, 'reg_lambda': 0.4930000484933498}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:54,037] Trial 60 finished with value: 316199.12287920865 and parameters: {'n_estimators': 1997, 'max_depth': 5, 'learning_rate': 0.05706580591144063, 'subsample': 0.5954470354991294, 'colsample_bytree': 0.8681561852719352, 'reg_alpha': 0.204694940748757, 'reg_lambda': 0.31620940353503674}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:56,904] Trial 61 finished with value: 302633.71882620914 and parameters: {'n_estimators': 1898, 'max_depth': 3, 'learning_rate': 0.0640483180116892, 'subsample': 0.5554378265468916, 'colsample_bytree': 0.8140351130064933, 'reg_alpha': 0.5726327212466334, 'reg_lambda': 0.5927446166197431}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:24:59,640] Trial 62 finished with value: 300342.0622262167 and parameters: {'n_estimators': 1824, 'max_depth': 3, 'learning_rate': 0.07794765536427921, 'subsample': 0.6528711984927035, 'colsample_bytree': 0.8904888511112046, 'reg_alpha': 0.40137657761178736, 'reg_lambda': 0.9585988127489867}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:25:01,455] Trial 63 finished with value: 302493.3019637431 and parameters: {'n_estimators': 1934, 'max_depth': 3, 'learning_rate': 0.09192443576229639, 'subsample': 0.5008912960611874, 'colsample_bytree': 0.8313385471788517, 'reg_alpha': 0.785653957495773, 'reg_lambda': 2.5006120470032056}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:25:03,086] Trial 64 finished with value: 318899.0918095183 and parameters: {'n_estimators': 1485, 'max_depth': 4, 'learning_rate': 0.05170814411841656, 'subsample': 0.6355531259996525, 'colsample_bytree': 0.962833077604021, 'reg_alpha': 1.067075663557494, 'reg_lambda': 0.4499109320811679}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:25:04,528] Trial 65 finished with value: 303443.6826698023 and parameters: {'n_estimators': 1797, 'max_depth': 3, 'learning_rate': 0.04165406504860748, 'subsample': 0.7726654024929744, 'colsample_bytree': 0.93035651327737, 'reg_alpha': 4.139366404810402, 'reg_lambda': 0.08939286631344635}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:25:17,378] Trial 66 finished with value: 363632.79619191185 and parameters: {'n_estimators': 1683, 'max_depth': 10, 'learning_rate': 0.0594923054737422, 'subsample': 0.663235473971877, 'colsample_bytree': 0.8651768924025521, 'reg_alpha': 7.117218443524403, 'reg_lambda': 0.7656983718349932}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:25:19,469] Trial 67 finished with value: 302508.6747330206 and parameters: {'n_estimators': 1575, 'max_depth': 3, 'learning_rate': 0.061912147027978856, 'subsample': 0.6958486812078319, 'colsample_bytree': 0.8476378276862161, 'reg_alpha': 2.3275395332082476, 'reg_lambda': 0.04922317424582597}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:25:29,551] Trial 68 finished with value: 337584.67257110425 and parameters: {'n_estimators': 1736, 'max_depth': 8, 'learning_rate': 0.07188882038590645, 'subsample': 0.6184296600424799, 'colsample_bytree': 0.978849488547926, 'reg_alpha': 0.08876594221569868, 'reg_lambda': 0.5212671802525052}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:25:32,729] Trial 69 finished with value: 313853.1133686991 and parameters: {'n_estimators': 1916, 'max_depth': 4, 'learning_rate': 0.05114812677406646, 'subsample': 0.5998543523113048, 'colsample_bytree': 0.7516312430525559, 'reg_alpha': 0.6971764976271256, 'reg_lambda': 0.022376757171213117}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:25:46,410] Trial 70 finished with value: 352248.15604590275 and parameters: {'n_estimators': 1209, 'max_depth': 9, 'learning_rate': 0.07698914445773045, 'subsample': 0.5791134892490057, 'colsample_bytree': 0.9110585506359405, 'reg_alpha': 1.418284003064772, 'reg_lambda': 1.6742375291460958}. Best is trial 35 with value: 295508.01024843304.
# [I 2026-04-27 21:25:49,377] Trial 71 finished with value: 291307.35990727996 and parameters: {'n_estimators': 1827, 'max_depth': 3, 'learning_rate': 0.08092674443356916, 'subsample': 0.6507108449160464, 'colsample_bytree': 0.8943146181351206, 'reg_alpha': 0.3859859252816337, 'reg_lambda': 1.159855669082564}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:25:52,329] Trial 72 finished with value: 311631.84318219323 and parameters: {'n_estimators': 1895, 'max_depth': 3, 'learning_rate': 0.011598155038954146, 'subsample': 0.6489609155870643, 'colsample_bytree': 0.8773370087535224, 'reg_alpha': 0.25334872021774674, 'reg_lambda': 0.952487004142151}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:25:55,444] Trial 73 finished with value: 301908.64914988674 and parameters: {'n_estimators': 1966, 'max_depth': 3, 'learning_rate': 0.08684239605564031, 'subsample': 0.703248378868739, 'colsample_bytree': 0.9265290459765055, 'reg_alpha': 0.47152274727997623, 'reg_lambda': 2.7161460739266836}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:25:57,968] Trial 74 finished with value: 304357.7928557568 and parameters: {'n_estimators': 1754, 'max_depth': 3, 'learning_rate': 0.06638067344369052, 'subsample': 0.6712466300118831, 'colsample_bytree': 0.9025598158302043, 'reg_alpha': 0.34569619083047576, 'reg_lambda': 1.2666382159144245}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:01,963] Trial 75 finished with value: 326254.0329305668 and parameters: {'n_estimators': 1813, 'max_depth': 4, 'learning_rate': 0.09736152611947767, 'subsample': 0.7151187930371895, 'colsample_bytree': 0.9528982425612902, 'reg_alpha': 0.8833574744970876, 'reg_lambda': 0.19902453513258989}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:05,729] Trial 76 finished with value: 307322.2269848861 and parameters: {'n_estimators': 1879, 'max_depth': 3, 'learning_rate': 0.08327296049242926, 'subsample': 0.7452948236149778, 'colsample_bytree': 0.853585111767821, 'reg_alpha': 0.589839037058898, 'reg_lambda': 7.355185237926102}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:08,508] Trial 77 finished with value: 293945.226159094 and parameters: {'n_estimators': 1699, 'max_depth': 3, 'learning_rate': 0.05633260199625691, 'subsample': 0.6373711128514423, 'colsample_bytree': 0.9814645757058735, 'reg_alpha': 1.827591864609041, 'reg_lambda': 0.32693102577504124}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:10,596] Trial 78 finished with value: 296647.6546023971 and parameters: {'n_estimators': 1677, 'max_depth': 3, 'learning_rate': 0.05509329011932525, 'subsample': 0.6375057901114995, 'colsample_bytree': 0.9813416621097415, 'reg_alpha': 1.9705379986053753, 'reg_lambda': 0.2730571071782504}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:14,131] Trial 79 finished with value: 315077.9758766064 and parameters: {'n_estimators': 1641, 'max_depth': 4, 'learning_rate': 0.05477284438640955, 'subsample': 0.6374591651983968, 'colsample_bytree': 0.9783151116402533, 'reg_alpha': 1.8568851621202036, 'reg_lambda': 0.33752607351324454}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:16,215] Trial 80 finished with value: 302043.0825216791 and parameters: {'n_estimators': 1693, 'max_depth': 3, 'learning_rate': 0.04801501270291086, 'subsample': 0.6217993423833865, 'colsample_bytree': 0.9836508717435011, 'reg_alpha': 1.5540645656745844, 'reg_lambda': 0.27824348329409515}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:18,073] Trial 81 finished with value: 304512.6479239966 and parameters: {'n_estimators': 1567, 'max_depth': 3, 'learning_rate': 0.0556959865618705, 'subsample': 0.6094735072126439, 'colsample_bytree': 0.9584332670127989, 'reg_alpha': 3.290555698101508, 'reg_lambda': 0.11715315394814721}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:20,155] Trial 82 finished with value: 304310.2089333898 and parameters: {'n_estimators': 1838, 'max_depth': 3, 'learning_rate': 0.06067948106580047, 'subsample': 0.6581659794705924, 'colsample_bytree': 0.9888871206283333, 'reg_alpha': 2.161382701313849, 'reg_lambda': 0.21511112699451734}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:22,330] Trial 83 finished with value: 304128.6267991715 and parameters: {'n_estimators': 1702, 'max_depth': 3, 'learning_rate': 0.037809037772103184, 'subsample': 0.6300606415201152, 'colsample_bytree': 0.9366995202305557, 'reg_alpha': 2.8445555139732535, 'reg_lambda': 0.49131948219487664}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:24,413] Trial 84 finished with value: 298690.68413690967 and parameters: {'n_estimators': 1490, 'max_depth': 3, 'learning_rate': 0.04255329215141849, 'subsample': 0.5610412294703879, 'colsample_bytree': 0.9686866723167996, 'reg_alpha': 1.2166467392697642, 'reg_lambda': 0.09355072604485992}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:26,893] Trial 85 finished with value: 300231.3445586504 and parameters: {'n_estimators': 1498, 'max_depth': 4, 'learning_rate': 0.040558066606030535, 'subsample': 0.559859046359727, 'colsample_bytree': 0.9662812072918602, 'reg_alpha': 0.631552555606591, 'reg_lambda': 0.4262661007968046}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:28,461] Trial 86 finished with value: 298928.3804297293 and parameters: {'n_estimators': 1426, 'max_depth': 3, 'learning_rate': 0.05037606984519, 'subsample': 0.579935520230867, 'colsample_bytree': 0.9903313890957663, 'reg_alpha': 0.8468987793223453, 'reg_lambda': 0.09141203488437283}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:30,271] Trial 87 finished with value: 300474.7479958223 and parameters: {'n_estimators': 1645, 'max_depth': 3, 'learning_rate': 0.0456309789938577, 'subsample': 0.6045463579910023, 'colsample_bytree': 0.9488764244848602, 'reg_alpha': 1.1761643571754865, 'reg_lambda': 1.089396727858843}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:36,130] Trial 88 finished with value: 337796.662980897 and parameters: {'n_estimators': 1561, 'max_depth': 7, 'learning_rate': 0.036262302155915256, 'subsample': 0.588849054546679, 'colsample_bytree': 0.9694016834091607, 'reg_alpha': 0.2267473135692825, 'reg_lambda': 0.1403654520831859}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:39,702] Trial 89 finished with value: 318503.54011082754 and parameters: {'n_estimators': 1643, 'max_depth': 4, 'learning_rate': 0.07153201300713383, 'subsample': 0.5303443267490379, 'colsample_bytree': 0.9208821462809601, 'reg_alpha': 0.42512320344383336, 'reg_lambda': 0.3350021328145181}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:42,011] Trial 90 finished with value: 309346.93428077555 and parameters: {'n_estimators': 1592, 'max_depth': 3, 'learning_rate': 0.09305877130156119, 'subsample': 0.6634625283604656, 'colsample_bytree': 0.9553650486442006, 'reg_alpha': 1.498205386706948, 'reg_lambda': 0.7964117553435094}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:44,156] Trial 91 finished with value: 298972.81939302274 and parameters: {'n_estimators': 1458, 'max_depth': 3, 'learning_rate': 0.04319599983958705, 'subsample': 0.5474394820572747, 'colsample_bytree': 0.9834637687659357, 'reg_alpha': 0.7164724098759069, 'reg_lambda': 0.09193892977697035}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:47,142] Trial 92 finished with value: 295690.47565525566 and parameters: {'n_estimators': 1358, 'max_depth': 3, 'learning_rate': 0.04850124045402453, 'subsample': 0.5788481826844342, 'colsample_bytree': 0.9978681510948075, 'reg_alpha': 0.8776136458784347, 'reg_lambda': 0.23745951501141999}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:50,466] Trial 93 finished with value: 298748.3772774362 and parameters: {'n_estimators': 1396, 'max_depth': 3, 'learning_rate': 0.046788853439880054, 'subsample': 0.5140114804282289, 'colsample_bytree': 0.9365579294836615, 'reg_alpha': 1.203857100880842, 'reg_lambda': 0.21742046552681438}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:53,110] Trial 94 finished with value: 298312.1175711719 and parameters: {'n_estimators': 1499, 'max_depth': 3, 'learning_rate': 0.05681027510321717, 'subsample': 0.5892460405218607, 'colsample_bytree': 0.9961838222324021, 'reg_alpha': 0.8584799120235538, 'reg_lambda': 0.17752571335533168}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:55,028] Trial 95 finished with value: 291979.67697875283 and parameters: {'n_estimators': 1092, 'max_depth': 3, 'learning_rate': 0.0653836579827618, 'subsample': 0.6413597704341768, 'colsample_bytree': 0.9970096704933714, 'reg_alpha': 0.4951547986629275, 'reg_lambda': 0.27131469682712844}. Best is trial 71 with value: 291307.35990727996.
# [I 2026-04-27 21:26:56,345] Trial 96 finished with value: 289060.7262303334 and parameters: {'n_estimators': 1135, 'max_depth': 3, 'learning_rate': 0.0804186814601128, 'subsample': 0.6493252124971919, 'colsample_bytree': 0.9901676276818134, 'reg_alpha': 0.2839803996561671, 'reg_lambda': 0.25917861378242724}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:26:58,448] Trial 97 finished with value: 314333.824851521 and parameters: {'n_estimators': 1107, 'max_depth': 4, 'learning_rate': 0.07997103136870078, 'subsample': 0.6416449647086467, 'colsample_bytree': 0.9882394592360577, 'reg_alpha': 0.17517699196724787, 'reg_lambda': 0.25476859061113094}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:26:59,532] Trial 98 finished with value: 301248.0004941188 and parameters: {'n_estimators': 1056, 'max_depth': 3, 'learning_rate': 0.0653894564670225, 'subsample': 0.6158191243588473, 'colsample_bytree': 0.9735060687098795, 'reg_alpha': 0.3033339622985529, 'reg_lambda': 0.38364633000752973}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:01,222] Trial 99 finished with value: 314947.78973579436 and parameters: {'n_estimators': 1247, 'max_depth': 3, 'learning_rate': 0.07663779410640938, 'subsample': 0.6231075400956593, 'colsample_bytree': 0.9896160334108569, 'reg_alpha': 0.3811410599854977, 'reg_lambda': 0.2783845322566102}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:02,334] Trial 100 finished with value: 297092.8787144152 and parameters: {'n_estimators': 1124, 'max_depth': 3, 'learning_rate': 0.08632225808190362, 'subsample': 0.6517537585747007, 'colsample_bytree': 0.9576775098063378, 'reg_alpha': 0.5193108065122034, 'reg_lambda': 0.13548422509892893}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:03,386] Trial 101 finished with value: 295517.3506156674 and parameters: {'n_estimators': 1006, 'max_depth': 3, 'learning_rate': 0.08724052177242589, 'subsample': 0.6447217399751647, 'colsample_bytree': 0.9554442814829225, 'reg_alpha': 0.47001046879443, 'reg_lambda': 0.1287311676978378}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:04,211] Trial 102 finished with value: 304272.85801192414 and parameters: {'n_estimators': 921, 'max_depth': 3, 'learning_rate': 0.09519596531511923, 'subsample': 0.6459697404338867, 'colsample_bytree': 0.9718778263278622, 'reg_alpha': 0.2720884742532942, 'reg_lambda': 0.1876565438212278}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:05,400] Trial 103 finished with value: 298699.5144265959 and parameters: {'n_estimators': 1157, 'max_depth': 3, 'learning_rate': 0.08943257761550552, 'subsample': 0.6332231778866991, 'colsample_bytree': 0.9933182738901101, 'reg_alpha': 0.1473580054640518, 'reg_lambda': 0.11811861097157857}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:06,872] Trial 104 finished with value: 302978.2598895321 and parameters: {'n_estimators': 955, 'max_depth': 3, 'learning_rate': 0.08175800135707309, 'subsample': 0.676636895708113, 'colsample_bytree': 0.8930470241928442, 'reg_alpha': 0.4722126509097431, 'reg_lambda': 0.23777213315877788}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:08,509] Trial 105 finished with value: 320116.69050303387 and parameters: {'n_estimators': 1070, 'max_depth': 4, 'learning_rate': 0.07406923154202759, 'subsample': 0.664480548583029, 'colsample_bytree': 0.6923767594119417, 'reg_alpha': 0.6357052091339334, 'reg_lambda': 0.3203698880929792}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:10,037] Trial 106 finished with value: 322767.0344235756 and parameters: {'n_estimators': 1034, 'max_depth': 3, 'learning_rate': 0.08409214880502308, 'subsample': 0.6003076564564821, 'colsample_bytree': 0.9809385479445191, 'reg_alpha': 0.3215443480982772, 'reg_lambda': 0.5115216624143004}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:11,499] Trial 107 finished with value: 300445.8597247986 and parameters: {'n_estimators': 1326, 'max_depth': 3, 'learning_rate': 0.05320169747790864, 'subsample': 0.6297064716338084, 'colsample_bytree': 0.9402717291102392, 'reg_alpha': 0.3667623123758397, 'reg_lambda': 0.1510934879325368}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:13,469] Trial 108 finished with value: 311723.8288577962 and parameters: {'n_estimators': 895, 'max_depth': 4, 'learning_rate': 0.0707882188055261, 'subsample': 0.6884412346913874, 'colsample_bytree': 0.9983201989044659, 'reg_alpha': 0.09107069652952274, 'reg_lambda': 0.06742217962622818}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:15,272] Trial 109 finished with value: 309347.07917043736 and parameters: {'n_estimators': 1012, 'max_depth': 3, 'learning_rate': 0.023203609061908954, 'subsample': 0.6543610833542397, 'colsample_bytree': 0.8799929367859902, 'reg_alpha': 0.7309297232016968, 'reg_lambda': 0.05475544792964778}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:17,342] Trial 110 finished with value: 301981.86297950754 and parameters: {'n_estimators': 1160, 'max_depth': 3, 'learning_rate': 0.06389223364939223, 'subsample': 0.6134753768065218, 'colsample_bytree': 0.9058376034821279, 'reg_alpha': 1.7646219485629075, 'reg_lambda': 0.1812937639052593}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:19,619] Trial 111 finished with value: 293301.3318854363 and parameters: {'n_estimators': 1113, 'max_depth': 3, 'learning_rate': 0.08981363629506066, 'subsample': 0.6528668058796582, 'colsample_bytree': 0.958499129744325, 'reg_alpha': 0.5032465615840418, 'reg_lambda': 0.10663214411563414}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:21,481] Trial 112 finished with value: 300315.1391757952 and parameters: {'n_estimators': 1285, 'max_depth': 3, 'learning_rate': 0.08843171340573489, 'subsample': 0.6403462474194739, 'colsample_bytree': 0.9637019062332622, 'reg_alpha': 0.245660599851985, 'reg_lambda': 0.07908657027941383}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:25,277] Trial 113 finished with value: 347851.70375647733 and parameters: {'n_estimators': 996, 'max_depth': 6, 'learning_rate': 0.09566589090183666, 'subsample': 0.6732152200725311, 'colsample_bytree': 0.9490523173682043, 'reg_alpha': 0.5016595591670168, 'reg_lambda': 0.11314859572191335}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:26,903] Trial 114 finished with value: 291659.06991181785 and parameters: {'n_estimators': 1133, 'max_depth': 3, 'learning_rate': 0.0781912430685592, 'subsample': 0.6479251099288159, 'colsample_bytree': 0.9795472998336137, 'reg_alpha': 0.9553470843988424, 'reg_lambda': 0.3050498741259682}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:28,298] Trial 115 finished with value: 316007.04657882085 and parameters: {'n_estimators': 1220, 'max_depth': 3, 'learning_rate': 0.0804227272468388, 'subsample': 0.6233559631557566, 'colsample_bytree': 0.981184135443935, 'reg_alpha': 1.048740274232168, 'reg_lambda': 0.2937981364566061}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:29,754] Trial 116 finished with value: 298552.7900725652 and parameters: {'n_estimators': 1129, 'max_depth': 3, 'learning_rate': 0.07620170590079495, 'subsample': 0.6466166967472349, 'colsample_bytree': 0.9258637433424617, 'reg_alpha': 0.9362006343620968, 'reg_lambda': 0.384025153571218}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:30,743] Trial 117 finished with value: 308447.6723642137 and parameters: {'n_estimators': 1083, 'max_depth': 3, 'learning_rate': 0.09147899841273437, 'subsample': 0.6937423122861572, 'colsample_bytree': 0.9732768161481455, 'reg_alpha': 2.152936580261377, 'reg_lambda': 0.2181063957711872}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:31,939] Trial 118 finished with value: 296024.231266635 and parameters: {'n_estimators': 1165, 'max_depth': 3, 'learning_rate': 0.06880846042951286, 'subsample': 0.6628776693416185, 'colsample_bytree': 0.9997718388774106, 'reg_alpha': 0.7994549577871922, 'reg_lambda': 0.1587497745010695}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:33,356] Trial 119 finished with value: 306946.060092952 and parameters: {'n_estimators': 1175, 'max_depth': 4, 'learning_rate': 0.0690032008016528, 'subsample': 0.6658342333047328, 'colsample_bytree': 0.9985124687350825, 'reg_alpha': 0.44657046024168806, 'reg_lambda': 0.1429755382402538}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:34,589] Trial 120 finished with value: 306509.0978845643 and parameters: {'n_estimators': 1193, 'max_depth': 3, 'learning_rate': 0.073465697389138, 'subsample': 0.6792601789521829, 'colsample_bytree': 0.9522720505602045, 'reg_alpha': 0.5605221889390335, 'reg_lambda': 0.10604079418608975}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:35,725] Trial 121 finished with value: 292079.72282500303 and parameters: {'n_estimators': 1138, 'max_depth': 3, 'learning_rate': 0.08431514277403201, 'subsample': 0.6371471165152225, 'colsample_bytree': 0.9847216670960662, 'reg_alpha': 0.7400210279558186, 'reg_lambda': 0.17807179796269326}. Best is trial 96 with value: 289060.7262303334.
# [I 2026-04-27 21:27:37,560] Trial 122 finished with value: 288257.32446927915 and parameters: {'n_estimators': 1145, 'max_depth': 3, 'learning_rate': 0.07964334129408765, 'subsample': 0.659251661503308, 'colsample_bytree': 0.9885744685962534, 'reg_alpha': 0.7613025094767495, 'reg_lambda': 0.17392508311834914}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:27:38,819] Trial 123 finished with value: 323618.99121572834 and parameters: {'n_estimators': 1240, 'max_depth': 3, 'learning_rate': 0.0835569496344182, 'subsample': 0.6074337388747654, 'colsample_bytree': 0.9897107460592792, 'reg_alpha': 0.7694126241654173, 'reg_lambda': 0.18360936539393535}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:27:40,306] Trial 124 finished with value: 296984.08479112585 and parameters: {'n_estimators': 1096, 'max_depth': 3, 'learning_rate': 0.06623252566093524, 'subsample': 0.6597529212015636, 'colsample_bytree': 0.9993699848461969, 'reg_alpha': 0.6736720651135417, 'reg_lambda': 0.22125357430853465}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:27:41,719] Trial 125 finished with value: 295925.5095318202 and parameters: {'n_estimators': 1133, 'max_depth': 3, 'learning_rate': 0.07864427089178791, 'subsample': 0.6467106491446187, 'colsample_bytree': 0.9623002499413722, 'reg_alpha': 0.8117607351667268, 'reg_lambda': 0.1708175006840212}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:27:42,818] Trial 126 finished with value: 300080.75781453855 and parameters: {'n_estimators': 1031, 'max_depth': 3, 'learning_rate': 0.07814719064052182, 'subsample': 0.6279750879555436, 'colsample_bytree': 0.965346613307591, 'reg_alpha': 0.3777369236848939, 'reg_lambda': 0.3478791179370375}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:27:43,916] Trial 127 finished with value: 307861.7612015237 and parameters: {'n_estimators': 1114, 'max_depth': 3, 'learning_rate': 0.08695521233890549, 'subsample': 0.5709555407353476, 'colsample_bytree': 0.9734112001313288, 'reg_alpha': 0.5576198283890511, 'reg_lambda': 0.4666119436569404}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:27:44,944] Trial 128 finished with value: 303553.3604852947 and parameters: {'n_estimators': 1144, 'max_depth': 3, 'learning_rate': 0.09975803205734654, 'subsample': 0.5958328196338043, 'colsample_bytree': 0.9424631988645373, 'reg_alpha': 0.9947840611208844, 'reg_lambda': 0.1281157404991938}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:27:46,145] Trial 129 finished with value: 304860.4809455465 and parameters: {'n_estimators': 1286, 'max_depth': 3, 'learning_rate': 0.08183431669761976, 'subsample': 0.6429596437747145, 'colsample_bytree': 0.9576743862320032, 'reg_alpha': 0.1869390232695242, 'reg_lambda': 0.2502379535068218}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:27:47,166] Trial 130 finished with value: 301565.62829036906 and parameters: {'n_estimators': 1076, 'max_depth': 3, 'learning_rate': 0.07413096647110942, 'subsample': 0.6192042969687295, 'colsample_bytree': 0.9147075136932941, 'reg_alpha': 0.44867982587992133, 'reg_lambda': 0.5975734585437895}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:27:48,515] Trial 131 finished with value: 297039.2757203549 and parameters: {'n_estimators': 1194, 'max_depth': 3, 'learning_rate': 0.06981673567314331, 'subsample': 0.6673705342612765, 'colsample_bytree': 0.9823218238381305, 'reg_alpha': 0.8053459950738122, 'reg_lambda': 0.15842959225378997}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:27:54,903] Trial 132 finished with value: 350301.6021583252 and parameters: {'n_estimators': 1047, 'max_depth': 8, 'learning_rate': 0.07868584989777479, 'subsample': 0.6343170730467723, 'colsample_bytree': 0.9864398656712576, 'reg_alpha': 0.6528795641730087, 'reg_lambda': 0.19065463287665238}. Best is trial 122 with value: 288257.32446927915.
# ...
# [I 2026-04-27 21:28:29,193] Trial 157 finished with value: 302569.6314264818 and parameters: {'n_estimators': 1007, 'max_depth': 3, 'learning_rate': 0.07694010041608375, 'subsample': 0.6358348032701696, 'colsample_bytree': 0.9546329085093885, 'reg_alpha': 0.06394744042479525, 'reg_lambda': 0.031697622530147615}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:28:30,023] Trial 158 finished with value: 308412.53191764717 and parameters: {'n_estimators': 903, 'max_depth': 3, 'learning_rate': 0.08799221825163457, 'subsample': 0.9611134532728667, 'colsample_bytree': 0.9683097234882969, 'reg_alpha': 0.27053074589839476, 'reg_lambda': 0.07436208078485648}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:28:31,242] Trial 159 finished with value: 320352.186434838 and parameters: {'n_estimators': 977, 'max_depth': 4, 'learning_rate': 0.06342693606410665, 'subsample': 0.647447149960161, 'colsample_bytree': 0.9235074841271365, 'reg_alpha': 0.07240541146279947, 'reg_lambda': 0.02682799400698017}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:28:32,175] Trial 160 finished with value: 313803.0323360487 and parameters: {'n_estimators': 1073, 'max_depth': 3, 'learning_rate': 0.09333810028928773, 'subsample': 0.6220958456709275, 'colsample_bytree': 0.9385857849783754, 'reg_alpha': 0.4422701277334109, 'reg_lambda': 0.053161535992370904}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:28:33,143] Trial 161 finished with value: 303840.48662824737 and parameters: {'n_estimators': 1106, 'max_depth': 3, 'learning_rate': 0.06540021964689566, 'subsample': 0.5866341830482952, 'colsample_bytree': 0.9776826947062661, 'reg_alpha': 0.3925636906225523, 'reg_lambda': 0.007700475835571672}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:28:34,061] Trial 162 finished with value: 296174.0026013329 and parameters: {'n_estimators': 1053, 'max_depth': 3, 'learning_rate': 0.05746350259719602, 'subsample': 0.6029679513311041, 'colsample_bytree': 0.9580294805469106, 'reg_alpha': 0.5405837779986584, 'reg_lambda': 0.021919019716891194}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:28:35,035] Trial 163 finished with value: 290025.56825970334 and parameters: {'n_estimators': 1015, 'max_depth': 3, 'learning_rate': 0.060314251143460396, 'subsample': 0.5972755787955271, 'colsample_bytree': 0.9473976753069098, 'reg_alpha': 0.15188351159100125, 'reg_lambda': 0.3556452789576879}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:28:35,952] Trial 164 finished with value: 299832.9275030674 and parameters: {'n_estimators': 1019, 'max_depth': 3, 'learning_rate': 0.07127623978696701, 'subsample': 0.6345280856419984, 'colsample_bytree': 0.9507783352321335, 'reg_alpha': 0.1381504863328154, 'reg_lambda': 0.21444990787882803}. Best is trial 122 with value: 288257.32446927915.
# [I 2026-04-27 21:28:36,795] Trial 165 finished with value: 286284.16031152295 and parameters: {'n_estimators': 963, 'max_depth': 3, 'learning_rate': 0.08034806312363742, 'subsample': 0.649840322505911, 'colsample_bytree': 0.9702092815445313, 'reg_alpha': 0.17820446354056346, 'reg_lambda': 0.08672538871564624}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:37,654] Trial 166 finished with value: 316300.60107690183 and parameters: {'n_estimators': 955, 'max_depth': 3, 'learning_rate': 0.019192702663645228, 'subsample': 0.6118519290403914, 'colsample_bytree': 0.9832298464205291, 'reg_alpha': 0.1678554380420087, 'reg_lambda': 0.09081985412745347}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:38,450] Trial 167 finished with value: 287222.40838177636 and parameters: {'n_estimators': 877, 'max_depth': 3, 'learning_rate': 0.08275590171237214, 'subsample': 0.653769533149716, 'colsample_bytree': 0.9689870412424353, 'reg_alpha': 0.21164280812575909, 'reg_lambda': 0.019791333364755206}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:39,192] Trial 168 finished with value: 305993.0002527894 and parameters: {'n_estimators': 843, 'max_depth': 3, 'learning_rate': 0.08308068642160736, 'subsample': 0.656374433436871, 'colsample_bytree': 0.9721016829786375, 'reg_alpha': 0.11161221145838983, 'reg_lambda': 0.019073294238193296}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:44,908] Trial 169 finished with value: 357260.5592714741 and parameters: {'n_estimators': 877, 'max_depth': 9, 'learning_rate': 0.08862333228715141, 'subsample': 0.6802165745865844, 'colsample_bytree': 0.9423492419521492, 'reg_alpha': 0.20307204852471664, 'reg_lambda': 0.3668031729690488}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:45,727] Trial 170 finished with value: 300556.2852869723 and parameters: {'n_estimators': 741, 'max_depth': 3, 'learning_rate': 0.07603833850298511, 'subsample': 0.6670654115412394, 'colsample_bytree': 0.9490163003033073, 'reg_alpha': 0.15124315838835636, 'reg_lambda': 0.025277216027161882}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:46,864] Trial 171 finished with value: 298378.7347085684 and parameters: {'n_estimators': 1078, 'max_depth': 3, 'learning_rate': 0.06050201503890301, 'subsample': 0.6392519389349083, 'colsample_bytree': 0.9883592873342022, 'reg_alpha': 0.22583267363461348, 'reg_lambda': 0.04490939692632995}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:47,780] Trial 172 finished with value: 299245.1704290825 and parameters: {'n_estimators': 982, 'max_depth': 3, 'learning_rate': 0.08131770344954369, 'subsample': 0.5643727654709857, 'colsample_bytree': 0.9658586135778291, 'reg_alpha': 0.10505090349160302, 'reg_lambda': 0.06250168629984777}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:48,745] Trial 173 finished with value: 297875.64855858294 and parameters: {'n_estimators': 1031, 'max_depth': 3, 'learning_rate': 0.06685046187558315, 'subsample': 0.6507369241304597, 'colsample_bytree': 0.9740195987675462, 'reg_alpha': 0.16657286344940742, 'reg_lambda': 0.01261268436590055}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:49,664] Trial 174 finished with value: 302575.4482630146 and parameters: {'n_estimators': 1013, 'max_depth': 3, 'learning_rate': 0.07329803411897194, 'subsample': 0.6274072592139981, 'colsample_bytree': 0.9809099746783402, 'reg_alpha': 0.2733376327445007, 'reg_lambda': 0.12072591771592145}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:50,520] Trial 175 finished with value: 320293.4251776943 and parameters: {'n_estimators': 932, 'max_depth': 3, 'learning_rate': 0.08490539305629481, 'subsample': 0.5999690939370974, 'colsample_bytree': 0.9594419752998233, 'reg_alpha': 0.196774749092903, 'reg_lambda': 0.030725298060735953}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:51,016] Trial 176 finished with value: 321480.5071827081 and parameters: {'n_estimators': 520, 'max_depth': 3, 'learning_rate': 0.09326544625895988, 'subsample': 0.6203593252531541, 'colsample_bytree': 0.6525480636977747, 'reg_alpha': 0.12907896438172542, 'reg_lambda': 0.010042249517507025}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:51,628] Trial 177 finished with value: 301408.0332326294 and parameters: {'n_estimators': 617, 'max_depth': 3, 'learning_rate': 0.06880419138829424, 'subsample': 0.650825038238842, 'colsample_bytree': 0.9322185062128887, 'reg_alpha': 0.35052256567110424, 'reg_lambda': 0.2998290274630743}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:52,651] Trial 178 finished with value: 305332.57957693574 and parameters: {'n_estimators': 1093, 'max_depth': 3, 'learning_rate': 0.06374341952318308, 'subsample': 0.8763968287739812, 'colsample_bytree': 0.9994258887154471, 'reg_alpha': 0.25119073740756426, 'reg_lambda': 0.016038493048572487}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:53,574] Trial 179 finished with value: 297015.1016941532 and parameters: {'n_estimators': 977, 'max_depth': 3, 'learning_rate': 0.07954554604835282, 'subsample': 0.6430752921276214, 'colsample_bytree': 0.9868693945243793, 'reg_alpha': 0.18989519283870548, 'reg_lambda': 0.018721515291224275}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:54,329] Trial 180 finished with value: 295612.54322764813 and parameters: {'n_estimators': 812, 'max_depth': 3, 'learning_rate': 0.07213397912729061, 'subsample': 0.6316411995215461, 'colsample_bytree': 0.9682485553311677, 'reg_alpha': 0.3052695858186835, 'reg_lambda': 0.2523350227366734}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:55,133] Trial 181 finished with value: 306349.2813536939 and parameters: {'n_estimators': 875, 'max_depth': 3, 'learning_rate': 0.07431262070787563, 'subsample': 0.6327214708068754, 'colsample_bytree': 0.9702892241550464, 'reg_alpha': 0.28415095288022396, 'reg_lambda': 0.24567655823695828}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:55,870] Trial 182 finished with value: 296039.7313937053 and parameters: {'n_estimators': 787, 'max_depth': 3, 'learning_rate': 0.07097205863798517, 'subsample': 0.6634873262095051, 'colsample_bytree': 0.9589201105690064, 'reg_alpha': 0.0018023369445289018, 'reg_lambda': 4.441159846054383}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:56,674] Trial 183 finished with value: 286835.04143263213 and parameters: {'n_estimators': 861, 'max_depth': 3, 'learning_rate': 0.07874281239500604, 'subsample': 0.6540994465746586, 'colsample_bytree': 0.9784829957237733, 'reg_alpha': 0.344256965000249, 'reg_lambda': 0.20552629851971696}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:57,683] Trial 184 finished with value: 290146.0572723441 and parameters: {'n_estimators': 851, 'max_depth': 3, 'learning_rate': 0.07717801475991927, 'subsample': 0.6568098954704773, 'colsample_bytree': 0.9493935302591919, 'reg_alpha': 0.3949997125975479, 'reg_lambda': 0.20217282299533995}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:58,596] Trial 185 finished with value: 322345.04456454446 and parameters: {'n_estimators': 847, 'max_depth': 3, 'learning_rate': 0.017379492352036383, 'subsample': 0.67099622503607, 'colsample_bytree': 0.9442880310649877, 'reg_alpha': 0.38596184269517986, 'reg_lambda': 0.2019645397168533}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:28:59,455] Trial 186 finished with value: 300689.68596921285 and parameters: {'n_estimators': 914, 'max_depth': 3, 'learning_rate': 0.08226597874121704, 'subsample': 0.6556477278359497, 'colsample_bytree': 0.9189545070397005, 'reg_alpha': 0.43601080922138297, 'reg_lambda': 0.13809452875074013}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:00,239] Trial 187 finished with value: 302083.16090869124 and parameters: {'n_estimators': 828, 'max_depth': 3, 'learning_rate': 0.07767394933891214, 'subsample': 0.6444819117897714, 'colsample_bytree': 0.9516767271552375, 'reg_alpha': 0.21850718244631676, 'reg_lambda': 0.11302343902387947}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:01,049] Trial 188 finished with value: 295553.0175653748 and parameters: {'n_estimators': 879, 'max_depth': 3, 'learning_rate': 0.08735137426970616, 'subsample': 0.6617124920538144, 'colsample_bytree': 0.9781971959099159, 'reg_alpha': 0.009521336120696338, 'reg_lambda': 0.1828740623480575}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:02,013] Trial 189 finished with value: 298425.97675348824 and parameters: {'n_estimators': 1051, 'max_depth': 3, 'learning_rate': 0.08081090805901425, 'subsample': 0.6771868720154881, 'colsample_bytree': 0.9347526949390332, 'reg_alpha': 0.3391015658534335, 'reg_lambda': 0.08277944387842259}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:02,921] Trial 190 finished with value: 308061.0878562384 and parameters: {'n_estimators': 948, 'max_depth': 3, 'learning_rate': 0.0870630021400654, 'subsample': 0.6535579469568794, 'colsample_bytree': 0.9555022708442734, 'reg_alpha': 0.49419616423907964, 'reg_lambda': 0.34383615815315777}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:03,930] Trial 191 finished with value: 306658.6689575389 and parameters: {'n_estimators': 1094, 'max_depth': 3, 'learning_rate': 0.08887601734727664, 'subsample': 0.665855846697149, 'colsample_bytree': 0.978258715125045, 'reg_alpha': 0.004493723640395978, 'reg_lambda': 0.1918698331228513}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:04,769] Trial 192 finished with value: 301787.05683823704 and parameters: {'n_estimators': 907, 'max_depth': 3, 'learning_rate': 0.08580447557045734, 'subsample': 0.6404340319276184, 'colsample_bytree': 0.9785451159473855, 'reg_alpha': 0.009035337218534743, 'reg_lambda': 0.16062317458047357}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:05,499] Trial 193 finished with value: 298497.5812362804 and parameters: {'n_estimators': 773, 'max_depth': 3, 'learning_rate': 0.0953424613575044, 'subsample': 0.659981289680534, 'colsample_bytree': 0.9641894366500613, 'reg_alpha': 0.39848937502881765, 'reg_lambda': 0.18241913276721738}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:06,292] Trial 194 finished with value: 303995.49089072103 and parameters: {'n_estimators': 856, 'max_depth': 3, 'learning_rate': 0.0757023644494609, 'subsample': 0.6493885099220611, 'colsample_bytree': 0.9883685992002418, 'reg_alpha': 0.07892890672219385, 'reg_lambda': 0.1387053028275132}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:07,264] Trial 195 finished with value: 298458.36624518223 and parameters: {'n_estimators': 1054, 'max_depth': 3, 'learning_rate': 0.08305861653279806, 'subsample': 0.6721636146044627, 'colsample_bytree': 0.9696314670091332, 'reg_alpha': 0.16316947768209525, 'reg_lambda': 0.4094821693951092}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:08,076] Trial 196 finished with value: 307419.8540053827 and parameters: {'n_estimators': 867, 'max_depth': 3, 'learning_rate': 0.02922399481369523, 'subsample': 0.6841138806611732, 'colsample_bytree': 0.9805571120775212, 'reg_alpha': 0.5886654375896222, 'reg_lambda': 0.10826155938274609}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:08,967] Trial 197 finished with value: 313073.39761638764 and parameters: {'n_estimators': 1004, 'max_depth': 3, 'learning_rate': 0.09020841763939, 'subsample': 0.6353850763523446, 'colsample_bytree': 0.7312865513362581, 'reg_alpha': 0.2395084392057466, 'reg_lambda': 0.21700288276974783}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:15,532] Trial 198 finished with value: 359320.3005873569 and parameters: {'n_estimators': 886, 'max_depth': 10, 'learning_rate': 0.012906245979000587, 'subsample': 0.6588088320683925, 'colsample_bytree': 0.9459371256057614, 'reg_alpha': 0.3069585647359619, 'reg_lambda': 0.30429156777637967}. Best is trial 165 with value: 286284.16031152295.
# [I 2026-04-27 21:29:17,211] Trial 199 finished with value: 304128.4751220337 and parameters: {'n_estimators': 1771, 'max_depth': 3, 'learning_rate': 0.07940714915256493, 'subsample': 0.622298173684532, 'colsample_bytree': 0.9606573781734175, 'reg_alpha': 0.018927320389592984, 'reg_lambda': 0.152075864255115}. Best is trial 165 with value: 286284.16031152295.
# Bộ tham số xịn nhất đây rồi: {'n_estimators': 963, 'max_depth': 3, 'learning_rate': 0.08034806312363742, 'subsample': 0.649840322505911, 'colsample_bytree': 0.9702092815445313, 'reg_alpha': 0.17820446354056346, 'reg_lambda': 0.08672538871564624}

# %% [markdown]
# #### By consolidating our hyperparameter tuning into a single, parameter-driven cell, we have implemented a modular pipeline that prioritizes code maintainability. This approach allows for seamless iteration; once the high-gain features are identified through exploratory analysis, they are statically updated in the configuration layer. This decoupling ensures that the Bayesian search engine (Optuna) consistently operates on a refined input matrix, effectively reducing computational overhead and mitigating the risk of stochastic variance. The result is a highly robust and reproducible model, optimized for the structural dynamics of the 2023 retail landscape.

# %%
# from xgboost import plot_importance

# # 1. Train lại một model với bộ tham số xịn nhất Optuna vừa tìm được
# best_model = XGBRegressor(**study.best_params)
# best_model.fit(X_train, y_train)

# # 2. Vẽ biểu đồ quan trọng theo GÁNH (Gain) - Cái này chuẩn hơn Weight
# fig, ax = plt.subplots(figsize=(10, 12))
# plot_importance(best_model, importance_type='gain', ax=ax)
# plt.show()

from xgboost import plot_importance
import matplotlib.pyplot as plt # Đảm bảo bạn đã import thư viện này để vẽ hình

# 1. Train lại một model với bộ tham số xịn nhất Optuna vừa tìm được
best_model = XGBRegressor(**study.best_params)

# --- DỌN DẸP LẠI DỮ LIỆU (Giống hệt bước trước) ---
X_train_clean = X_train.loc[:, ~X_train.columns.duplicated()].copy()
y_train_1d = y_train.squeeze()
# ---------------------------------------------------

# Fit model bằng dữ liệu ĐÃ CLEAN
best_model.fit(X_train_clean, y_train_1d)

# 2. Vẽ biểu đồ quan trọng theo GÁNH (Gain) - Cái này chuẩn hơn Weight
fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(best_model, importance_type='gain', ax=ax)
plt.show()

# %%
import xgboost as xgb

best_param={
    'n_estimators': 963,
    'max_depth': 3, 
    'learning_rate': 0.08034806312363742, 
    'subsample': 0.649840322505911, 
    'colsample_bytree': 0.9702092815445313, 
    'reg_alpha': 0.17820446354056346, 
    'reg_lambda': 0.08672538871564624
}
model_rev = XGBRegressor(**best_param)
model_rev.fit(df_daily[features], df_daily['Revenue'])

model_cogs= XGBRegressor(**best_param)
model_cogs.fit(df_daily[features], df_daily['COGS'])

print("✅ Đã huấn luyện xong bộ đôi 'não bộ' cho Model!")

from sklearn.model_selection import KFold, cross_validate
from sklearn.metrics import r2_score
kf = KFold(n_splits=5, shuffle=True, random_state=42)
scoring = {'mse': 'neg_mean_squared_error', 'r2': 'r2'}

# Chấm điểm thử cho Model Revenue
cv_results = cross_validate(model_rev, df_daily[features], df_daily['Revenue'], 
                            cv=kf, scoring=scoring)

# Tính toán các chỉ số trung bình từ kết quả CV
avg_mse = -cv_results['test_mse'].mean()
avg_rmse = np.sqrt(avg_mse)
avg_r2 = cv_results['test_r2'].mean()

print(f"📊 Kết quả Đánh giá 5-Fold:")
print(f"   - MSE:  {avg_mse:,.2f}")
print(f"   - RMSE: {avg_rmse:,.2f}")
print(f"   - R²:   {avg_r2:.4f}")

train_pred = model_rev.predict(df_daily[features])
train_r2 = r2_score(df_daily['Revenue'], train_pred)
print(f"Điểm trên tập Train: {train_r2:.4f}")
# Out:
# ✅ Đã huấn luyện xong bộ đôi 'não bộ' cho Model!
# 📊 Kết quả Đánh giá 5-Fold:
#    - MSE:  95,262,094,405.17
#    - RMSE: 308,645.58
#    - R²:   0.9856
# Điểm trên tập Train: 0.9967

# %%
# ĐÁNH GIÁ MÔ HÌNH REVENUE
cv_rev = cross_validate(model_rev, df_daily[features], df_daily['Revenue'], 
                         cv=kf, scoring=scoring)

# ĐÁNH GIÁ MÔ HÌNH COGS
cv_cogs = cross_validate(model_cogs, df_daily[features], df_daily['COGS'], 
                          cv=kf, scoring=scoring)

# TỔNG KẾT KẾT QUẢ
print(f"[REVENUE] Local RMSE: {np.sqrt(-cv_rev['test_mse'].mean()):,.2f} | R²: {cv_rev['test_r2'].mean():.4f}")
print(f"[COGS]    Local RMSE: {np.sqrt(-cv_cogs['test_mse'].mean()):,.2f} | R²: {cv_cogs['test_r2'].mean():.4f}")
# Out:
# [REVENUE] Local RMSE: 308,645.58 | R²: 0.9856
# [COGS]    Local RMSE: 261,245.85 | R²: 0.9861

# %%
from xgboost import plot_importance

# 1. Thiết lập kích thước biểu đồ
fig, ax = plt.subplots(figsize=(10, 8))

# 2. Vẽ biểu đồ quan trọng (Dùng 'weight' để xem tần suất biến đó được dùng để phân loại)
plot_importance(model_rev, ax=ax, max_num_features=15, importance_type='weight', color='royalblue')

plt.title("Top 15 Đặc trưng ảnh hưởng nhất đến Doanh thu")
plt.show()

# %%
ALL_DATES = sorted(df_daily['Date'].unique())

def get_lag_safe(date_obj, lag_days, key, hist_dict):
    target_date = date_obj - pd.Timedelta(days=lag_days)
    
    if target_date in hist_dict:
        return hist_dict[target_date].get(key, 0)
    
    valid_dates = [d for d in ALL_DATES if d <= target_date]
    if valid_dates:
        closest_date = valid_dates[-1]
        if abs((closest_date - target_date).days) <= 3:
            return hist_dict.get(closest_date, {}).get(key, 0)
    return 0

# %%
def get_promo_features_for_single_date(current_date):
    year = current_date.year
    month_day = current_date.strftime('%m-%d')
    
    is_spring = 1 if '03-18' <= month_day <= '04-17' else 0
    is_midyear = 1 if '06-23' <= month_day <= '07-22' else 0
    is_fall = 1 if ('08-30' <= month_day <= '10-01') or ((year % 4 == 1) and month_day == '10-02') else 0
    is_yearend = 1 if ('11-18' <= month_day <= '12-31') or ('01-01' <= month_day <= '01-02') else 0
    
    is_rural = 1 if (year % 2 == 1) and ('01-30' <= month_day <= '03-01') else 0
    is_urban = 1 if (year % 2 == 1) and ('07-30' <= month_day <= '09-02') else 0
    
    # --- Decode ---
    cat_promo = -1
    if is_spring or is_midyear or is_yearend:
        cat_promo = 0
    if is_rural:
        cat_promo = 1
    if is_urban:
        cat_promo = 2
        
    chanel_promo = -1
    if is_spring or is_fall:
        chanel_promo = 4
    if is_rural:
        chanel_promo = 1
    if is_urban:
        chanel_promo = 2
    if is_midyear:
        chanel_promo = 3
    if is_yearend:
        chanel_promo = 0
        
    pct_discount = 0.0
    if is_rural:
        pct_discount = 0.15
    if is_spring:
        pct_discount = 0.12
    if is_midyear:
        pct_discount = 0.18
    if is_fall:
        pct_discount = 0.1
    if is_yearend:
        pct_discount = 0.2
    
    fix_discount = 0
    if is_urban:
        fix_discount = 50
        
    return {
        'is_Spring_promotion': is_spring,
        'is_MidYear_promotion': is_midyear,
        'is_FallLauch_promotion': is_fall,
        'is_YearEnd_promotion': is_yearend,
        'is_Rural_promotion': is_rural,
        'is_Urban_promotion': is_urban,
        'category_promotion': cat_promo,
        'chanel_promotion': chanel_promo,
        'pct_discount_promotion': pct_discount, 
        'fix_discount_promotion': fix_discount 
    }

# %%
from sklearn.metrics import mean_squared_error
from tqdm import tqdm

# Hàm helper lấy giá trị từ dictionary lịch sử
def get_lag_val(date_obj, lag_days, key, hist_dict):
    target_ds = date_obj - pd.Timedelta(days=lag_days)
    if target_ds in hist_dict:
        return hist_dict[target_ds].get(key, 0)
    return 0

# 1. Tạo tập validation 
val_start = '2022-11-01'
val_end = '2022-12-31'

# Lấy 400 ngày cuối cùng của tập train để làm lịch sử cho validation
historical_val = df_daily[['Date', 'Revenue', 'Profit']].iloc[-400:-30].copy()
historical_val = historical_val.rename(columns={'Date': 'ds', 'Revenue': 'y', 'Profit': 'profit'})
historical_val_dict = historical_val.set_index('ds').to_dict('index')

# 2. Tạo đặc trưng tĩnh theo tháng
train_monthly_avg = df_daily.groupby('month')[
    ['seg_Balanced', 'seg_Activewear', 'seg_Premium', 'seg_All-weather', 'seg_Everyday', 'seg_Performance', 
    'cat_Casual', 'cat_Outdoor', 'cat_Streetwear', 
    
    'rev_lag_1', 'rev_lag_7', 'rev_lag_365', 
    'profit_lag_1', 'profit_lag_7', 'profit_lag_365', 
    'margin_rate', 'margin_rate_lag_1', 'margin_rate_lag_7', 'margin_rate_lag_365',  
    
    'month', 'is_promoted', 
    'avg_discount_pct', 'max_discount_pct',

    'is_Spring_promotion', 'is_MidYear_promotion', 'is_FallLauch_promotion',
    'is_YearEnd_promotion', 'is_Rural_promotion', 'is_Urban_promotion',
    'category_promotion', 'chanel_promotion', 
    'pct_discount_promotion', 'fix_discount_promotion']
].mean().to_dict('index')

# 3. Tìm tỷ lệ blending tối ưu
best_score = float('inf')
best_ratio = 0.8
best_growth = 1.03

print("Đang tìm tỷ lệ blending tối ưu...")
for growth in [0.99, 1.0, 1.01]:
    for ratio in [0.45, 0.5, 0.55, 0.60]:
        val_results = []
        temp_dict = historical_val_dict.copy()
        
        for current_date in pd.date_range(start=val_start, end=val_end):
            month = current_date.month
            promo_features = get_promo_features_for_single_date(current_date)
            # Tạo feature cho ngày hiện tại
            current_features = {
                'month': month,
                
                'rev_lag_1': get_lag_safe(current_date, 1, 'y', temp_dict),
                'rev_lag_7': get_lag_safe(current_date, 7, 'y', temp_dict),
                'rev_lag_365': get_lag_safe(current_date, 365, 'y', temp_dict),

                'profit_lag_1': get_lag_safe(current_date, 1, 'profit', temp_dict),
                'profit_lag_7': get_lag_safe(current_date, 7, 'profit', temp_dict),
                'profit_lag_365': get_lag_safe(current_date, 365, 'profit', temp_dict),

                'margin_rate_lag_7': get_lag_safe(current_date, 7, 'profit', temp_dict) / (get_lag_safe(current_date, 7, 'y', temp_dict) + 1),
                'margin_rate_lag_1': get_lag_safe(current_date, 1, 'profit', temp_dict) / (get_lag_safe(current_date, 1, 'y', temp_dict) + 1),
                'margin_rate_lag_365': get_lag_safe(current_date, 365, 'profit', temp_dict) / (get_lag_safe(current_date, 365, 'y', temp_dict) + 1),
            }
            current_features.update(promo_features)
        
            # Tính margin_rate_lag_7
            rev_lag_7 = get_lag_safe(current_date, 7, 'y', temp_dict)
            profit_lag_7_val = current_features['profit_lag_7']
            current_features['margin_rate_lag_7'] = profit_lag_7_val / (rev_lag_7 + 1)
            
            # Thêm đặc trưng tĩnh
            for k, v in train_monthly_avg.get(month, {}).items():
                current_features[k] = v 
            
            X_pred = pd.DataFrame([current_features])[features]
            revenue_pred = model_rev.predict(X_pred)[0]
            cogs_pred = model_cogs.predict(X_pred)[0]
            
            hist_rev = get_lag_safe(current_date, 365, 'y', temp_dict)
            hist_cogs = hist_rev - get_lag_safe(current_date, 365, 'profit', temp_dict) if hist_rev > 0 else 0
            
            final_rev = (hist_rev * growth * ratio) + (revenue_pred * (1 - ratio))
            final_cogs = (hist_cogs * growth * ratio) + (cogs_pred * (1 - ratio))
            
            temp_dict[current_date] = {'y': final_rev, 'profit': final_rev - final_cogs}
            val_results.append({'Date': current_date, 'Revenue': final_rev, 'COGS': final_cogs})
        
        # Đánh giá
        val_df = pd.DataFrame(val_results)
        actual_train = df_daily[df_daily['Date'].between(val_start, val_end)]
        val_merged = val_df.merge(actual_train[['Date', 'Revenue', 'COGS']], on='Date', suffixes=('_pred', '_actual'))
        
        mse_rev = mean_squared_error(val_merged['Revenue_actual'], val_merged['Revenue_pred'])
        mse_cogs = mean_squared_error(val_merged['COGS_actual'], val_merged['COGS_pred'])
        total_mse = mse_rev + mse_cogs
        
        if total_mse < best_score:
            best_score = total_mse
            best_ratio = ratio
            best_growth = growth

print(f"\nTỶ LỆ BLENDING TỐI ƯU:")
print(f"   - History weight: {best_ratio:.0%}")
print(f"   - AI weight:      {1-best_ratio:.0%}")
print(f"   - Growth factor:  {best_growth}")
print(f"   - Best MSE:       {best_score:,.2f}")
# Out:
# Đang tìm tỷ lệ blending tối ưu...
#
# TỶ LỆ BLENDING TỐI ƯU:
#    - History weight: 45%
#    - AI weight:      55%
#    - Growth factor:  0.99
#    - Best MSE:       703,166,719,647.39

# %%
from tqdm import tqdm

print("Bắt đầu quá trình dự đoán tuần tự...")

historical_df = df_daily[['Date', 'Revenue', 'Profit']].iloc[-370:].copy()
historical_df = historical_df.rename(columns={'Date': 'ds', 'Revenue': 'y', 'Profit': 'profit'})
historical_dict = historical_df.set_index('ds').to_dict('index')

future_dates = pd.date_range(start='2023-01-01', end='2024-07-01')
results = []

# Các đặc trưng tĩnh (không thay đổi theo thời gian hoặc lấy trung bình tháng)
train_monthly_avg = df_daily.groupby('month')[
    ['seg_Balanced', 'seg_Activewear', 'seg_Premium', 'seg_All-weather', 'seg_Everyday', 'seg_Performance', 
    'cat_Casual', 'cat_Outdoor', 'cat_Streetwear', 
    
    'rev_lag_1', 'rev_lag_7', 'rev_lag_365', 
    'profit_lag_1', 'profit_lag_7', 'profit_lag_365', 
    'margin_rate', 'margin_rate_lag_1', 'margin_rate_lag_7', 'margin_rate_lag_365',  
    
    'month', 'is_promoted', 
    'avg_discount_pct', 'max_discount_pct',

    'is_Spring_promotion', 'is_MidYear_promotion', 'is_FallLauch_promotion',
    'is_YearEnd_promotion', 'is_Rural_promotion', 'is_Urban_promotion',
    'category_promotion', 'chanel_promotion', 
    'pct_discount_promotion', 'fix_discount_promotion']
].mean().to_dict('index')
# Dự đoán tuần tự
for current_date in tqdm(future_dates, desc="Đang dự đoán"):
    month = current_date.month
    promo_features = get_promo_features_for_single_date(current_date)
    # Tạo feature cho ngày hiện tại
    current_features = {
        'month': month,
        
        'rev_lag_1': get_lag_safe(current_date, 1, 'y', historical_dict),
        'rev_lag_7': get_lag_safe(current_date, 7, 'y', historical_dict),
        'rev_lag_365': get_lag_safe(current_date, 365, 'y', historical_dict),

        'profit_lag_1': get_lag_safe(current_date, 1, 'profit', historical_dict),
        'profit_lag_7': get_lag_safe(current_date, 7, 'profit', historical_dict),
        'profit_lag_365': get_lag_safe(current_date, 365, 'profit', historical_dict),

        'margin_rate_lag_7': get_lag_safe(current_date, 7, 'profit', historical_dict) / (get_lag_safe(current_date, 7, 'y', historical_dict) + 1),
        'margin_rate_lag_1': get_lag_safe(current_date, 1, 'profit', historical_dict) / (get_lag_safe(current_date, 1, 'y', historical_dict) + 1),
        'margin_rate_lag_365': get_lag_safe(current_date, 365, 'profit', historical_dict) / (get_lag_safe(current_date, 365, 'y', historical_dict) + 1),
    }
    current_features.update(promo_features)
    
    # Thêm các đặc trưng tĩnh từ dữ liệu trung bình tháng
    for k, v in train_monthly_avg.get(month, {}).items():
        current_features[k] = v

    # Dự đoán Doanh thu và Giá vốn
    X_pred = pd.DataFrame([current_features])[features]
    revenue_pred = model_rev.predict(X_pred)[0]
    cogs_pred = model_cogs.predict(X_pred)[0]

    # Blending
    hist_rev = get_lag_safe(current_date, 365, 'y', historical_dict)
    hist_cogs = hist_rev - get_lag_safe(current_date, 365, 'profit', historical_dict) if hist_rev > 0 else 0

    growth_factor = 1.00
    final_rev = (hist_rev * growth_factor * 0.5) + (revenue_pred * 0.5)
    final_cogs = (hist_cogs * growth_factor * 0.5) + (cogs_pred * 0.5)

    # Cập nhật kết quả vào historical_dict cho các lần dự đoán tiếp theo
    historical_dict[current_date] = {'y': final_rev, 'profit': final_rev - final_cogs}
    
    # Lưu kết quả
    results.append({
        'Date': current_date.strftime('%Y-%m-%d'),
        'Revenue': final_rev,
        'COGS': final_cogs
    })

# Tạo và lưu file submission
submission_final = pd.DataFrame(results)
path_submit = 'submission_vi_v3.csv'
submission_final.to_csv(path_submit, index=False)
print(f"✅ File {path_submit} đã sẵn sàng nộp.")
# Out:
# Bắt đầu quá trình dự đoán tuần tự...
# Đang dự đoán: 100%|██████████| 548/548 [00:12<00:00, 44.50it/s]
# ✅ File submission_vi_v3.csv đã sẵn sàng nộp.
